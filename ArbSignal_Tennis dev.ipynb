# %%
import pandas as pd
# Set pandas to display all columns
pd.set_option('display.max_columns', None)

# %%
toto_raw = pd.read_csv('Data/scrapers/Toto/totoAllSports2025-01-21T18:05:01Z.csv', index_col=0).drop_duplicates()
kambi_raw = pd.read_csv('Data/scrapers/unibet/unibetAllSports2025-01-21T16:02:20Z.csv', index_col=0).drop_duplicates()
# Apply the condition and update outcome_label
toto_raw_tennis = toto_raw[toto_raw['sport'] == 'Tennis']
kambi_raw_tennis = kambi_raw[kambi_raw['sport'] == 'TENNIS']
# Adjust odds and line
kambi_raw_tennis['line'] = kambi_raw_tennis['line'] / 1000
kambi_raw_tennis['odds'] = kambi_raw_tennis['odds'] / 1000
# Out:
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3866311931.py:2: DtypeWarning: Columns (23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   kambi_raw = pd.read_csv('Data/scrapers/unibet/unibetAllSports2025-01-21T16:02:20Z.csv', index_col=0).drop_duplicates()
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3866311931.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_raw_tennis['line'] = kambi_raw_tennis['line'] / 1000
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3866311931.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_raw_tennis['odds'] = kambi_raw_tennis['odds'] / 1000

# %%
kambi_raw_tennis.to_csv('Data/Testing/unibetTennis2025-01-21T16:02:20Z.csv')
toto_raw_tennis.to_csv('Data/Testing/totoTennis2025-01-21T18:05:01Z.csv')

# %%
# filter down to suitable betting opps
kambi_filtered_tennis = kambi_raw_tennis[kambi_raw_tennis['bet_offer_type_english_name'].isin(['Match', 'Odd/Even', 'Player Occurrence Line', 'Asian Over/Under', 'Over/Under', 'Handicap', 'Asian Handicap', 'Yes/No', 'Head to Head'])]
toto_filtered_tennis = toto_raw_tennis[toto_raw_tennis['Outcome Type'].isin(['--', 'DN', 'OE', 'HH', 'HL', 'AG'])]

kambi_filtered_tennis = kambi_raw_tennis
toto_filtered_tennis = toto_raw_tennis[toto_raw_tennis['Outcome Type'].isin(['DN', 'OE', 'HH', 'HL', 'AG'])]

# Remove duplicates in toto_filtered_football based on specified columns
toto_filtered_tennis = toto_filtered_tennis.drop_duplicates(
    subset=['Event Name', 'Market Name', 'Outcome Name']
)
# Remove duplicates in kambi_filtered_football based on specified columns
kambi_filtered_tennis = kambi_filtered_tennis.drop_duplicates(
    subset=['event_name', 'outcome_label', 'criterion_label']
)

# %%
kambi_raw_tennis['event_name'].unique()
# Out:
# array(['Titouan Droguet vs August Holmgren',
#        'Pierre Herbert-Hugues vs Calvin Hemery',
#        'Mikhail Kukushkin vs Jozef Kovalik',
#        'Terence Atmane vs Gregoire Barrere',
#        'Benoit Paire vs Harold Mayot',
#        'Alibek Kachmazov vs Aleksandar Kovacevic',
#        'Ugo Blanchet vs Seyboth Thiago Wild',
#        'Mattia Bellucci vs Constant Lestienne',
#        'Matteo Martineau vs Jerome Kym',
#        'Adrian Mannarino vs Mackenzie McDonald',
#        'Arthur Gea vs Laslo Djere',
#        'Alexander Blockx vs Alexander Ritschard',
#        'Pedro Araujo vs Jan Choinski',
#        'Marton Fucsovics vs Moro Alejandro Canas',
#        'Nicolas Mejia vs Dominik Koepfer',
#        'Yasutaka Uchiyama vs Christopher Eubanks',
#        'Jaime Faria vs Marc Huesler-Andrea',
#        'Lautaro Midon vs Juan Cerundolo Manuel',
#        'Daniel Galan Elahi vs Maxime Chazal',
#        'Gonzalo Bueno vs Ramos-Albert Viñolas',
#        'Marco Trungelliti vs De Carvalho Cardoso Mateus Alves',
#        'Adolfo Vallejo Daniel vs Emilio Nava',
#        'Aguilar Joaquin Cardozo vs Facundo Mena',
#        'Franco Roncadelli vs Juan Torres Bautista',
#        'Madison Keys vs Elina Svitolina', 'Emma Navarro vs Iga Swiatek',
#        'Aryna Sabalenka vs Paula Badosa', 'Ben Shelton vs Lorenzo Sonego',
#        'Jannik Sinner vs De Alex Minaur',
#        'Novak Djokovic vs Alexander Zverev'], dtype=object)

# %%
# Next to winner and over/under we have Yes/no for e.g. .....Wint een set
toto_raw_tennis['Market Name'].unique()
# Out:
# array(['Wedstrijd', '1e Set - Wedstrijd Resultaat', 'Set - Correct Score',
#        'Aantal Games - Over/Under 20.5', 'Aantal Games - Over/Under 22.5',
#        'Aantal Games - Over/Under 23.5', 'Set 1 Correct Score',
#        'Match Winner and Total Games Over/Under 22.5',
#        'Set 1 Aantal Games - Over/Under 8.5',
#        'Set 1 Aantal Games - Over/Under 9.5',
#        'Set 1 Aantal Games - Over/Under 10.5',
#        'Aantal Games - Over/Under 21.5', 'TOTO Special', 'Price Boost',
#        'Set - Handicap 1.5', 'Set - Handicap -1.5',
#        'Aantal Games - Over/Under 18.5', 'Aantal Games - Over/Under 17.5',
#        'Match Winner and Total Games Over/Under 17.5',
#        'Set 1 Aantal Games - Over/Under 7.5',
#        'Aantal Games - Over/Under 16.5', 'Aantal Games - Over/Under 42.5',
#        'Aantal Games - Over/Under 40.5', 'Aantal Games - Over/Under 41.5',
#        'Set 1 Aantal Games - Over/Under 12.5',
#        'Match Winner and Total Games Over/Under 41.5',
#        'Aantal Games - Over/Under 19.5', 'Aantal Games - Over/Under 34.5',
#        'Aantal Games - Over/Under 35.5',
#        'Match Winner and Total Games Over/Under 35.5',
#        'Aantal Games - Over/Under 36.5',
#        'Match Winner and Total Games Over/Under 20.5',
#        'Match Winner and Total Games Over/Under 40.5',
#        'Aantal Games - Over/Under 39.5', 'Aantal Games - Over/Under 24.5',
#        'Match Winner and Total Games Over/Under 23.5',
#        'Match Winner and Total Games Over/Under 21.5',
#        'Aantal Sets - Over/Under 2.5', '1e Set - Game 3 Correct Score',
#        'Match Winner and Total Games Over/Under 19.5',
#        'Collarini A / Olivo R Wint een Set',
#        'Arias B / Zeballos F Wint een Set', 'Exact Sets',
#        'Cecchinato M / Pellegrino A Wint een Set',
#        'Andreozzi G / Kestelboim M Wint een Set',
#        'Sabanov I / Sabanov M Wint een Set',
#        'Blockx A / Collignon R Wint een Set',
#        'Chidekh C / Paris J Wint een Set',
#        'Bergevi F / Niklas-Salminen P Wint een Set',
#        'Carou I / Dellien H Wint een Set',
#        'Ambrogi L E / Burruchaga R A Wint een Set',
#        'Draxl L / Harper C Wint een Set',
#        'Araujo P / Dodig M Wint een Set',
#        'Jecan M-A / Ricca G Wint een Set',
#        'Cash R / Tracy J Wint een Set',
#        'Denolly C / Jacquet K Wint een Set',
#        'Stevenson D / Willis M Wint een Set',
#        'Doumbia S / Reboul F Wint een Set',
#        'Atmane T / Droguet T Wint een Set',
#        'Pichler D / Sachko V Wint een Set',
#        'Mcdonald M / Vega Hernandez D Wint een Set',
#        'Arneodo R / Guinard M Wint een Set',
#        'Kiger M / Reynolds F Wint een Set',
#        'Albot R / Popko D Wint een Set',
#        'Kirkov V / Stevens B Wint een Set',
#        'Britto L / Roncadelli F Wint een Set',
#        'Galan D E / Taberner C Wint een Set',
#        'Goldhoff G / Hilderbrand T Wint een Set',
#        'Liutarevich I / Veldheer M Wint een Set',
#        'Aguilar Cardozo F / Aguilar Cardozo J Wint een Set',
#        'Heide G / Reis Da Silva J L Wint een Set',
#        'Trhac P / Walkow S Wint een Set',
#        'de Jong J / Moro Canas A Wint een Set',
#        'Middelkoop M / Molchanov D Wint een Set',
#        'Elias G / Pereira T Wint een Set',
#        'Mayot H / Sanchez L Wint een Set',
#        'Matos R / Zormann M Wint een Set',
#        'Arribage T / Cornea V V Wint een Set',
#        'Harrison C / King E Wint een Set',
#        'Aantal Games - Over/Under 33.5',
#        'Match Winner and Total Games Over/Under 34.5',
#        '1e Set - Game 4 Correct Score'], dtype=object)

# %% [markdown]
# ## Winnaar

# %%
## Note Kambi does noy yet scrape doubles

from rapidfuzz import process, fuzz
import pandas as pd

# Filter kambi_filtered_football based on criterion_label
filtered_kambi_winnaar = kambi_filtered_tennis[
    kambi_filtered_tennis['criterion_label'].str.contains('Wedstrijdnotering')
]

# Filter kambi_filtered_football based on criterion_label
filtered_toto_winnaar = toto_filtered_tennis[
    toto_filtered_tennis['Market Name'].str.contains('Wedstrijd')
]

# Preprocess strings: Remove extra whitespace and lowercase
def preprocess(text):
    return ' '.join(text.lower().split())

# %%
import unicodedata

# Replace '-' with a space and remove accents in the 'names' column
filtered_kambi_winnaar['event_name'] = filtered_kambi_winnaar['event_name'].apply(
    lambda x: ''.join(
        char for char in unicodedata.normalize('NFKD', x.replace('-', ' '))
        if not unicodedata.combining(char)
    )
)
# Replace '-' with a space and remove accents in the 'names' column
filtered_toto_winnaar['Event Name'] = filtered_toto_winnaar['Event Name'].apply(
    lambda x: ''.join(
        char for char in unicodedata.normalize('NFKD', x.replace('-', ' '))
        if not unicodedata.combining(char)
    )
)

kambi_events = filtered_kambi_winnaar['event_name'].tolist()

# Function to find the best match for 'Event Name' in toto_filtered_football
def find_best_match(event_name):
    # Use a token-based similarity for better handling of substrings
    result = process.extractOne(event_name, kambi_events, scorer=fuzz.token_set_ratio, score_cutoff=90)
    if result is None:  # No match found
        return None
    match, score, _ = result
    return match

# Apply matching function to toto_filtered_football
filtered_toto_winnaar['matched_event'] = filtered_toto_winnaar['Event Name'].apply(find_best_match)
# Out:
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2316754585.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_kambi_winnaar['event_name'] = filtered_kambi_winnaar['event_name'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2316754585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_toto_winnaar['Event Name'] = filtered_toto_winnaar['Event Name'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2316754585.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_toto_winnaar['matched_event'] = filtered_toto_winnaar['Event Name'].apply(find_best_match)

# %%
# Merge the DataFrames using the standardized column
merged_df_winnaar = pd.merge(
    filtered_toto_winnaar,
    filtered_kambi_winnaar,
    left_on=['matched_event'], 
    right_on=['event_name'], 
    how='inner'  # Perform an inner join
)

merged_df_winnaar = merged_df_winnaar[(merged_df_winnaar['matched_event'].notnull())&(merged_df_winnaar['Outcome SubType'] != merged_df_winnaar['type'])]

# %%
merged_df_winnaar
# Out:
#     event_id_x                                         Event Name Market Name  \
# 0      6626321                    Madison Keys vs Elina Svitolina   Wedstrijd
# 3      6626321                    Madison Keys vs Elina Svitolina   Wedstrijd
# 5      6628498                        Emma Navarro vs Iga Swiatek   Wedstrijd
# 6      6628498                        Emma Navarro vs Iga Swiatek   Wedstrijd
# 8      6628331                      Ben Shelton vs Lorenzo Sonego   Wedstrijd
# 11     6628331                      Ben Shelton vs Lorenzo Sonego   Wedstrijd
# 12     6629125                    Jannik Sinner vs Alex De Minaur   Wedstrijd
# 15     6629125                    Jannik Sinner vs Alex De Minaur   Wedstrijd
# 17     6637925                    Aryna Sabalenka vs Paula Badosa   Wedstrijd
# 18     6637925                    Aryna Sabalenka vs Paula Badosa   Wedstrijd
# 21     6639834                 Novak Djokovic vs Alexander Zverev   Wedstrijd
# 22     6639834                 Novak Djokovic vs Alexander Zverev   Wedstrijd
# 24     6622178                       Benoit Paire vs Harold Mayot   Wedstrijd
# 27     6622178                       Benoit Paire vs Harold Mayot   Wedstrijd
# 29     6622174           Alibek Kachmazov vs Aleksandar Kovacevic   Wedstrijd
# 30     6622174           Alibek Kachmazov vs Aleksandar Kovacevic   Wedstrijd
# 32     6622176              Mattia Bellucci vs Constant Lestienne   Wedstrijd
# 35     6622176              Mattia Bellucci vs Constant Lestienne   Wedstrijd
# 36     6622175                     Matteo Martineau vs Jerome Kym   Wedstrijd
# 39     6622175                     Matteo Martineau vs Jerome Kym   Wedstrijd
# 40     6622177                          Arthur Gea vs Laslo Djere   Wedstrijd
# 43     6622177                          Arthur Gea vs Laslo Djere   Wedstrijd
# 45     6622179             Adrian Mannarino vs Mackenzie Mcdonald   Wedstrijd
# 46     6622179             Adrian Mannarino vs Mackenzie Mcdonald   Wedstrijd
# 49     6622171                Ugo Blanchet vs Thiago Seyboth Wild   Wedstrijd
# 50     6622171                Ugo Blanchet vs Thiago Seyboth Wild   Wedstrijd
# 53     6634196                Daniel Elahi Galan vs Maxime Chazal   Wedstrijd
# 54     6634196                Daniel Elahi Galan vs Maxime Chazal   Wedstrijd
# 57     6622485           Yasutaka Uchiyama vs Christopher Eubanks   Wedstrijd
# 58     6622485           Yasutaka Uchiyama vs Christopher Eubanks   Wedstrijd
# 60     6614476               Adolfo Daniel Vallejo vs Emilio Nava   Wedstrijd
# 63     6614476               Adolfo Daniel Vallejo vs Emilio Nava   Wedstrijd
# 65     6634194  Marco Trungelliti vs Mateus De Carvalho Cardos...   Wedstrijd
# 66     6634194  Marco Trungelliti vs Mateus De Carvalho Cardos...   Wedstrijd
# 69     6614480            Joaquin Aguilar Cardozo vs Facundo Mena   Wedstrijd
# 70     6614480            Joaquin Aguilar Cardozo vs Facundo Mena   Wedstrijd
# 72     6634199          Franco Roncadelli vs Juan Bautista Torres   Wedstrijd
# 75     6634199          Franco Roncadelli vs Juan Bautista Torres   Wedstrijd
# 77     6622480                 Jaime Faria vs Marc Andrea Huesler   Wedstrijd
# 78     6622480                 Jaime Faria vs Marc Andrea Huesler   Wedstrijd
#
#                         Outcome Name  Odds (Decimal)  Price Numerator  \
# 0                    Elina Svitolina            2.65             33.0
# 3                       Madison Keys            1.51             51.0
# 5                       Emma Navarro           10.00              9.0
# 6                        Iga Swiatek            1.06              3.0
# 8                     Lorenzo Sonego            3.20             11.0
# 11                       Ben Shelton            1.38             19.0
# 12                    Alex De Minaur            5.25             17.0
# 15                     Jannik Sinner            1.18              9.0
# 17                   Aryna Sabalenka            1.24              6.0
# 18                      Paula Badosa            4.25             13.0
# 21                    Novak Djokovic            1.63             63.0
# 22                  Alexander Zverev            2.34             67.0
# 24                      Harold Mayot            1.18              9.0
# 27                      Benoit Paire            4.75             15.0
# 29                  Alibek Kachmazov            2.34             67.0
# 30              Aleksandar Kovacevic            1.58             29.0
# 32                Constant Lestienne            2.39            139.0
# 35                   Mattia Bellucci            1.56             14.0
# 36                        Jerome Kym            1.33             33.0
# 39                  Matteo Martineau            3.25              9.0
# 40                       Laslo Djere            1.67             67.0
# 43                        Arthur Gea            2.17            117.0
# 45                  Adrian Mannarino            2.39            139.0
# 46                Mackenzie Mcdonald            1.56             14.0
# 49                      Ugo Blanchet            2.90             19.0
# 50               Thiago Seyboth Wild            1.40              2.0
# 53                Daniel Elahi Galan            1.25              1.0
# 54                     Maxime Chazal            3.80             14.0
# 57                 Yasutaka Uchiyama            2.55             31.0
# 58               Christopher Eubanks            1.50              1.0
# 60                       Emilio Nava            1.75              3.0
# 63             Adolfo Daniel Vallejo            2.05             21.0
# 65                 Marco Trungelliti            1.71             71.0
# 66  Mateus De Carvalho Cardoso Alves            2.10             11.0
# 69           Joaquin Aguilar Cardozo            4.00              3.0
# 70                      Facundo Mena            1.23             23.0
# 72              Juan Bautista Torres            1.36              9.0
# 75                 Franco Roncadelli            3.05             41.0
# 77                       Jaime Faria            2.47            147.0
# 78               Marc-Andrea Huesler            1.53             53.0
#
#     Price Denominator Outcome Type Outcome SubType sport_x  \
# 0                20.0           HH               2  Tennis
# 3               100.0           HH               1  Tennis
# 5                 1.0           HH               1  Tennis
# 6                50.0           HH               2  Tennis
# 8                 5.0           HH               2  Tennis
# 11               50.0           HH               1  Tennis
# 12                4.0           HH               2  Tennis
# 15               50.0           HH               1  Tennis
# 17               25.0           HH               1  Tennis
# 18                4.0           HH               2  Tennis
# 21              100.0           HH               1  Tennis
# 22               50.0           HH               2  Tennis
# 24               50.0           HH               2  Tennis
# 27                4.0           HH               1  Tennis
# 29               50.0           HH               1  Tennis
# 30               50.0           HH               2  Tennis
# 32              100.0           HH               2  Tennis
# 35               25.0           HH               1  Tennis
# 36              100.0           HH               2  Tennis
# 39                4.0           HH               1  Tennis
# 40              100.0           HH               2  Tennis
# 43              100.0           HH               1  Tennis
# 45              100.0           HH               1  Tennis
# 46               25.0           HH               2  Tennis
# 49               10.0           HH               1  Tennis
# 50                5.0           HH               2  Tennis
# 53                4.0           HH               1  Tennis
# 54                5.0           HH               2  Tennis
# 57               20.0           HH               1  Tennis
# 58                2.0           HH               2  Tennis
# 60                4.0           HH               2  Tennis
# 63               20.0           HH               1  Tennis
# 65              100.0           HH               1  Tennis
# 66               10.0           HH               2  Tennis
# 69                1.0           HH               1  Tennis
# 70              100.0           HH               2  Tennis
# 72               25.0           HH               2  Tennis
# 75               20.0           HH               1  Tennis
# 77              100.0           HH               1  Tennis
# 78              100.0           HH               2  Tennis
#
#                             competition  \
# 0        WTA Australian Open, Enkelspel
# 3        WTA Australian Open, Enkelspel
# 5        WTA Australian Open, Enkelspel
# 6        WTA Australian Open, Enkelspel
# 8        ATP Australian Open, Enkelspel
# 11       ATP Australian Open, Enkelspel
# 12       ATP Australian Open, Enkelspel
# 15       ATP Australian Open, Enkelspel
# 17       WTA Australian Open, Enkelspel
# 18       WTA Australian Open, Enkelspel
# 21       ATP Australian Open, Enkelspel
# 22       ATP Australian Open, Enkelspel
# 24  ATP Challenger Quimper I, Enkelspel
# 27  ATP Challenger Quimper I, Enkelspel
# 29  ATP Challenger Quimper I, Enkelspel
# 30  ATP Challenger Quimper I, Enkelspel
# 32  ATP Challenger Quimper I, Enkelspel
# 35  ATP Challenger Quimper I, Enkelspel
# 36  ATP Challenger Quimper I, Enkelspel
# 39  ATP Challenger Quimper I, Enkelspel
# 40  ATP Challenger Quimper I, Enkelspel
# 43  ATP Challenger Quimper I, Enkelspel
# 45  ATP Challenger Quimper I, Enkelspel
# 46  ATP Challenger Quimper I, Enkelspel
# 49  ATP Challenger Quimper I, Enkelspel
# 50  ATP Challenger Quimper I, Enkelspel
# 53      ATP Challenger Punta, Enkelspel
# 54      ATP Challenger Punta, Enkelspel
# 57   ATP Challenger Oeiras 3, Enkelspel
# 58   ATP Challenger Oeiras 3, Enkelspel
# 60      ATP Challenger Punta, Enkelspel
# 63      ATP Challenger Punta, Enkelspel
# 65      ATP Challenger Punta, Enkelspel
# 66      ATP Challenger Punta, Enkelspel
# 69      ATP Challenger Punta, Enkelspel
# 70      ATP Challenger Punta, Enkelspel
# 72      ATP Challenger Punta, Enkelspel
# 75      ATP Challenger Punta, Enkelspel
# 77   ATP Challenger Oeiras 3, Enkelspel
# 78   ATP Challenger Oeiras 3, Enkelspel
#
#                                         matched_event  bet_offer_id  \
# 0                     Madison Keys vs Elina Svitolina    2487363274
# 3                     Madison Keys vs Elina Svitolina    2487363274
# 5                         Emma Navarro vs Iga Swiatek    2487377595
# 6                         Emma Navarro vs Iga Swiatek    2487377595
# 8                       Ben Shelton vs Lorenzo Sonego    2487376809
# 11                      Ben Shelton vs Lorenzo Sonego    2487376809
# 12                    Jannik Sinner vs De Alex Minaur    2487406209
# 15                    Jannik Sinner vs De Alex Minaur    2487406209
# 17                    Aryna Sabalenka vs Paula Badosa    2487591123
# 18                    Aryna Sabalenka vs Paula Badosa    2487591123
# 21                 Novak Djokovic vs Alexander Zverev    2487636588
# 22                 Novak Djokovic vs Alexander Zverev    2487636588
# 75  1.35   NaN         NaN    2  2025-01-21T12:57:04Z            7/20
# 77  1.48   NaN         NaN    2  2025-01-20T23:07:34Z           12/25
# 78  2.55   NaN         NaN    1  2025-01-20T23:07:34Z           31/20
#
#     odds_american status cash_out_status home_score away_score  \
# 0          -200.0   OPEN         ENABLED        NaN        NaN
# 3           170.0   OPEN         ENABLED        NaN        NaN
# 5         -1430.0   OPEN         ENABLED        NaN        NaN
# 6           850.0   OPEN         ENABLED        NaN        NaN
# 8          -305.0   OPEN         ENABLED        NaN        NaN
# 11          245.0   OPEN         ENABLED        NaN        NaN
# 12         -530.0   OPEN         ENABLED        NaN        NaN
# 15          410.0   OPEN         ENABLED        NaN        NaN
# 17          300.0   OPEN         ENABLED        NaN        NaN
# 18         -385.0   OPEN         ENABLED        NaN        NaN
# 21          125.0   OPEN         ENABLED        NaN        NaN
# 22         -150.0   OPEN         ENABLED        NaN        NaN
# 24          360.0   OPEN         ENABLED        NaN        NaN
# 27         -530.0   OPEN         ENABLED        NaN        NaN
# 29         -182.0   OPEN         ENABLED        NaN        NaN
# 30          140.0   OPEN         ENABLED        NaN        NaN
# 32         -177.0   OPEN         ENABLED        NaN        NaN
# 35          135.0   OPEN         ENABLED        NaN        NaN
# 36          235.0   OPEN         ENABLED        NaN        NaN
# 39         -335.0   OPEN         ENABLED        NaN        NaN
# 40          110.0   OPEN         ENABLED        NaN        NaN
# 43         -139.0   OPEN         ENABLED        NaN        NaN
# 45         -177.0   OPEN         ENABLED        NaN        NaN
# 46          135.0   OPEN         ENABLED        NaN        NaN
# 49         -275.0   OPEN         ENABLED        NaN        NaN
# 50          200.0   OPEN         ENABLED        NaN        NaN
# 53          240.0   OPEN         ENABLED        NaN        NaN
# 54         -335.0   OPEN         ENABLED        NaN        NaN
# 57         -225.0   OPEN         ENABLED        NaN        NaN
# 58          165.0   OPEN         ENABLED        NaN        NaN
# 60          105.0   OPEN         ENABLED        NaN        NaN
# 63         -134.0   OPEN         ENABLED        NaN        NaN
# 65          105.0   OPEN         ENABLED        NaN        NaN
# 66         -127.0   OPEN         ENABLED        NaN        NaN
# 69         -500.0   OPEN         ENABLED        NaN        NaN
# 70          330.0   OPEN         ENABLED        NaN        NaN
# 72          210.0   OPEN         ENABLED        NaN        NaN
# 75         -286.0   OPEN         ENABLED        NaN        NaN
# 77         -210.0   OPEN         ENABLED        NaN        NaN
# 78          155.0   OPEN         ENABLED        NaN        NaN
#
#                                            event_name sport_y      group_name
# 0                     Madison Keys vs Elina Svitolina  TENNIS             NaN
# 3                     Madison Keys vs Elina Svitolina  TENNIS             NaN
# 5                         Emma Navarro vs Iga Swiatek  TENNIS             NaN
# 6                         Emma Navarro vs Iga Swiatek  TENNIS             NaN
# 8                       Ben Shelton vs Lorenzo Sonego  TENNIS             NaN
# 11                      Ben Shelton vs Lorenzo Sonego  TENNIS             NaN
# 12                    Jannik Sinner vs De Alex Minaur  TENNIS             NaN
# 15                    Jannik Sinner vs De Alex Minaur  TENNIS             NaN
# 17                    Aryna Sabalenka vs Paula Badosa  TENNIS             NaN
# 18                    Aryna Sabalenka vs Paula Badosa  TENNIS             NaN
# 21                 Novak Djokovic vs Alexander Zverev  TENNIS             NaN
# 22                 Novak Djokovic vs Alexander Zverev  TENNIS             NaN
# 24                       Benoit Paire vs Harold Mayot  TENNIS         Quimper
# 27                       Benoit Paire vs Harold Mayot  TENNIS         Quimper
# 29           Alibek Kachmazov vs Aleksandar Kovacevic  TENNIS         Quimper
# 30           Alibek Kachmazov vs Aleksandar Kovacevic  TENNIS         Quimper
# 32              Mattia Bellucci vs Constant Lestienne  TENNIS         Quimper
# 35              Mattia Bellucci vs Constant Lestienne  TENNIS         Quimper
# 36                     Matteo Martineau vs Jerome Kym  TENNIS         Quimper
# 39                     Matteo Martineau vs Jerome Kym  TENNIS         Quimper
# 40                          Arthur Gea vs Laslo Djere  TENNIS         Quimper
# 43                          Arthur Gea vs Laslo Djere  TENNIS         Quimper
# 45             Adrian Mannarino vs Mackenzie McDonald  TENNIS         Quimper
# 46             Adrian Mannarino vs Mackenzie McDonald  TENNIS         Quimper
# 49                Ugo Blanchet vs Seyboth Thiago Wild  TENNIS         Quimper
# 50                Ugo Blanchet vs Seyboth Thiago Wild  TENNIS         Quimper
# 53                Daniel Galan Elahi vs Maxime Chazal  TENNIS  Punta del Este
# 54                Daniel Galan Elahi vs Maxime Chazal  TENNIS  Punta del Este
# 57           Yasutaka Uchiyama vs Christopher Eubanks  TENNIS          Oeiras
# 58           Yasutaka Uchiyama vs Christopher Eubanks  TENNIS          Oeiras
# 60               Adolfo Vallejo Daniel vs Emilio Nava  TENNIS  Punta del Este
# 63               Adolfo Vallejo Daniel vs Emilio Nava  TENNIS  Punta del Este
# 65  Marco Trungelliti vs De Carvalho Cardoso Mateu...  TENNIS  Punta del Este
# 66  Marco Trungelliti vs De Carvalho Cardoso Mateu...  TENNIS  Punta del Este
# 69            Aguilar Joaquin Cardozo vs Facundo Mena  TENNIS  Punta del Este
# 70            Aguilar Joaquin Cardozo vs Facundo Mena  TENNIS  Punta del Este
# 72          Franco Roncadelli vs Juan Torres Bautista  TENNIS  Punta del Este
# 75          Franco Roncadelli vs Juan Torres Bautista  TENNIS  Punta del Este
# 77                 Jaime Faria vs Marc Huesler Andrea  TENNIS          Oeiras
# 78                 Jaime Faria vs Marc Huesler Andrea  TENNIS          Oeiras

# %% [markdown]
# ## Over/Under

# %%
kambi_filtered_tennis_overunder = kambi_filtered_tennis[kambi_filtered_tennis['bet_offer_type_name'].str.contains('Over')]
toto_filtered_tennis_overunder = toto_filtered_tennis[(toto_filtered_tennis['Outcome Name'].str.contains('Over')) | (toto_filtered_tennis['Outcome Name'].str.contains('Under'))]

# %%
import unicodedata

# Replace '-' with a space and remove accents in the 'names' column
kambi_filtered_tennis_overunder['event_name'] = kambi_filtered_tennis_overunder['event_name'].apply(
    lambda x: ''.join(
        char for char in unicodedata.normalize('NFKD', x.replace('-', ' '))
        if not unicodedata.combining(char)
    )
)

# Replace '-' with a space and remove accents in the 'names' column
kambi_filtered_tennis_overunder['criterion_label'] = kambi_filtered_tennis_overunder['criterion_label'].apply(
    lambda x: ''.join(
        char for char in unicodedata.normalize('NFKD', x.replace('-', ' '))
        if not unicodedata.combining(char)
    )
)

# Replace '-' with a space and remove accents in the 'names' column
kambi_filtered_tennis_overunder['criterion_english_label'] = kambi_filtered_tennis_overunder['criterion_english_label'].apply(
    lambda x: ''.join(
        char for char in unicodedata.normalize('NFKD', x.replace('-', ' '))
        if not unicodedata.combining(char)
    )
)

# Replace '-' with a space and remove accents in the 'names' column
toto_filtered_tennis_overunder['Event Name'] = toto_filtered_tennis_overunder['Event Name'].apply(
    lambda x: ''.join(
        char for char in unicodedata.normalize('NFKD', x.replace('-', ' '))
        if not unicodedata.combining(char)
    )
)

# Replace '-' with a space and remove accents in the 'names' column
toto_filtered_tennis_overunder['Market Name'] = toto_filtered_tennis_overunder['Market Name'].apply(
    lambda x: ''.join(
        char for char in unicodedata.normalize('NFKD', x.replace('-', ' '))
        if not unicodedata.combining(char)
    )
)

kambi_events = kambi_filtered_tennis_overunder['event_name'].tolist()

# Function to find the best match for 'Event Name' in toto_filtered_football
def find_best_match(event_name):
    # Use a token-based similarity for better handling of substrings
    result = process.extractOne(event_name, kambi_events, scorer=fuzz.token_set_ratio, score_cutoff=90)
    if result is None:  # No match found
        return None
    match, score, _ = result
    return match

# Apply matching function to toto_filtered_football
toto_filtered_tennis_overunder['matched_event'] = toto_filtered_tennis_overunder['Event Name'].apply(find_best_match)
# Out:
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3351848315.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_overunder['event_name'] = kambi_filtered_tennis_overunder['event_name'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3351848315.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_overunder['criterion_label'] = kambi_filtered_tennis_overunder['criterion_label'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3351848315.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_overunder['criterion_english_label'] = kambi_filtered_tennis_overunder['criterion_english_label'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3351848315.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_overunder['Event Name'] = toto_filtered_tennis_overunder['Event Name'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3351848315.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_overunder['Market Name'] = toto_filtered_tennis_overunder['Market Name'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3351848315.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_overunder['matched_event'] = toto_filtered_tennis_overunder['Event Name'].apply(find_best_match)

# %%
# Create 'OverUnderType'
kambi_filtered_tennis_overunder['OverUnderType'] = kambi_filtered_tennis_overunder['criterion_label'].apply(
    lambda x: 'Sets' if 'Sets' in x and 'Games' not in x 
    else 'Games in Set' if 'Games' in x and 'Set' in x 
    else 'Games' if 'Games' in x 
    else 'Points' if 'Punten' in x 
    else None  # Default case if none of the conditions match
)

# Create 'OverUnderTime'
def determine_over_under_time(label):
    if 'set 1' in label.lower():
        return 'Set 1'
    elif 'set 2' in label.lower():
        return 'Set 2'
    elif 'set 3' in label.lower():
        return 'Set 3'
    elif 'set 4' in label.lower():
        return 'Set 4'
    elif 'set 5' in label.lower():
        return 'Set 5'
    else:
        return 'Full Time'

kambi_filtered_tennis_overunder['OverUnderTime'] = kambi_filtered_tennis_overunder['criterion_label'].apply(determine_over_under_time)

# Create 'Team1' and 'Team2'
kambi_filtered_tennis_overunder[['Team1', 'Team2']] = kambi_filtered_tennis_overunder['event_name'].str.split(' vs ', expand=True)

# Create 'OverUnderType2'
kambi_filtered_tennis_overunder['OverUnderType2'] = kambi_filtered_tennis_overunder.apply(
    lambda row: '1' if row['Team1'] in row['criterion_english_label'] else (
        '2' if row['Team2'] in row['criterion_english_label'] else 'Total team 1 and team 2'
    ),
    axis=1
)
# Out:
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3145040859.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_overunder['OverUnderType'] = kambi_filtered_tennis_overunder['criterion_label'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3145040859.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_overunder['OverUnderTime'] = kambi_filtered_tennis_overunder['criterion_label'].apply(determine_over_under_time)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3145040859.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_overunder[['Team1', 'Team2']] = kambi_filtered_tennis_overunder['event_name'].str.split(' vs ', expand=True)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3145040859.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_overunder[['Team1', 'Team2']] = kambi_filtered_tennis_overunder['event_name'].str.split(' vs ', expand=True)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/3145040859.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_overunder['OverUnderType2'] = kambi_filtered_tennis_overunder.apply(

# %%
# Create 'OverUnderType'
toto_filtered_tennis_overunder['OverUnderType'] = toto_filtered_tennis_overunder['Market Name'].apply(
    lambda x: 'Sets' if 'Sets' in x and 'Games' not in x 
    else 'Games in Set' if 'Games' in x and 'Set' in x 
    else 'Games' if 'Games' in x 
    else 'Points' if 'Punten' in x 
    else None  # Default case if none of the conditions match
)

# Create 'OverUnderTime'
toto_filtered_tennis_overunder['OverUnderTime'] = toto_filtered_tennis_overunder['Market Name'].apply(determine_over_under_time)

# Create 'Team1' and 'Team2'
toto_filtered_tennis_overunder[['Team1', 'Team2']] = toto_filtered_tennis_overunder['Event Name'].str.split(' vs ', expand=True)

# Create 'OverUnderType2'
toto_filtered_tennis_overunder['OverUnderType2'] = toto_filtered_tennis_overunder.apply(
    lambda row: '1' if row['Team1'] in row['Market Name'] else (
        '2' if row['Team2'] in row['Market Name'] else 'Total team 1 and team 2'
    ),
    axis=1
)

# Create 'line'
toto_filtered_tennis_overunder['line'] = toto_filtered_tennis_overunder['Market Name'].apply(
    lambda x: float(x.split('Over/Under ')[-1]) if 'Over/Under ' in x else None
)
# Out:
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2880689030.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_overunder['OverUnderType'] = toto_filtered_tennis_overunder['Market Name'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2880689030.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_overunder['OverUnderTime'] = toto_filtered_tennis_overunder['Market Name'].apply(determine_over_under_time)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2880689030.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_overunder[['Team1', 'Team2']] = toto_filtered_tennis_overunder['Event Name'].str.split(' vs ', expand=True)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2880689030.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_overunder[['Team1', 'Team2']] = toto_filtered_tennis_overunder['Event Name'].str.split(' vs ', expand=True)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2880689030.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_overunder['OverUnderType2'] = toto_filtered_tennis_overunder.apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2880689030.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_overunder['line'] = toto_filtered_tennis_overunder['Market Name'].apply(

# %%
# Perform the merge
merged_tennis_overunder = pd.merge(
    toto_filtered_tennis_overunder,
    kambi_filtered_tennis_overunder,
    left_on=['line', 'OverUnderType', 'OverUnderTime', 'OverUnderType2', 'matched_event'],
    right_on=['line', 'OverUnderType', 'OverUnderTime', 'OverUnderType2', 'event_name'],
    how='inner'  # Use 'inner' join to get only matching rows; adjust as needed
)
# Keep records with opposite outcomes
merged_tennis_overunder = merged_tennis_overunder[merged_tennis_overunder['outcome_english_label'] != merged_tennis_overunder['Outcome Name']]

# Display the merged DataFrame
merged_tennis_overunder.head()
# Out:
#    event_id_x                       Event Name  \
# 1     6626321  Madison Keys vs Elina Svitolina
# 2     6626321  Madison Keys vs Elina Svitolina
# 4     6626321  Madison Keys vs Elina Svitolina
# 7     6626321  Madison Keys vs Elina Svitolina
# 9     6628498      Emma Navarro vs Iga Swiatek
#
#                            Market Name Outcome Name  Odds (Decimal)  \
# 1       Aantal Games   Over/Under 22.5         Over            2.02
# 2       Aantal Games   Over/Under 22.5        Under            1.77
# 4  Set 1 Aantal Games   Over/Under 9.5        Under            1.90
# 7  Set 1 Aantal Games   Over/Under 9.5         Over            1.88
# 9  Set 1 Aantal Games   Over/Under 8.5         Over            1.79
#
#    Price Numerator  Price Denominator Outcome Type Outcome SubType sport_x  \
# 1             51.0               50.0           HL               1  Tennis
# 2             77.0              100.0           HL               L  Tennis
# 4              9.0               10.0           HL               L  Tennis
# 7             22.0               25.0           HL               1  Tennis
# 9             79.0              100.0           HL               1  Tennis
#
#                       competition                    matched_event  \
# 1  WTA Australian Open, Enkelspel  Madison Keys vs Elina Svitolina
# 2  WTA Australian Open, Enkelspel  Madison Keys vs Elina Svitolina
# 4  WTA Australian Open, Enkelspel  Madison Keys vs Elina Svitolina
# 7  WTA Australian Open, Enkelspel  Madison Keys vs Elina Svitolina
# 9  WTA Australian Open, Enkelspel      Emma Navarro vs Iga Swiatek
#
#   OverUnderType OverUnderTime       Team1_x          Team2_x  \
# 1         Games     Full Time  Madison Keys  Elina Svitolina
# 2         Games     Full Time  Madison Keys  Elina Svitolina
# 4  Games in Set         Set 1  Madison Keys  Elina Svitolina
# 7  Games in Set         Set 1  Madison Keys  Elina Svitolina
# 9  Games in Set         Set 1  Emma Navarro      Iga Swiatek
#
#             OverUnderType2  line  bet_offer_id  criterion_id  \
# 1  Total team 1 and team 2  22.5    2487363282    1001159891
# 2  Total team 1 and team 2  22.5    2487363282    1001159891
# 4  Total team 1 and team 2   9.5    2487363279    1001159979
# 7  Total team 1 and team 2   9.5    2487363279    1001159979
# 9  Total team 1 and team 2   8.5    2487385531    1001159979
#
#                criterion_label criterion_english_label occurrence_type  \
# 1          Totaal Aantal Games             Total Games             NaN
# 2          Totaal Aantal Games             Total Games             NaN
# 4  Totaal Aantal Games   Set 1     Total Games   Set 1             NaN
# 7  Totaal Aantal Games   Set 1     Total Games   Set 1             NaN
# 9  Totaal Aantal Games   Set 1     Total Games   Set 1             NaN
#
#   lifetime  bet_offer_type_id bet_offer_type_name bet_offer_type_english_name  \
# 1      NaN                  6          Over/Onder                  Over/Under
# 2      NaN                  6          Over/Onder                  Over/Under
# 4      NaN                  6          Over/Onder                  Over/Under
# 7      NaN                  6          Over/Onder                  Over/Under
# 9      NaN                  6          Over/Onder                  Over/Under
#
#    event_id_y  outcome_id outcome_label outcome_english_label  odds  \
# 1  1022624618  3619085076    Minder dan                 Under  1.79
# 2  1022624618  3619085075      Meer dan                  Over  2.06
# 4  1022624618  3619085070      Meer dan                  Over  1.88
# 7  1022624618  3619085072    Minder dan                 Under  1.96
# 9  1022625921  3619143763    Minder dan                 Under  2.07
#
#   participant      type          changed_date odds_fractional  odds_american  \
# 1         NaN  OT_UNDER  2025-01-21T10:46:55Z           10/13         -127.0
# 2         NaN   OT_OVER  2025-01-21T10:46:55Z           21/20          106.0
# 4         NaN   OT_OVER  2025-01-21T10:46:55Z           22/25         -114.0
# 7         NaN  OT_UNDER  2025-01-21T10:46:55Z           19/20         -105.0
# 9         NaN  OT_UNDER  2025-01-21T11:00:26Z           21/20          107.0
#
#   status cash_out_status home_score away_score  \
# 1   OPEN         ENABLED        NaN        NaN
# 2   OPEN         ENABLED        NaN        NaN
# 4   OPEN         ENABLED        NaN        NaN
# 7   OPEN         ENABLED        NaN        NaN
# 9   OPEN         ENABLED        NaN        NaN
#
#                         event_name sport_y group_name       Team1_y  \
# 1  Madison Keys vs Elina Svitolina  TENNIS        NaN  Madison Keys
# 2  Madison Keys vs Elina Svitolina  TENNIS        NaN  Madison Keys
# 4  Madison Keys vs Elina Svitolina  TENNIS        NaN  Madison Keys
# 7  Madison Keys vs Elina Svitolina  TENNIS        NaN  Madison Keys
# 9      Emma Navarro vs Iga Swiatek  TENNIS        NaN  Emma Navarro
#
#            Team2_y
# 1  Elina Svitolina
# 2  Elina Svitolina
# 4  Elina Svitolina
# 7  Elina Svitolina
# 9      Iga Swiatek

# %%
len(merged_tennis_overunder)
# Out:
# 20

# %% [markdown]
# ## Yes/ No

# %%
kambi_filtered_tennis_yesno = kambi_filtered_tennis[kambi_filtered_tennis['bet_offer_type_name'].str.contains('Ja/Nee')]
toto_filtered_tennis_yesno = toto_filtered_tennis[(toto_filtered_tennis['Outcome Name'].str.contains('Ja')) | (toto_filtered_tennis['Outcome Name'].str.contains('Nee'))]

# %%
import unicodedata

# Replace '-' with a space and remove accents in the 'names' column
kambi_filtered_tennis_yesno['event_name'] = kambi_filtered_tennis_yesno['event_name'].apply(
    lambda x: ''.join(
        char for char in unicodedata.normalize('NFKD', x.replace('-', ' '))
        if not unicodedata.combining(char)
    )
)

# Replace '-' with a space and remove accents in the 'names' column
kambi_filtered_tennis_yesno['criterion_label'] = kambi_filtered_tennis_yesno['criterion_label'].apply(
    lambda x: ''.join(
        char for char in unicodedata.normalize('NFKD', x.replace('-', ' '))
        if not unicodedata.combining(char)
    )
)

# Replace '-' with a space and remove accents in the 'names' column
kambi_filtered_tennis_yesno['criterion_english_label'] = kambi_filtered_tennis_yesno['criterion_english_label'].apply(
    lambda x: ''.join(
        char for char in unicodedata.normalize('NFKD', x.replace('-', ' '))
        if not unicodedata.combining(char)
    )
)

# Replace '-' with a space and remove accents in the 'names' column
toto_filtered_tennis_yesno['Event Name'] = toto_filtered_tennis_yesno['Event Name'].apply(
    lambda x: ''.join(
        char for char in unicodedata.normalize('NFKD', x.replace('-', ' '))
        if not unicodedata.combining(char)
    )
)

# Replace '-' with a space and remove accents in the 'names' column
toto_filtered_tennis_yesno['Market Name'] = toto_filtered_tennis_yesno['Market Name'].apply(
    lambda x: ''.join(
        char for char in unicodedata.normalize('NFKD', x.replace('-', ' '))
        if not unicodedata.combining(char)
    )
)

kambi_events = kambi_filtered_tennis_yesno['event_name'].tolist()

# Function to find the best match for 'Event Name' in toto_filtered_football
def find_best_match(event_name):
    # Use a token-based similarity for better handling of substrings
    result = process.extractOne(event_name, kambi_events, scorer=fuzz.token_set_ratio, score_cutoff=90)
    if result is None:  # No match found
        return None
    match, score, _ = result
    return match

# Apply matching function to toto_filtered_football
toto_filtered_tennis_yesno['matched_event'] = toto_filtered_tennis_yesno['Event Name'].apply(find_best_match)
# Out:
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/4236750431.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_yesno['event_name'] = kambi_filtered_tennis_yesno['event_name'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/4236750431.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_yesno['criterion_label'] = kambi_filtered_tennis_yesno['criterion_label'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/4236750431.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_yesno['criterion_english_label'] = kambi_filtered_tennis_yesno['criterion_english_label'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/4236750431.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_yesno['Event Name'] = toto_filtered_tennis_yesno['Event Name'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/4236750431.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_yesno['Market Name'] = toto_filtered_tennis_yesno['Market Name'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/4236750431.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_yesno['matched_event'] = toto_filtered_tennis_yesno['Event Name'].apply(find_best_match)

# %%
# Create 'OverUnderType'
kambi_filtered_tennis_yesno['YesNoType'] = kambi_filtered_tennis_yesno['criterion_label'].apply(
    lambda x: 'Set winst' if 'Wint een Set' in x
    else None  # Default case if none of the conditions match
)

# Create 'OverUnderTime'
def determine_over_under_time(label):
    if 'set 1' in label.lower():
        return 'Set 1'
    elif 'set 2' in label.lower():
        return 'Set 2'
    elif 'set 3' in label.lower():
        return 'Set 3'
    elif 'set 4' in label.lower():
        return 'Set 4'
    elif 'set 5' in label.lower():
        return 'Set 5'
    else:
        return 'Full Time'

kambi_filtered_tennis_yesno['OverUnderTime'] = kambi_filtered_tennis_yesno['criterion_label'].apply(determine_over_under_time)

# Create 'Team1' and 'Team2'
kambi_filtered_tennis_yesno[['Team1', 'Team2']] = kambi_filtered_tennis_yesno['event_name'].str.split(' vs ', expand=True)

# Create 'OverUnderType2'
kambi_filtered_tennis_yesno['YesNoType2'] = kambi_filtered_tennis_yesno.apply(
    lambda row: '1' if row['Team1'] in row['criterion_english_label'] else (
        '2' if row['Team2'] in row['criterion_english_label'] else 'Total team 1 and team 2'
    ),
    axis=1
)
# Out:
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2757714873.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_yesno['YesNoType'] = kambi_filtered_tennis_yesno['criterion_label'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2757714873.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_yesno['OverUnderTime'] = kambi_filtered_tennis_yesno['criterion_label'].apply(determine_over_under_time)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2757714873.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_yesno[['Team1', 'Team2']] = kambi_filtered_tennis_yesno['event_name'].str.split(' vs ', expand=True)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2757714873.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_yesno[['Team1', 'Team2']] = kambi_filtered_tennis_yesno['event_name'].str.split(' vs ', expand=True)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2757714873.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_tennis_yesno['YesNoType2'] = kambi_filtered_tennis_yesno.apply(

# %%
# Create 'OverUnderType'
toto_filtered_tennis_yesno['YesNoType'] = toto_filtered_tennis_yesno['Market Name'].apply(
    lambda x: 'Set winst' if 'Wint een Set' in x
    else None  # Default case if none of the conditions match
)

# Create 'OverUnderTime'
toto_filtered_tennis_yesno['OverUnderTime'] = toto_filtered_tennis_yesno['Market Name'].apply(determine_over_under_time)

# Create 'Team1' and 'Team2'
toto_filtered_tennis_yesno[['Team1', 'Team2']] = toto_filtered_tennis_yesno['Event Name'].str.split(' vs ', expand=True)

# Create 'OverUnderType2'
toto_filtered_tennis_yesno['YesNoType2'] = toto_filtered_tennis_yesno.apply(
    lambda row: '1' if row['Team1'] in row['Market Name'] else (
        '2' if row['Team2'] in row['Market Name'] else 'Total team 1 and team 2'
    ),
    axis=1
)
# Out:
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2875134936.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_yesno['YesNoType'] = toto_filtered_tennis_yesno['Market Name'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2875134936.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_yesno['OverUnderTime'] = toto_filtered_tennis_yesno['Market Name'].apply(determine_over_under_time)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2875134936.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_yesno[['Team1', 'Team2']] = toto_filtered_tennis_yesno['Event Name'].str.split(' vs ', expand=True)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2875134936.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_yesno[['Team1', 'Team2']] = toto_filtered_tennis_yesno['Event Name'].str.split(' vs ', expand=True)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_36304/2875134936.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_tennis_yesno['YesNoType2'] = toto_filtered_tennis_yesno.apply(

# %%
# Perform the merge
merged_tennis_yesno = pd.merge(
    toto_filtered_tennis_yesno,
    kambi_filtered_tennis_yesno,
    left_on=['YesNoType', 'OverUnderTime', 'YesNoType2', 'matched_event'],
    right_on=['YesNoType', 'OverUnderTime', 'YesNoType2', 'event_name'],
    how='inner'  # Use 'inner' join to get only matching rows; adjust as needed
)
# Keep records with opposite outcomes
merged_tennis_yesno = merged_tennis_yesno[merged_tennis_yesno['outcome_english_label'] != merged_tennis_yesno['Outcome Name']]

# Display the merged DataFrame
merged_tennis_yesno.head()
# Out:
# Empty DataFrame
# Columns: [event_id_x, Event Name, Market Name, Outcome Name, Odds (Decimal), Price Numerator, Price Denominator, Outcome Type, Outcome SubType, sport_x, competition, matched_event, YesNoType, OverUnderTime, Team1_x, Team2_x, YesNoType2, bet_offer_id, criterion_id, criterion_label, criterion_english_label, occurrence_type, lifetime, bet_offer_type_id, bet_offer_type_name, bet_offer_type_english_name, event_id_y, outcome_id, outcome_label, outcome_english_label, odds, line, participant, type, changed_date, odds_fractional, odds_american, status, cash_out_status, home_score, away_score, event_name, sport_y, group_name, Team1_y, Team2_y]
# Index: []

# %% [markdown]
# ## Match Winnaar & OverUnder & YesNo and do Arb Analysis

# %%
# Perform the stacked union
# 58                 Jaime Faria vs Marc Andrea Huesler
# 59                 Jaime Faria vs Marc Andrea Huesler
#
#                             Market Name  Odds (Decimal)  \
# 0        Aantal Games   Over/Under 22.5            2.02
# 1        Aantal Games   Over/Under 22.5            1.77
# 2   Set 1 Aantal Games   Over/Under 9.5            1.90
# 3   Set 1 Aantal Games   Over/Under 9.5            1.88
# 4   Set 1 Aantal Games   Over/Under 8.5            1.79
# 5   Set 1 Aantal Games   Over/Under 8.5            1.99
# 6   Set 1 Aantal Games   Over/Under 9.5            1.45
# 7   Set 1 Aantal Games   Over/Under 9.5            2.70
# 8        Aantal Games   Over/Under 34.5            1.82
# 9        Aantal Games   Over/Under 34.5            1.95
# 10  Set 1 Aantal Games   Over/Under 9.5            2.03
# 11  Set 1 Aantal Games   Over/Under 9.5            1.76
# 12       Aantal Games   Over/Under 20.5            1.92
# 13       Aantal Games   Over/Under 20.5            1.85
# 14  Set 1 Aantal Games   Over/Under 9.5            1.73
# 15  Set 1 Aantal Games   Over/Under 9.5            2.08
# 16       Aantal Games   Over/Under 40.5            1.87
# 17       Aantal Games   Over/Under 40.5            1.91
# 18  Set 1 Aantal Games   Over/Under 9.5            2.39
# 19  Set 1 Aantal Games   Over/Under 9.5            1.56
# 20                            Wedstrijd            2.65
# 21                            Wedstrijd            1.51
# 22                            Wedstrijd           10.00
# 23                            Wedstrijd            1.06
# 24                            Wedstrijd            3.20
# 25                            Wedstrijd            1.38
# 26                            Wedstrijd            5.25
# 27                            Wedstrijd            1.18
# 28                            Wedstrijd            1.24
# 29                            Wedstrijd            4.25
# 30                            Wedstrijd            1.63
# 31                            Wedstrijd            2.34
# 32                            Wedstrijd            1.18
# 33                            Wedstrijd            4.75
# 34                            Wedstrijd            2.34
# 35                            Wedstrijd            1.58
# 36                            Wedstrijd            2.39
# 37                            Wedstrijd            1.56
# 38                            Wedstrijd            1.33
# 39                            Wedstrijd            3.25
# 40                            Wedstrijd            1.67
# 41                            Wedstrijd            2.17
# 42                            Wedstrijd            2.39
# 43                            Wedstrijd            1.56
# 44                            Wedstrijd            2.90
# 45                            Wedstrijd            1.40
# 46                            Wedstrijd            1.25
# 47                            Wedstrijd            3.80
# 48                            Wedstrijd            2.55
# 49                            Wedstrijd            1.50
# 50                            Wedstrijd            1.75
# 51                            Wedstrijd            2.05
# 52                            Wedstrijd            1.71
# 53                            Wedstrijd            2.10
# 54                            Wedstrijd            4.00
# 55                            Wedstrijd            1.23
# 56                            Wedstrijd            1.36
# 57                            Wedstrijd            3.05
# 58                            Wedstrijd            2.47
# 59                            Wedstrijd            1.53
#
#                         Outcome Name Outcome SubType Outcome Type  \
# 0                               Over               1           HL
# 1                              Under               L           HL
# 2                              Under               L           HL
# 3                               Over               1           HL
# 4                               Over               1           HL
# 5                              Under               L           HL
# 6                               Over               1           HL
# 7                              Under               L           HL
# 8                               Over               1           HL
# 9                              Under               L           HL
# 10                              Over               1           HL
# 11                             Under               L           HL
# 12                             Under               L           HL
# 13                              Over               1           HL
# 14                             Under               L           HL
# 15                              Over               1           HL
# 22              9.0              NaN              NaN               NaN
# 23              3.0              NaN              NaN               NaN
# 24             11.0              NaN              NaN               NaN
# 25             19.0              NaN              NaN               NaN
# 26             17.0              NaN              NaN               NaN
# 27              9.0              NaN              NaN               NaN
# 28              6.0              NaN              NaN               NaN
# 29             13.0              NaN              NaN               NaN
# 30             63.0              NaN              NaN               NaN
# 31             67.0              NaN              NaN               NaN
# 32              9.0              NaN              NaN               NaN
# 33             15.0              NaN              NaN               NaN
# 34             67.0              NaN              NaN               NaN
# 35             29.0              NaN              NaN               NaN
# 36            139.0              NaN              NaN               NaN
# 37             14.0              NaN              NaN               NaN
# 38             33.0              NaN              NaN               NaN
# 39              9.0              NaN              NaN               NaN
# 40             67.0              NaN              NaN               NaN
# 41            117.0              NaN              NaN               NaN
# 42            139.0              NaN              NaN               NaN
# 43             14.0              NaN              NaN               NaN
# 44             19.0              NaN              NaN               NaN
# 45              2.0              NaN              NaN               NaN
# 46              1.0              NaN              NaN               NaN
# 47             14.0              NaN              NaN               NaN
# 48             31.0              NaN              NaN               NaN
# 49              1.0              NaN              NaN               NaN
# 50              3.0              NaN              NaN               NaN
# 51             21.0              NaN              NaN               NaN
# 52             71.0              NaN              NaN               NaN
# 53             11.0              NaN              NaN               NaN
# 54              3.0              NaN              NaN               NaN
# 55             23.0              NaN              NaN               NaN
# 56              9.0              NaN              NaN               NaN
# 57             41.0              NaN              NaN               NaN
# 58            147.0              NaN              NaN               NaN
# 59             53.0              NaN              NaN               NaN
#
#              Team2_y YesNoType YesNoType2 away_score  bet_offer_id  \
# 0    Elina Svitolina       NaN        NaN        NaN    2487363282
# 1    Elina Svitolina       NaN        NaN        NaN    2487363282
# 2    Elina Svitolina       NaN        NaN        NaN    2487363279
# 3    Elina Svitolina       NaN        NaN        NaN    2487363279
# 4        Iga Swiatek       NaN        NaN        NaN    2487385531
# 5        Iga Swiatek       NaN        NaN        NaN    2487385531
# 6     Lorenzo Sonego       NaN        NaN        NaN    2487376814
# 7     Lorenzo Sonego       NaN        NaN        NaN    2487376814
# 8     De Alex Minaur       NaN        NaN        NaN    2487409293
# 9     De Alex Minaur       NaN        NaN        NaN    2487409293
# 10    De Alex Minaur       NaN        NaN        NaN    2487409291
# 11    De Alex Minaur       NaN        NaN        NaN    2487409291
# 12      Paula Badosa       NaN        NaN        NaN    2487593272
# 13      Paula Badosa       NaN        NaN        NaN    2487593272
# 14      Paula Badosa       NaN        NaN        NaN    2487593270
# 15      Paula Badosa       NaN        NaN        NaN    2487593270
# 16  Alexander Zverev       NaN        NaN        NaN    2487636596
# 17  Alexander Zverev       NaN        NaN        NaN    2487636596
# 18  Alexander Zverev       NaN        NaN        NaN    2487636594
# 19  Alexander Zverev       NaN        NaN        NaN    2487636594
# 20               NaN       NaN        NaN        NaN    2487363274
# 21               NaN       NaN        NaN        NaN    2487363274
# 22               NaN       NaN        NaN        NaN    2487377595
# 23               NaN       NaN        NaN        NaN    2487377595
# 24               NaN       NaN        NaN        NaN    2487376809
# 25               NaN       NaN        NaN        NaN    2487376809
# 26               NaN       NaN        NaN        NaN    2487406209
# 27               NaN       NaN        NaN        NaN    2487406209
# 28               NaN       NaN        NaN        NaN    2487591123
# 29               NaN       NaN        NaN        NaN    2487591123
# 30               NaN       NaN        NaN        NaN    2487636588
# 31               NaN       NaN        NaN        NaN    2487636588
# 32               NaN       NaN        NaN        NaN    2487529647
# 33               NaN       NaN        NaN        NaN    2487529647
# 34               NaN       NaN        NaN        NaN    2487529643
# 35               NaN       NaN        NaN        NaN    2487529643
# 36               NaN       NaN        NaN        NaN    2487529645
# 37               NaN       NaN        NaN        NaN    2487529645
# 38               NaN       NaN        NaN        NaN    2487529648
# 39               NaN       NaN        NaN        NaN    2487529648
# 40               NaN       NaN        NaN        NaN    2487529646
# 41               NaN       NaN        NaN        NaN    2487529646
# 42               NaN       NaN        NaN        NaN    2487529642
# 43               NaN       NaN        NaN        NaN    2487529642
# 44               NaN       NaN        NaN        NaN    2487529644
# 45               NaN       NaN        NaN        NaN    2487529644
# 46               NaN       NaN        NaN        NaN    2487592492
# 47               NaN       NaN        NaN        NaN    2487592492
# 48               NaN       NaN        NaN        NaN    2487445660
# 49               NaN       NaN        NaN        NaN    2487445660
# 50               NaN       NaN        NaN        NaN    2487286655
# 51               NaN       NaN        NaN        NaN    2487286655
# 52               NaN       NaN        NaN        NaN    2487592490
# 53               NaN       NaN        NaN        NaN    2487592490
# 54               NaN       NaN        NaN        NaN    2487150297
# 55               NaN       NaN        NaN        NaN    2487150297
# 56               NaN       NaN        NaN        NaN    2487592488
# 57               NaN       NaN        NaN        NaN    2487592488
# 58               NaN       NaN        NaN        NaN    2487529614
# 59               NaN       NaN        NaN        NaN    2487529614
#
#    bet_offer_type_english_name  bet_offer_type_id bet_offer_type_name  \
# 0                   Over/Under                  6          Over/Onder
# 1                   Over/Under                  6          Over/Onder
# 2                   Over/Under                  6          Over/Onder
# 3                   Over/Under                  6          Over/Onder
# 4                   Over/Under                  6          Over/Onder
# 5                   Over/Under                  6          Over/Onder
# 6                   Over/Under                  6          Over/Onder
# 7                   Over/Under                  6          Over/Onder
# 8                   Over/Under                  6          Over/Onder
# 9                   Over/Under                  6          Over/Onder
# 10                  Over/Under                  6          Over/Onder
# 11                  Over/Under                  6          Over/Onder
# 12                  Over/Under                  6          Over/Onder
# 13                  Over/Under                  6          Over/Onder
# 14                  Over/Under                  6          Over/Onder
# 15                  Over/Under                  6          Over/Onder
# 16                  Over/Under                  6          Over/Onder
# 17                  Over/Under                  6          Over/Onder
# 18                  Over/Under                  6          Over/Onder
# 19                  Over/Under                  6          Over/Onder
# 20                       Match                  2          Wedstrijd
# 21                       Match                  2          Wedstrijd
# 22                       Match                  2          Wedstrijd
# 23                       Match                  2          Wedstrijd
# 24                       Match                  2          Wedstrijd
# 25                       Match                  2          Wedstrijd
# 26                       Match                  2          Wedstrijd
# 27                       Match                  2          Wedstrijd
# 28                       Match                  2          Wedstrijd
# 29                       Match                  2          Wedstrijd
# 30                       Match                  2          Wedstrijd
# 31                       Match                  2          Wedstrijd
# 55     6614480  1022613964            Aguilar Joaquin Cardozo vs Facundo Mena
# 56     6634199  1022631667          Franco Roncadelli vs Juan Torres Bautista
# 57     6634199  1022631667          Franco Roncadelli vs Juan Torres Bautista
# 58     6622480  1022621317                 Jaime Faria vs Marc Huesler Andrea
# 59     6622480  1022621317                 Jaime Faria vs Marc Huesler Andrea
#
#         group_name home_score lifetime  line  \
# 0              NaN        NaN      NaN  22.5
# 1              NaN        NaN      NaN  22.5
# 2              NaN        NaN      NaN   9.5
# 3              NaN        NaN      NaN   9.5
# 4              NaN        NaN      NaN   8.5
# 5              NaN        NaN      NaN   8.5
# 6              NaN        NaN      NaN   9.5
# 7              NaN        NaN      NaN   9.5
# 8              NaN        NaN      NaN  34.5
# 9              NaN        NaN      NaN  34.5
# 10             NaN        NaN      NaN   9.5
# 11             NaN        NaN      NaN   9.5
# 12             NaN        NaN      NaN  20.5
# 13             NaN        NaN      NaN  20.5
# 14             NaN        NaN      NaN   9.5
# 15             NaN        NaN      NaN   9.5
# 16             NaN        NaN      NaN  40.5
# 17             NaN        NaN      NaN  40.5
# 18             NaN        NaN      NaN   9.5
# 19             NaN        NaN      NaN   9.5
# 20             NaN        NaN      NaN   NaN
# 21             NaN        NaN      NaN   NaN
# 22             NaN        NaN      NaN   NaN
# 23             NaN        NaN      NaN   NaN
# 24             NaN        NaN      NaN   NaN
# 25             NaN        NaN      NaN   NaN
# 26             NaN        NaN      NaN   NaN
# 27             NaN        NaN      NaN   NaN
# 28             NaN        NaN      NaN   NaN
# 29             NaN        NaN      NaN   NaN
# 30             NaN        NaN      NaN   NaN
# 31             NaN        NaN      NaN   NaN
# 32         Quimper        NaN      NaN   NaN
# 33         Quimper        NaN      NaN   NaN
# 34         Quimper        NaN      NaN   NaN
# 35         Quimper        NaN      NaN   NaN
# 36         Quimper        NaN      NaN   NaN
# 37         Quimper        NaN      NaN   NaN
# 38         Quimper        NaN      NaN   NaN
# 39         Quimper        NaN      NaN   NaN
# 40         Quimper        NaN      NaN   NaN
# 41         Quimper        NaN      NaN   NaN
# 42         Quimper        NaN      NaN   NaN
# 43         Quimper        NaN      NaN   NaN
# 44         Quimper        NaN      NaN   NaN
# 45         Quimper        NaN      NaN   NaN
# 46  Punta del Este        NaN      NaN   NaN
# 47  Punta del Este        NaN      NaN   NaN
# 48          Oeiras        NaN      NaN   NaN
# 49          Oeiras        NaN      NaN   NaN
# 50  Punta del Este        NaN      NaN   NaN
# 51  Punta del Este        NaN      NaN   NaN
# 52  Punta del Este        NaN      NaN   NaN
# 53  Punta del Este        NaN      NaN   NaN
# 54  Punta del Este        NaN      NaN   NaN
# 55  Punta del Este        NaN      NaN   NaN
# 56  Punta del Este        NaN      NaN   NaN
# 57  Punta del Este        NaN      NaN   NaN
# 58          Oeiras        NaN      NaN   NaN
# 59          Oeiras        NaN      NaN   NaN
#
#                                         matched_event occurrence_type  odds  \
# 0                     Madison Keys vs Elina Svitolina             NaN  1.79
# 1                     Madison Keys vs Elina Svitolina             NaN  2.06
# 49           Yasutaka Uchiyama vs Christopher Eubanks             NaN  2.65
# 50               Adolfo Vallejo Daniel vs Emilio Nava             NaN  2.05
# 51               Adolfo Vallejo Daniel vs Emilio Nava             NaN  1.75
# 52  Marco Trungelliti vs De Carvalho Cardoso Mateu...             NaN  2.05
# 53  Marco Trungelliti vs De Carvalho Cardoso Mateu...             NaN  1.79
# 54            Aguilar Joaquin Cardozo vs Facundo Mena             NaN  1.20
# 55            Aguilar Joaquin Cardozo vs Facundo Mena             NaN  4.30
# 56          Franco Roncadelli vs Juan Torres Bautista             NaN  3.10
# 57          Franco Roncadelli vs Juan Torres Bautista             NaN  1.35
# 58                 Jaime Faria vs Marc Huesler Andrea             NaN  1.48
# 59                 Jaime Faria vs Marc Huesler Andrea             NaN  2.55
#
#     odds_american odds_fractional              outcome_english_label  \
# 0          -127.0           10/13                              Under
# 1           106.0           21/20                               Over
# 2          -114.0           22/25                               Over
# 3          -105.0           19/20                              Under
# 4           107.0           21/20                              Under
# 5          -129.0           10/13                               Over
# 6           200.0             2/1                              Under
# 7          -265.0            4/11                               Over
# 8           108.0           27/25                              Under
# 9          -130.0             3/4                               Over
# 10         -125.0             4/5                              Under
# 11          105.0           21/20                               Over
# 12         -120.0             5/6                               Over
# 13         -103.0           49/50                              Under
# 14          106.0           21/20                               Over
# 15         -127.0           10/13                              Under
# 16         -105.0           19/20                              Under
# 17         -115.0           17/20                               Over
# 18         -167.0             3/5                               Over
# 19          135.0           27/20                              Under
# 20         -200.0             1/2                      Keys, Madison
# 21          170.0           17/10                   Svitolina, Elina
# 22        -1430.0            1/16                       Swiatek, Iga
# 23          850.0            17/2                      Navarro, Emma
# 24         -305.0          33/100                       Shelton, Ben
# 25          245.0           49/20                    Sonego, Lorenzo
# 26         -530.0            2/11                     Sinner, Jannik
# 27          410.0             4/1                    De Minaur, Alex
# 28          300.0             3/1                      Badosa, Paula
# 29         -385.0             1/4                   Sabalenka, Aryna
# 30          125.0             5/4                  Zverev, Alexander
# 31         -150.0             4/6                    Djokovic, Novak
# 32          360.0            18/5                      Paire, Benoit
# 33         -530.0            2/11                      Mayot, Harold
# 34         -182.0           11/20              Kovacevic, Aleksandar
# 35          140.0             7/5                  Kachmazov, Alibek
# 36         -177.0           11/20                   Bellucci, Mattia
# 37          135.0           27/20                Lestienne, Constant
# 38          235.0           47/20                  Martineau, Matteo
# 39         -335.0            3/10                        Kym, Jerome
# 40          110.0           11/10                        Gea, Arthur
# 41         -139.0            7/10                       Djere, Laslo
# 42         -177.0           11/20                McDonald, Mackenzie
# 43          135.0           27/20                  Mannarino, Adrian
# 44         -275.0            4/11               Seyboth Wild, Thiago
# 45          200.0             2/1                      Blanchet, Ugo
# 46          240.0            12/5                     Chazal, Maxime
# 47         -335.0            3/10                Galan, Daniel Elahi
# 48         -225.0             4/9               Eubanks, Christopher
# 49          165.0           33/20                 Uchiyama, Yasutaka
# 50          105.0           21/20             Vallejo, Adolfo Daniel
# 51         -134.0             3/4                       Nava, Emilio
# 52          105.0           21/20  De Carvalho Cardoso Alves, Mateus
# 40  3619626380                        Gea, Arthur         NaN  Tennis  TENNIS
# 41  3619626393                       Djere, Laslo         NaN  Tennis  TENNIS
# 42  3619626383                McDonald, Mackenzie         NaN  Tennis  TENNIS
# 43  3619626376                  Mannarino, Adrian         NaN  Tennis  TENNIS
# 44  3619626386               Seyboth Wild, Thiago         NaN  Tennis  TENNIS
# 45  3619626377                      Blanchet, Ugo         NaN  Tennis  TENNIS
# 46  3619897262                     Chazal, Maxime         NaN  Tennis  TENNIS
# 47  3619897256                Galan, Daniel Elahi         NaN  Tennis  TENNIS
# 48  3619351487               Eubanks, Christopher         NaN  Tennis  TENNIS
# 49  3619351483                        Uchiyama, Y         NaN  Tennis  TENNIS
# 50  3618801544             Vallejo, Adolfo Daniel         NaN  Tennis  TENNIS
# 51  3618801546                       Nava, Emilio         NaN  Tennis  TENNIS
# 52  3619897259  De Carvalho Cardoso Alves, Mateus         NaN  Tennis  TENNIS
# 53  3619897251                 Trungelliti, Marco         NaN  Tennis  TENNIS
# 54  3618347207                      Mena, Facundo         NaN  Tennis  TENNIS
# 55  3618347202           Aguilar Cardozo, Joaquin         NaN  Tennis  TENNIS
# 56  3619897249                 Roncadelli, Franco         NaN  Tennis  TENNIS
# 57  3619897258              Torres, Juan Bautista         NaN  Tennis  TENNIS
# 58  3619626287               Huesler, Marc-Andrea         NaN  Tennis  TENNIS
# 59  3619626285                       Faria, Jaime         NaN  Tennis  TENNIS
#
#    status      type
# 0    OPEN  OT_UNDER
# 1    OPEN   OT_OVER
# 2    OPEN   OT_OVER
# 3    OPEN  OT_UNDER
# 4    OPEN  OT_UNDER
# 5    OPEN   OT_OVER
# 6    OPEN  OT_UNDER
# 7    OPEN   OT_OVER
# 8    OPEN  OT_UNDER
# 9    OPEN   OT_OVER
# 10   OPEN  OT_UNDER
# 11   OPEN   OT_OVER
# 12   OPEN   OT_OVER
# 13   OPEN  OT_UNDER
# 14   OPEN   OT_OVER
# 15   OPEN  OT_UNDER
# 16   OPEN  OT_UNDER
# 17   OPEN   OT_OVER
# 18   OPEN   OT_OVER
# 19   OPEN  OT_UNDER
# 20   OPEN         1
# 21   OPEN         2
# 22   OPEN         2
# 23   OPEN         1
# 24   OPEN         1
# 25   OPEN         2
# 26   OPEN         1
# 27   OPEN         2
# 28   OPEN         2
# 29   OPEN         1
# 30   OPEN         2
# 31   OPEN         1
# 32   OPEN         1
# 33   OPEN         2
# 34   OPEN         2
# 35   OPEN         1
# 36   OPEN         1
# 37   OPEN         2
# 38   OPEN         1
# 39   OPEN         2
# 40   OPEN         1
# 41   OPEN         2
# 42   OPEN         2
# 43   OPEN         1
# 44   OPEN         2
# 45   OPEN         1
# 46   OPEN         2
# 47   OPEN         1
# 48   OPEN         2
# 49   OPEN         1
# 50   OPEN         1
# 51   OPEN         2
# 52   OPEN         2
# 53   OPEN         1
# 54   OPEN         2
# 55   OPEN         1
# 56   OPEN         1
# 57   OPEN         2
# 58   OPEN         2
# 59   OPEN         1

# %%
# Calculate Arbitrage Percentage
total_tennis['Arbitrage Percentage'] = (1 / total_tennis['Odds (Decimal)'] + 1 / total_tennis['odds']) * 100

# Identify Arbitrage Opportunities
total_tennis['Is Arbitrage'] = total_tennis['Arbitrage Percentage'] < 100

# Calculate Optimal Stakes if Arbitrage
total_stake = 1000
total_tennis['Stake A'] = total_tennis.apply(
    lambda row: (1 / row['Odds (Decimal)'] / (1 / row['Odds (Decimal)'] + 1 / row['odds']) * total_stake) if row['Is Arbitrage'] else 0,
    axis=1
)
total_tennis['Stake B'] = total_tennis.apply(
    lambda row: (1 / row['odds'] / (1 / row['Odds (Decimal)'] + 1 / row['odds']) * total_stake) if row['Is Arbitrage'] else 0,
    axis=1
)

total_tennis[['Event Name', 'Market Name', 'Outcome Name', 'outcome_label', 'Odds (Decimal)', 'odds', 'Arbitrage Percentage', 'Is Arbitrage', 'Stake A', 'Stake B']]
# Out:
#                                            Event Name  \
# 0                     Madison Keys vs Elina Svitolina
# 1                     Madison Keys vs Elina Svitolina
# 2                     Madison Keys vs Elina Svitolina
# 3                     Madison Keys vs Elina Svitolina
# 4                         Emma Navarro vs Iga Swiatek
# 5                         Emma Navarro vs Iga Swiatek
# 6                       Ben Shelton vs Lorenzo Sonego
# 7                       Ben Shelton vs Lorenzo Sonego
# 8                     Jannik Sinner vs Alex De Minaur
# 9                     Jannik Sinner vs Alex De Minaur
# 10                    Jannik Sinner vs Alex De Minaur
# 11                    Jannik Sinner vs Alex De Minaur
# 12                    Aryna Sabalenka vs Paula Badosa
# 13                    Aryna Sabalenka vs Paula Badosa
# 14                    Aryna Sabalenka vs Paula Badosa
# 15                    Aryna Sabalenka vs Paula Badosa
# 16                 Novak Djokovic vs Alexander Zverev
# 17                 Novak Djokovic vs Alexander Zverev
# 18                 Novak Djokovic vs Alexander Zverev
# 19                 Novak Djokovic vs Alexander Zverev
# 20                    Madison Keys vs Elina Svitolina
# 21                    Madison Keys vs Elina Svitolina
# 22                        Emma Navarro vs Iga Swiatek
# 23                        Emma Navarro vs Iga Swiatek
# 24                      Ben Shelton vs Lorenzo Sonego
# 25                      Ben Shelton vs Lorenzo Sonego
# 26                    Jannik Sinner vs Alex De Minaur
# 27                    Jannik Sinner vs Alex De Minaur
# 28                    Aryna Sabalenka vs Paula Badosa
# 29                    Aryna Sabalenka vs Paula Badosa
# 30                 Novak Djokovic vs Alexander Zverev
# 31                 Novak Djokovic vs Alexander Zverev
# 32                       Benoit Paire vs Harold Mayot
# 33                       Benoit Paire vs Harold Mayot
# 34           Alibek Kachmazov vs Aleksandar Kovacevic
# 35           Alibek Kachmazov vs Aleksandar Kovacevic
# 36              Mattia Bellucci vs Constant Lestienne
# 37              Mattia Bellucci vs Constant Lestienne
# 38                     Matteo Martineau vs Jerome Kym
# 39                     Matteo Martineau vs Jerome Kym
# 40                          Arthur Gea vs Laslo Djere
# 41                          Arthur Gea vs Laslo Djere
# 42             Adrian Mannarino vs Mackenzie Mcdonald
# 43             Adrian Mannarino vs Mackenzie Mcdonald
# 44                Ugo Blanchet vs Thiago Seyboth Wild
# 45                Ugo Blanchet vs Thiago Seyboth Wild
# 46                Daniel Elahi Galan vs Maxime Chazal
# 47                Daniel Elahi Galan vs Maxime Chazal
# 48           Yasutaka Uchiyama vs Christopher Eubanks
# 49           Yasutaka Uchiyama vs Christopher Eubanks
# 50               Adolfo Daniel Vallejo vs Emilio Nava
# 51               Adolfo Daniel Vallejo vs Emilio Nava
# 52  Marco Trungelliti vs Mateus De Carvalho Cardos...
# 53  Marco Trungelliti vs Mateus De Carvalho Cardos...
# 54            Joaquin Aguilar Cardozo vs Facundo Mena
# 55            Joaquin Aguilar Cardozo vs Facundo Mena
# 56          Franco Roncadelli vs Juan Bautista Torres
# 57          Franco Roncadelli vs Juan Bautista Torres
# 58                 Jaime Faria vs Marc Andrea Huesler
# 59                 Jaime Faria vs Marc Andrea Huesler
#
#                             Market Name                      Outcome Name  \
# 0        Aantal Games   Over/Under 22.5                              Over
# 1        Aantal Games   Over/Under 22.5                             Under
# 2   Set 1 Aantal Games   Over/Under 9.5                             Under
# 3   Set 1 Aantal Games   Over/Under 9.5                              Over
# 4   Set 1 Aantal Games   Over/Under 8.5                              Over
# 5   Set 1 Aantal Games   Over/Under 8.5                             Under
# 6   Set 1 Aantal Games   Over/Under 9.5                              Over
# 7   Set 1 Aantal Games   Over/Under 9.5                             Under
# 8        Aantal Games   Over/Under 34.5                              Over
# 9        Aantal Games   Over/Under 34.5                             Under
# 10  Set 1 Aantal Games   Over/Under 9.5                              Over
# 11  Set 1 Aantal Games   Over/Under 9.5                             Under
# 12       Aantal Games   Over/Under 20.5                             Under
# 13       Aantal Games   Over/Under 20.5                              Over
# 14  Set 1 Aantal Games   Over/Under 9.5                             Under
# 15  Set 1 Aantal Games   Over/Under 9.5                              Over
# 16       Aantal Games   Over/Under 40.5                              Over
# 17       Aantal Games   Over/Under 40.5                             Under
# 18  Set 1 Aantal Games   Over/Under 9.5                             Under
# 19  Set 1 Aantal Games   Over/Under 9.5                              Over
# 20                            Wedstrijd                   Elina Svitolina
# 21                            Wedstrijd                      Madison Keys
# 22                            Wedstrijd                      Emma Navarro
# 23                            Wedstrijd                       Iga Swiatek
# 24                            Wedstrijd                    Lorenzo Sonego
# 25                            Wedstrijd                       Ben Shelton
# 26                            Wedstrijd                    Alex De Minaur
# 27                            Wedstrijd                     Jannik Sinner
# 28                            Wedstrijd                   Aryna Sabalenka
# 29                            Wedstrijd                      Paula Badosa
# 30                            Wedstrijd                    Novak Djokovic
# 31                            Wedstrijd                  Alexander Zverev
# 32                            Wedstrijd                      Harold Mayot
# 33                            Wedstrijd                      Benoit Paire
# 34                            Wedstrijd                  Alibek Kachmazov
# 35                            Wedstrijd              Aleksandar Kovacevic
# 36                            Wedstrijd                Constant Lestienne
# 37                            Wedstrijd                   Mattia Bellucci
# 38                            Wedstrijd                        Jerome Kym
# 39                            Wedstrijd                  Matteo Martineau
# 40                            Wedstrijd                       Laslo Djere
# 41                            Wedstrijd                        Arthur Gea
# 42                            Wedstrijd                  Adrian Mannarino
# 43                            Wedstrijd                Mackenzie Mcdonald
# 51                       Nava, Emilio            2.05  1.75
# 52  De Carvalho Cardoso Alves, Mateus            1.71  2.05
# 53                 Trungelliti, Marco            2.10  1.79
# 54                      Mena, Facundo            4.00  1.20
# 55           Aguilar Cardozo, Joaquin            1.23  4.30
# 56                 Roncadelli, Franco            1.36  3.10
# 57              Torres, Juan Bautista            3.05  1.35
# 58               Huesler, Marc-Andrea            2.47  1.48
# 59                       Faria, Jaime            1.53  2.55
#
#     Arbitrage Percentage  Is Arbitrage  Stake A  Stake B
# 0             105.370872         False        0        0
# 1             105.040864         False        0        0
# 2             105.823068         False        0        0
# 3             104.211898         False        0        0
# 4             104.175101         False        0        0
# 5             106.431032         False        0        0
# 6             102.298851         False        0        0
# 7             109.500805         False        0        0
# 8             103.021978         False        0        0
# 9             107.779226         False        0        0
# 10            104.816639         False        0        0
# 11            105.598670         False        0        0
# 12            106.431159         False        0        0
# 13            104.559105         False        0        0
# 14            106.347158         False        0        0
# 15            103.942845         False        0        0
# 16            104.496344         False        0        0
# 17            105.831957         False        0        0
# 18            104.341004         False        0        0
# 19            106.655756         False        0        0
# 20            104.402516         False        0        0
# 21            103.262203         False        0        0
# 22            103.457944         False        0        0
# 23            104.865938         False        0        0
# 24            106.437970         False        0        0
# 25            101.449275         False        0        0
# 26            103.081232         False        0        0
# 27            104.353606         False        0        0
# 28            105.645161         False        0        0
# 29            102.894491         False        0        0
# 30            105.794138         False        0        0
# 31            102.615282         False        0        0
# 32            106.484893         False        0        0
# 33            105.086245         False        0        0
# 34            107.251172         False        0        0
# 35            104.957806         False        0        0
# 36            105.535272         False        0        0
# 37            106.655756         False        0        0
# 38            105.038716         False        0        0
# 39            107.105109         False        0        0
# 40            107.499287         False        0        0
# 41            104.222484         False        0        0
# 42            105.535272         False        0        0
# 43            106.655756         False        0        0
# 44            107.475459         False        0        0
# 45            104.761905         False        0        0
# 46            109.411765         False        0        0
# 47            103.238866         False        0        0
# 48            108.181204         False        0        0
# 49            104.402516         False        0        0
# 50            105.923345         False        0        0
# 51            105.923345         False        0        0
# 52            107.260020         False        0        0
# 53            103.484969         False        0        0
# 54            108.333333         False        0        0
# 55            104.556627         False        0        0
# 56            105.787476         False        0        0
# 57            106.860959         False        0        0
# 58            108.053398         False        0        0
# 59            104.575163         False        0        0

# %%
total_tennis[total_tennis['Is Arbitrage']==True]
# Out:
# Empty DataFrame
# Columns: [Event Name, Market Name, Odds (Decimal), Outcome Name, Outcome SubType, Outcome Type, OverUnderTime, OverUnderType, OverUnderType2, Price Denominator, Price Numerator, Team1_x, Team1_y, Team2_x, Team2_y, YesNoType, YesNoType2, away_score, bet_offer_id, bet_offer_type_english_name, bet_offer_type_id, bet_offer_type_name, cash_out_status, changed_date, competition, criterion_english_label, criterion_id, criterion_label, event_id_x, event_id_y, event_name, group_name, home_score, lifetime, line, matched_event, occurrence_type, odds, odds_american, odds_fractional, outcome_english_label, outcome_id, outcome_label, participant, sport_x, sport_y, status, type, Arbitrage Percentage, Is Arbitrage, Stake A, Stake B]
# Index: []
