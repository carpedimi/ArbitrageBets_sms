# %% [markdown]
# ## Set up matching DF's

# %%
import pandas as pd
# Set pandas to display all columns
pd.set_option('display.max_columns', None)

# %%
toto_raw = pd.read_csv('Data/scrapers/Toto/totoAllSports25122024.csv', index_col=0).drop_duplicates()
kambi_raw = pd.read_csv('Data/scrapers/unibet/unibet_allSports_odds_25122024.csv', index_col=0).drop_duplicates()
# Apply the condition and update outcome_label
toto_raw_basketbal = toto_raw[toto_raw['sport'] == 'Basketbal']
kambi_raw_basketbal = kambi_raw[kambi_raw['sport'] == 'BASKETBALL']

# %% [markdown]
# Below is a translation of the abbreviations for the column outcome types into their likely meanings in the context of betting odds:
#
# - `--`: Undefined or No Outcome (e.g., no odds available).
# - `AG`: Anytime Goal Scorer (player to score at any time in the match).
# - `CS`: Correct Score (predict the exact final score of the event).
# - `DC`: Double Chance (cover two outcomes, e.g., Home Win or Draw).
# - `DN`: Draw No Bet (stake refunded if the match ends in a draw).
# - `FS`: First Scorer (player to score the first goal/point in the event).
# - `H1`: First Half Result (outcome at the end of the first half).
# - `H2`: Second Half Result (outcome in the second half only).
# - `HF`: Half-Time/Full-Time (predict the result at both half-time and full-time).
# - `HH`: Head-to-Head (comparison between two participants, e.g., players or teams).
# - `HL`: Handicap Line (spread betting; adjust the line to level the playing field).
# - `LS`: Last Scorer (player to score the last goal/point in the event).
# - `MH`: Match Handicap (spread betting for the entire match).
# - `MR`: Match Result (predict the overall winner or draw for the match).
# - `OE`: Odd/Even (predict whether the total points/goals scored will be odd or even).
# - `WH`: Winning Half (which half will have the higher score).
# - `WM`: Winning Margin (predict the margin by which a team/player will win).

# %%
# filter down to suitable betting opps
kambi_filtered_basketbal = kambi_raw_basketbal[kambi_raw_basketbal['bet_offer_type_english_name'].isin(['Match', 'Odd/Even', 'Player Occurrence Line', 'Asian Over/Under', 'Over/Under', 'Handicap', 'Asian Handicap', 'Yes/No', 'Head to Head'])]
toto_filtered_basketbal = toto_raw_basketbal[toto_raw_basketbal['Outcome Type'].isin(['--', 'DN', 'OE', 'HH', 'HL', 'AG'])]

kambi_filtered_basketbal = kambi_raw_basketbal
toto_filtered_basketbal = toto_raw_basketbal[toto_raw_basketbal['Outcome Type'].isin(['DN', 'OE', 'HH', 'HL', 'AG'])]

# Remove duplicates in toto_filtered_basketbal based on specified columns
toto_filtered_basketbal = toto_filtered_basketbal.drop_duplicates(
    subset=['Event Name', 'Market Name', 'Outcome Name']
)
# Remove duplicates in kambi_filtered_basketbal based on specified columns
kambi_filtered_basketbal = kambi_filtered_basketbal.drop_duplicates(
    subset=['event_name', 'outcome_label', 'criterion_label']
)

# %% [markdown]
# ## Winnaar

# %%
from rapidfuzz import process, fuzz
import pandas as pd

# Filter kambi_filtered_basketbal based on criterion_label
filtered_kambi_winnaar = kambi_filtered_basketbal[
    kambi_filtered_basketbal['criterion_label'] == 'Resultaat aan het Eind van 4e Kwart'
]

# Filter kambi_filtered_basketbal based on criterion_label
filtered_toto_winnaar = toto_filtered_basketbal[
    toto_filtered_basketbal['Market Name'] == 'Winnaar'
]

# Preprocess strings: Remove extra whitespace and lowercase
def preprocess(text):
    return ' '.join(text.lower().split())

# %%
# Create a dictionary for faster lookups of event_name in kambi_filtered_basketbal
kambi_events = filtered_kambi_winnaar['event_name'].tolist()

# Function to find the best match for 'Event Name' in toto_filtered_basketbal
def find_best_match(event_name):
    # Use a token-based similarity for better handling of substrings
    result = process.extractOne(event_name, kambi_events, scorer=fuzz.token_set_ratio, score_cutoff=70)
    if result is None:  # No match found
        return None
    match, score, _ = result
    return match

# Apply matching function to toto_filtered_basketbal
toto_filtered_basketbal['matched_event'] = toto_filtered_basketbal['Event Name'].apply(find_best_match)

# %%
# Filter rows in toto_filtered_basketbal where Market Name == 'Winnaar'
toto_filtered_basketbal = toto_filtered_basketbal[toto_filtered_basketbal['Market Name'] == 'Winnaar']

# Perform a left join on the matched_event_name (from toto) and event_name (from kambi)
merged_df = toto_filtered_basketbal.merge(
    filtered_kambi_winnaar,
    left_on='matched_event',
    right_on='event_name',
    how='left'
)

# %%
merged_df[merged_df['Event Name'].str.contains('Alba')]
# Out:
#     event_id_x                  Event Name Market Name Outcome Name  \
# 46     6255852  Alba Berlin vs Real Madrid     Winnaar  Real Madrid
# 47     6255852  Alba Berlin vs Real Madrid     Winnaar  Real Madrid
# 48     6255852  Alba Berlin vs Real Madrid     Winnaar  Real Madrid
# 49     6255852  Alba Berlin vs Real Madrid     Winnaar  Alba Berlin
# 50     6255852  Alba Berlin vs Real Madrid     Winnaar  Alba Berlin
# 51     6255852  Alba Berlin vs Real Madrid     Winnaar  Alba Berlin
#
#     Odds (Decimal)  Price Numerator  Price Denominator Outcome Type  \
# 46            1.18                9                 50           HH
# 47            1.18                9                 50           HH
# 48            1.18                9                 50           HH
# 49            5.25               17                  4           HH
# 50            5.25               17                  4           HH
# 51            5.25               17                  4           HH
#
#    Outcome SubType    sport_x        competition  \
# 46               2  Basketbal  Euroleague Mannen
# 47               2  Basketbal  Euroleague Mannen
# 48               2  Basketbal  Euroleague Mannen
# 49               1  Basketbal  Euroleague Mannen
# 50               1  Basketbal  Euroleague Mannen
# 51               1  Basketbal  Euroleague Mannen
#
#                             matched_event  bet_offer_id  criterion_id  \
# 46  Alba Berlin vs Real Madrid Baloncesto  2.481232e+09  1.001212e+09
# 47  Alba Berlin vs Real Madrid Baloncesto  2.481232e+09  1.001212e+09
# 48  Alba Berlin vs Real Madrid Baloncesto  2.481232e+09  1.001212e+09
# 49  Alba Berlin vs Real Madrid Baloncesto  2.481232e+09  1.001212e+09
# 50  Alba Berlin vs Real Madrid Baloncesto  2.481232e+09  1.001212e+09
# 51  Alba Berlin vs Real Madrid Baloncesto  2.481232e+09  1.001212e+09
#
#                         criterion_label     criterion_english_label  \
# 46  Resultaat aan het Eind van 4e Kwart  Result at end of Quarter 4
# 47  Resultaat aan het Eind van 4e Kwart  Result at end of Quarter 4
# 48  Resultaat aan het Eind van 4e Kwart  Result at end of Quarter 4
# 49  Resultaat aan het Eind van 4e Kwart  Result at end of Quarter 4
# 50  Resultaat aan het Eind van 4e Kwart  Result at end of Quarter 4
# 51  Resultaat aan het Eind van 4e Kwart  Result at end of Quarter 4
#
#    occurrence_type   lifetime  bet_offer_type_id bet_offer_type_name  \
# 46          POINTS  FULL_TIME                2.0          Wedstrijd
# 47          POINTS  FULL_TIME                2.0          Wedstrijd
# 48          POINTS  FULL_TIME                2.0          Wedstrijd
# 49          POINTS  FULL_TIME                2.0          Wedstrijd
# 50          POINTS  FULL_TIME                2.0          Wedstrijd
# 51          POINTS  FULL_TIME                2.0          Wedstrijd
#
#    bet_offer_type_english_name    event_id_y    outcome_id outcome_label  \
# 46                       Match  1.021227e+09  3.598105e+09             2
# 47                       Match  1.021227e+09  3.598105e+09             1
# 48                       Match  1.021227e+09  3.598105e+09             X
# 49                       Match  1.021227e+09  3.598105e+09             2
# 50                       Match  1.021227e+09  3.598105e+09             1
# 51                       Match  1.021227e+09  3.598105e+09             X
#
#    outcome_english_label     odds  line             participant      type  \
# 46                     2   1190.0   NaN  Real Madrid Baloncesto         2
# 47                     1   5250.0   NaN             Alba Berlin         1
# 48                     X  18000.0   NaN                     NaN  OT_CROSS
# 49                     2   1190.0   NaN  Real Madrid Baloncesto         2
# 50                     1   5250.0   NaN             Alba Berlin         1
# 51                     X  18000.0   NaN                     NaN  OT_CROSS
#
#             changed_date odds_fractional  odds_american status  \
# 46  2024-12-24T17:23:59Z            2/11         -530.0   OPEN
# 47  2024-12-24T17:23:59Z            17/4          425.0   OPEN
# 48  2024-12-24T17:23:59Z            17/1         1700.0   OPEN
# 49  2024-12-24T17:23:59Z            2/11         -530.0   OPEN
# 50  2024-12-24T17:23:59Z            17/4          425.0   OPEN
# 51  2024-12-24T17:23:59Z            17/1         1700.0   OPEN
#
#    cash_out_status  home_score  away_score  \
# 46         ENABLED         NaN         NaN
# 47         ENABLED         NaN         NaN
# 48         ENABLED         NaN         NaN
# 49         ENABLED         NaN         NaN
# 50         ENABLED         NaN         NaN
# 51         ENABLED         NaN         NaN
#
#                                event_name     sport_y group_name
# 46  Alba Berlin vs Real Madrid Baloncesto  BASKETBALL        NaN
# 47  Alba Berlin vs Real Madrid Baloncesto  BASKETBALL        NaN
# 48  Alba Berlin vs Real Madrid Baloncesto  BASKETBALL        NaN
# 49  Alba Berlin vs Real Madrid Baloncesto  BASKETBALL        NaN
# 50  Alba Berlin vs Real Madrid Baloncesto  BASKETBALL        NaN
# 51  Alba Berlin vs Real Madrid Baloncesto  BASKETBALL        NaN

# %%
from rapidfuzz import fuzz

# Define a function to check similarity
def is_too_similar(outcome_name, participant):
    # Compute similarity score
    similarity = fuzz.ratio(str(outcome_name), str(participant))
    # Return True if similarity is greater than or equal to 70
    return similarity >= 70

# Filter merged_df to keep only rows where Outcome Name and participant are NOT too similar
filtered_merged_df = merged_df[
    ~merged_df.apply(lambda row: is_too_similar(row['Outcome Name'], row['participant']), axis=1)
]

filtered_merged_df_match_winner = filtered_merged_df[~(filtered_merged_df['matched_event'].isna()) & ~(filtered_merged_df['participant'].isna())]

# Display the filtered DataFrame
filtered_merged_df_match_winner.drop_duplicates(subset=['event_id_x', 'Event Name', 'Market Name', 'Outcome Name',
       'Odds (Decimal)', 'Price Numerator', 'Price Denominator',
       'Outcome Type', 'Outcome SubType', 'sport_x', 'competition',
       'matched_event', 'bet_offer_id', 'criterion_id', 'criterion_label',
       'criterion_english_label', 'occurrence_type', 'lifetime',
       'bet_offer_type_id', 'bet_offer_type_name',
       'bet_offer_type_english_name', 'event_id_y', 'outcome_id',
       'outcome_label', 'outcome_english_label', 'odds', 'line', 'participant',
       'type', 'changed_date', 'odds_fractional', 'odds_american', 'status',
       'cash_out_status', 'home_score', 'away_score', 'event_name', 'sport_y'])
# Out:
#      event_id_x                                       Event Name Market Name  \
# 9       5095868             New York Knicks vs San Antonio Spurs     Winnaar
# 11      5095868             New York Knicks vs San Antonio Spurs     Winnaar
# 15      5095905       Dallas Mavericks vs Minnesota Timberwolves     Winnaar
# 17      5095905       Dallas Mavericks vs Minnesota Timberwolves     Winnaar
# 21      5095904             Boston Celtics vs Philadelphia 76ers     Winnaar
# 23      5095904             Boston Celtics vs Philadelphia 76ers     Winnaar
# 27      5095863      Golden State Warriors vs Los Angeles Lakers     Winnaar
# 29      5095863      Golden State Warriors vs Los Angeles Lakers     Winnaar
# 32      5095864                   Phoenix Suns vs Denver Nuggets     Winnaar
# 36      5095864                   Phoenix Suns vs Denver Nuggets     Winnaar
# 40      6255851               AS Monaco vs Anadolu Efes Istanbul     Winnaar
# 44      6255851               AS Monaco vs Anadolu Efes Istanbul     Winnaar
# 46      6255852                       Alba Berlin vs Real Madrid     Winnaar
# 47      6255852                       Alba Berlin vs Real Madrid     Winnaar
# 49      6255852                       Alba Berlin vs Real Madrid     Winnaar
# 53      6255850           Maccabi Tel Aviv vs BC Zalgiris Kaunas     Winnaar
# 55      6255850           Maccabi Tel Aviv vs BC Zalgiris Kaunas     Winnaar
# 58      6255853  EA7 Emporio Armani Milano vs Olympiacos Piraeus     Winnaar
# 59      6255853  EA7 Emporio Armani Milano vs Olympiacos Piraeus     Winnaar
# 62      6255853  EA7 Emporio Armani Milano vs Olympiacos Piraeus     Winnaar
# 77      6264775                Barcelona vs KK Crvena Zvezda Mts     Winnaar
# 79      6264775                Barcelona vs KK Crvena Zvezda Mts     Winnaar
# 83      6264774               Bayern München vs Panathinaikos BC     Winnaar
# 85      6264774               Bayern München vs Panathinaikos BC     Winnaar
# 88      6264773           KK Partizan Nis Belgrade vs Fenerbahçe     Winnaar
# 92      6264773           KK Partizan Nis Belgrade vs Fenerbahçe     Winnaar
# 95      6264772               Saski Baskonia vs Paris Basketball     Winnaar
# 97      6264772               Saski Baskonia vs Paris Basketball     Winnaar
# 98      6264772               Saski Baskonia vs Paris Basketball     Winnaar
# 100     6264776        Virtus Bologna vs Asvel Lyon Villeurbanne     Winnaar
# 104     6264776        Virtus Bologna vs Asvel Lyon Villeurbanne     Winnaar
# 130     6323892                    Ratiopharm Ulm vs Beşiktaş JK     Winnaar
# 131     6323892                    Ratiopharm Ulm vs Beşiktaş JK     Winnaar
# 133     6323892                    Ratiopharm Ulm vs Beşiktaş JK     Winnaar
#
#                   Outcome Name  Odds (Decimal)  Price Numerator  \
# 9            San Antonio Spurs            4.15               63
# 11             New York Knicks            1.24               10
# 15      Minnesota Timberwolves            2.75                7
# 17            Dallas Mavericks            1.47               10
# 21          Philadelphia 76ers            3.95               59
# 23              Boston Celtics            1.27               10
# 27          Los Angeles Lakers            2.45               29
# 29       Golden State Warriors            1.58               10
# 32                Phoenix Suns            2.15               23
# 36              Denver Nuggets            1.74               20
# 40                   AS Monaco            1.47               47
# 44       Anadolu Efes Istanbul            2.75                7
# 46                 Real Madrid            1.18                9
# 47                 Real Madrid            1.18                9
# 49                 Alba Berlin            5.25               17
# 53          BC Zalgiris Kaunas            1.69               69
# 55            Maccabi Tel Aviv            2.20                6
# 58   EA7 Emporio Armani Milano            2.30               13
# 59   EA7 Emporio Armani Milano            2.30               13
# 62          Olympiacos Piraeus            1.65               13
# 77        KK Crvena Zvezda Mts            3.40               12
# 79                   Barcelona            1.33               33
# 83            Panathinaikos BC            1.80                4
# 85              Bayern München            2.05               21
# 88    KK Partizan Nis Belgrade            1.77               77
# 92                  Fenerbahçe            2.10               11
# 95            Paris Basketball            1.95               19
# 97              Saski Baskonia            1.87               87
# 98              Saski Baskonia            1.87               87
# 100             Virtus Bologna            1.69               69
# 104    Asvel Lyon Villeurbanne            2.20                6
# 130                Beşiktaş JK            1.80                4
# 131                Beşiktaş JK            1.80                4
# 133             Ratiopharm Ulm            1.87               87
#
#      Price Denominator Outcome Type Outcome SubType    sport_x  \
# 9                   20           HH               2  Basketbal
# 11                  41           HH               1  Basketbal
# 15                   4           HH               2  Basketbal
# 17                  21           HH               1  Basketbal
# 21                  20           HH               2  Basketbal
# 23                  37           HH               1  Basketbal
# 27                  20           HH               2  Basketbal
# 29                  17           HH               1  Basketbal
# 32                  20           HH               1  Basketbal
# 36                  27           HH               2  Basketbal
# 40                 100           HH               1  Basketbal
# 44                   4           HH               2  Basketbal
# 46                  50           HH               2  Basketbal
# 47                  50           HH               2  Basketbal
# 49                   4           HH               1  Basketbal
# 53                 100           HH               2  Basketbal
# 55                   5           HH               1  Basketbal
# 58                  10           HH               1  Basketbal
# 59                  10           HH               1  Basketbal
# 62                  20           HH               2  Basketbal
# 77                   5           HH               2  Basketbal
# 79                 100           HH               1  Basketbal
# 83                   5           HH               2  Basketbal
# 85                  20           HH               1  Basketbal
# 88                 100           HH               1  Basketbal
# 92                  10           HH               2  Basketbal
# 95                  20           HH               2  Basketbal
# 97                 100           HH               1  Basketbal
# 98                 100           HH               1  Basketbal
# 100                100           HH               1  Basketbal
# 104                  5           HH               2  Basketbal
# 130                  5           HH               2  Basketbal
# 131                  5           HH               2  Basketbal
# 133                100           HH               1  Basketbal
#
#            competition                                      matched_event  \
# 9                  NBA               New York Knicks vs San Antonio Spurs
# 11                 NBA               New York Knicks vs San Antonio Spurs
result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 11   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 15   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 17   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 21   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 23   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 27   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 29   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 32   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 36   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 40   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 44   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 46   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 47   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 49   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 53   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 55   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 58   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 59   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 62   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 77   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 79   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 83   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 85   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 88   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 92   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 95   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 97   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 98   Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 100  Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 104  Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 130  Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 131  Result at end of Quarter 4          POINTS  FULL_TIME                2.0
# 133  Result at end of Quarter 4          POINTS  FULL_TIME                2.0
#
#     bet_offer_type_name bet_offer_type_english_name    event_id_y  \
# 9            Wedstrijd                        Match  1.021416e+09
# 11           Wedstrijd                        Match  1.021416e+09
# 15           Wedstrijd                        Match  1.021416e+09
# 17           Wedstrijd                        Match  1.021416e+09
# 21           Wedstrijd                        Match  1.021416e+09
# 23           Wedstrijd                        Match  1.021416e+09
# 27           Wedstrijd                        Match  1.021416e+09
# 29           Wedstrijd                        Match  1.021416e+09
# 32           Wedstrijd                        Match  1.021416e+09
# 36           Wedstrijd                        Match  1.021416e+09
# 40           Wedstrijd                        Match  1.021227e+09
# 44           Wedstrijd                        Match  1.021227e+09
# 46           Wedstrijd                        Match  1.021227e+09
# 47           Wedstrijd                        Match  1.021227e+09
# 49           Wedstrijd                        Match  1.021227e+09
# 53           Wedstrijd                        Match  1.021227e+09
# 55           Wedstrijd                        Match  1.021227e+09
# 58           Wedstrijd                        Match  1.021227e+09
# 59           Wedstrijd                        Match  1.021227e+09
# 62           Wedstrijd                        Match  1.021227e+09
# 77           Wedstrijd                        Match  1.022328e+09
# 79           Wedstrijd                        Match  1.022328e+09
# 83           Wedstrijd                        Match  1.021227e+09
# 85           Wedstrijd                        Match  1.021227e+09
# 88           Wedstrijd                        Match  1.022397e+09
# 92           Wedstrijd                        Match  1.022397e+09
# 95           Wedstrijd                        Match  1.021227e+09
# 97           Wedstrijd                        Match  1.021227e+09
# 98           Wedstrijd                        Match  1.021227e+09
# 100          Wedstrijd                        Match  1.021227e+09
# 104          Wedstrijd                        Match  1.021227e+09
# 130          Wedstrijd                        Match  1.021173e+09
# 131          Wedstrijd                        Match  1.021173e+09
# 133          Wedstrijd                        Match  1.021173e+09
#
#        outcome_id outcome_label outcome_english_label    odds  line  \
# 9    3.598716e+09             1                     1  1250.0   NaN
# 11   3.598716e+09             2                     2  4250.0   NaN
# 15   3.598712e+09             1                     1  1520.0   NaN
# 17   3.598712e+09             2                     2  2700.0   NaN
# 21   3.598255e+09             1                     1  1300.0   NaN
# 23   3.598255e+09             2                     2  3700.0   NaN
# 27   3.598718e+09             1                     1  1630.0   NaN
# 29   3.598718e+09             2                     2  2430.0   NaN
# 32   3.598724e+09             2                     2  1710.0   NaN
# 36   3.598724e+09             1                     1  2250.0   NaN
# 40   3.598100e+09             2                     2  2950.0   NaN
# 44   3.598100e+09             1                     1  1480.0   NaN
# 46   3.598105e+09             2                     2  1190.0   NaN
# 47   3.598105e+09             1                     1  5250.0   NaN
# 49   3.598105e+09             2                     2  1190.0   NaN
# 53   3.598108e+09             1                     1  2230.0   NaN
# 131                  Ratiopharm Ulm    1  2024-12-23T10:05:55Z
# 133                        Besiktas    2  2024-12-23T10:05:55Z
#
#     odds_fractional  odds_american status cash_out_status  home_score  \
# 9               1/4         -400.0   OPEN         ENABLED         NaN
# 11             13/4          325.0   OPEN         ENABLED         NaN
# 15            13/25         -195.0   OPEN         ENABLED         NaN
# 17            17/10          170.0   OPEN         ENABLED         NaN
# 21             3/10         -335.0   OPEN         ENABLED         NaN
# 23            27/10          270.0   OPEN         ENABLED         NaN
# 27             8/13         -159.0   OPEN         ENABLED         NaN
# 29              7/5          143.0   OPEN         ENABLED         NaN
# 32             7/10         -141.0   OPEN         ENABLED         NaN
# 36              5/4          125.0   OPEN         ENABLED         NaN
# 40            39/20          195.0   OPEN         ENABLED         NaN
# 44            12/25         -210.0   OPEN         ENABLED         NaN
# 46             2/11         -530.0   OPEN         ENABLED         NaN
# 47             17/4          425.0   OPEN         ENABLED         NaN
# 49             2/11         -530.0   OPEN         ENABLED         NaN
# 53              6/5          123.0   OPEN         ENABLED         NaN
# 55              3/4         -132.0   OPEN         ENABLED         NaN
# 58             7/10         -143.0   OPEN         ENABLED         NaN
# 59            27/20          135.0   OPEN         ENABLED         NaN
# 62            27/20          135.0   OPEN         ENABLED         NaN
# 77             4/11         -265.0   OPEN         ENABLED         NaN
# 79            49/20          245.0   OPEN         ENABLED         NaN
# 83            59/50          118.0   OPEN         ENABLED         NaN
# 85            10/13         -127.0   OPEN         ENABLED         NaN
# 88              5/4          128.0   OPEN         ENABLED         NaN
# 92             8/11         -136.0   OPEN         ENABLED         NaN
# 95            Evens          102.0   OPEN         ENABLED         NaN
# 97            10/11         -108.0   OPEN         ENABLED         NaN
# 98            Evens          102.0   OPEN         ENABLED         NaN
# 100             5/4          128.0   OPEN         ENABLED         NaN
# 104            8/11         -136.0   OPEN         ENABLED         NaN
# 130           19/20         -105.0   OPEN         ENABLED         NaN
# 131           19/20         -105.0   OPEN         ENABLED         NaN
# 133           19/20         -105.0   OPEN         ENABLED         NaN
#
#      away_score                                         event_name  \
# 9           NaN               New York Knicks vs San Antonio Spurs
# 11          NaN               New York Knicks vs San Antonio Spurs
# 15          NaN         Dallas Mavericks vs Minnesota Timberwolves
# 17          NaN         Dallas Mavericks vs Minnesota Timberwolves
# 21          NaN               Boston Celtics vs Philadelphia 76ers
# 23          NaN               Boston Celtics vs Philadelphia 76ers
# 27          NaN        Golden State Warriors vs Los Angeles Lakers
# 29          NaN        Golden State Warriors vs Los Angeles Lakers
# 32          NaN                     Phoenix Suns vs Denver Nuggets
# 36          NaN                     Phoenix Suns vs Denver Nuggets
# 40          NaN                          AS Monaco vs Anadolu Efes
# 44          NaN                          AS Monaco vs Anadolu Efes
# 46          NaN              Alba Berlin vs Real Madrid Baloncesto
# 47          NaN              Alba Berlin vs Real Madrid Baloncesto
# 49          NaN              Alba Berlin vs Real Madrid Baloncesto
# 53          NaN                Maccabi Tel Aviv vs Žalgiris Kaunas
# 55          NaN                Maccabi Tel Aviv vs Žalgiris Kaunas
# 58          NaN   A|X Armani Exchange Milano vs Olympiacos Piraeus
# 59          NaN   A|X Armani Exchange Milano vs Olympiacos Piraeus
# 62          NaN   A|X Armani Exchange Milano vs Olympiacos Piraeus
# 77          NaN           FC Barcelona vs KK Crvena Zvezda Belgrad
# 79          NaN           FC Barcelona vs KK Crvena Zvezda Belgrad
# 83          NaN                 FC Bayern München vs Panathinaikos
# 85          NaN                 FC Bayern München vs Panathinaikos
# 88          NaN               Partizan Belgrade vs Fenerbahçe Beko
# 92          NaN               Partizan Belgrade vs Fenerbahçe Beko
# 95          NaN     Cazoo Baskonia Vitoria-Gasteiz vs Paris Basket
# 97          NaN     Cazoo Baskonia Vitoria-Gasteiz vs Paris Basket
# 98          NaN     Cazoo Baskonia Vitoria-Gasteiz vs Paris Basket
# 100         NaN  Segafredo Virtus Bologna vs Asvel Lyon-Villeur...
# 104         NaN  Segafredo Virtus Bologna vs Asvel Lyon-Villeur...
# 130         NaN                         Ratiopharm Ulm vs Besiktas
# 131         NaN                         Ratiopharm Ulm vs Besiktas
# 133         NaN                         Ratiopharm Ulm vs Besiktas
#
#         sport_y group_name
# 9    BASKETBALL        NaN
# 11   BASKETBALL        NaN
# 15   BASKETBALL        NaN
# 17   BASKETBALL        NaN
# 21   BASKETBALL        NaN
# 23   BASKETBALL        NaN
# 27   BASKETBALL        NaN
# 29   BASKETBALL        NaN
# 32   BASKETBALL        NaN
# 36   BASKETBALL        NaN
# 40   BASKETBALL        NaN
# 44   BASKETBALL        NaN
# 46   BASKETBALL        NaN
# 47   BASKETBALL        NaN
# 49   BASKETBALL        NaN
# 53   BASKETBALL        NaN
# 55   BASKETBALL        NaN
# 58   BASKETBALL        NaN
# 59   BASKETBALL        NaN
# 62   BASKETBALL        NaN
# 77   BASKETBALL        NaN
# 79   BASKETBALL        NaN
# 83   BASKETBALL        NaN
# 85   BASKETBALL        NaN
# 88   BASKETBALL        NaN
# 92   BASKETBALL        NaN
# 95   BASKETBALL        NaN
# 97   BASKETBALL        NaN
# 98   BASKETBALL        NaN
# 100  BASKETBALL        NaN
# 104  BASKETBALL        NaN
# 130  BASKETBALL    EuroCup
# 131  BASKETBALL    EuroCup
# 133  BASKETBALL    EuroCup

# %% [markdown]
# ## Over/Under

# %%
# filter down to suitable betting opps
kambi_filtered_basketbal = kambi_raw_basketbal[kambi_raw_basketbal['bet_offer_type_english_name'].isin(['Match', 'Odd/Even', 'Player Occurrence Line', 'Asian Over/Under', 'Over/Under', 'Handicap', 'Asian Handicap', 'Yes/No', 'Head to Head'])]
toto_filtered_basketbal = toto_raw_basketbal[toto_raw_basketbal['Outcome Type'].isin(['--', 'DN', 'OE', 'HH', 'HL', 'AG'])]

kambi_filtered_basketbal = kambi_raw_basketbal
toto_filtered_basketbal = toto_raw_basketbal[toto_raw_basketbal['Outcome Type'].isin(['DN', 'OE', 'HH', 'HL', 'AG'])]

# Remove duplicates in toto_filtered_basketbal based on specified columns
toto_filtered_basketbal = toto_filtered_basketbal.drop_duplicates(
    subset=['Event Name', 'Market Name', 'Outcome Name']
)
# Remove duplicates in kambi_filtered_basketbal based on specified columns
kambi_filtered_basketbal = kambi_filtered_basketbal.drop_duplicates(
    subset=['event_name', 'outcome_label', 'criterion_label']
)

# %%
kambi_filtered_basketbal_overunder = kambi_filtered_basketbal[kambi_filtered_basketbal['bet_offer_type_name'].str.contains('Over')]
toto_filtered_basketbal_overunder = toto_filtered_basketbal[(toto_filtered_basketbal['Outcome Name'].str.contains('Over')) | (toto_filtered_basketbal['Outcome Name'].str.contains('Under'))]

kambi_filtered_basketbal_overunder['Participant_1'] = kambi_filtered_basketbal_overunder['event_name'].str.split(' vs ').str[0]
kambi_filtered_basketbal_overunder['Participant_2'] = kambi_filtered_basketbal_overunder['event_name'].str.split(' vs ').str[1]
# Fill the 'overunderparty' column based on conditions
kambi_filtered_basketbal_overunder['OverUnderType'] = kambi_filtered_basketbal_overunder.apply(
    lambda row: 1 if row['Participant_1'] in row['criterion_label'] 
                else 2 if row['Participant_2'] in row['criterion_label'] 
                else 3 if 'Totaal Aantal' in row['criterion_label']
                else None, 
    axis=1
)
kambi_filtered_basketbal_overunder['TimeScale'] = kambi_filtered_basketbal_overunder.apply(
    lambda row: '1e Kwart' if '1e Kwart'in row['criterion_label'] 
                else '2e Kwart' if '2e Kwart' in row['criterion_label'] 
                else '3e Kwart' if '3e Kwart' in row['criterion_label'] 
                else '4e Kwart' if '4e Kwart' in row['criterion_label'] 
                else '1e Helft' if '1e Helft' in row['criterion_label'] 
                else '2e Helft' if '2e Helft' in row['criterion_label']                
                else 'Inclusief Extra Tijd' if 'Full Time' in row['criterion_label'] 
                else None, 
    axis=1
)

toto_filtered_basketbal_overunder['Participant_1'] = toto_filtered_basketbal_overunder['Event Name'].str.split(' vs ').str[0]
toto_filtered_basketbal_overunder['Participant_2'] = toto_filtered_basketbal_overunder['Event Name'].str.split(' vs ').str[1]
toto_filtered_basketbal_overunder['Line'] = toto_filtered_basketbal_overunder['Market Name'].str.split('Under ').str[1]

# Fill the 'overunderparty' column based on conditions
toto_filtered_basketbal_overunder['OverUnderType'] = toto_filtered_basketbal_overunder.apply(
    lambda row: 1 if row['Participant_1'] in row['Market Name'] 
                else 2 if row['Participant_2'] in row['Market Name'] 
                else 3 if 'Aantal Punten' in row['Market Name'] 
                else None, 
    axis=1
)
toto_filtered_basketbal_overunder['TimeScale'] = toto_filtered_basketbal_overunder.apply(
    lambda row: '1e Helft' if '1e Helft' in row['Market Name']          
                else 'Inclusief Extra Tijd' if 'Full Time' in row['Market Name']
                else None, 
    axis=1
)
# Out:
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_1874/156776043.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_basketbal_overunder['Participant_1'] = kambi_filtered_basketbal_overunder['event_name'].str.split(' vs ').str[0]
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_1874/156776043.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_basketbal_overunder['Participant_2'] = kambi_filtered_basketbal_overunder['event_name'].str.split(' vs ').str[1]
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_1874/156776043.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_basketbal_overunder['OverUnderType'] = kambi_filtered_basketbal_overunder.apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_1874/156776043.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_basketbal_overunder['TimeScale'] = kambi_filtered_basketbal_overunder.apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_1874/156776043.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_basketbal_overunder['Participant_1'] = toto_filtered_basketbal_overunder['Event Name'].str.split(' vs ').str[0]
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_1874/156776043.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_basketbal_overunder['Participant_2'] = toto_filtered_basketbal_overunder['Event Name'].str.split(' vs ').str[1]
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_1874/156776043.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_basketbal_overunder['Line'] = toto_filtered_basketbal_overunder['Market Name'].str.split('Under ').str[1]
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_1874/156776043.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_basketbal_overunder['OverUnderType'] = toto_filtered_basketbal_overunder.apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_1874/156776043.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toto_filtered_basketbal_overunder['TimeScale'] = toto_filtered_basketbal_overunder.apply(

# %%
from rapidfuzz import process, fuzz
import pandas as pd

# Helper function to find the best fuzzy match
def fuzzy_match(value, choices, threshold=70):
    match = process.extractOne(
        value, choices, scorer=fuzz.ratio
    )  # Get the best match and its score
    if match and match[1] >= threshold:  # Check if score meets the threshold
        return match[0]  # Return the matched value
    return None  # No match found

# Create fuzzy-matched columns for Participant_1 and Participant_2
kambi_filtered_basketbal_overunder['Fuzzy_Participant_1'] = kambi_filtered_basketbal_overunder['Participant_1'].apply(
    lambda x: fuzzy_match(x, toto_filtered_basketbal_overunder['Participant_1'].unique())
)

kambi_filtered_basketbal_overunder['Fuzzy_Participant_2'] = kambi_filtered_basketbal_overunder['Participant_2'].apply(
    lambda x: fuzzy_match(x, toto_filtered_basketbal_overunder['Participant_2'].unique())
)

# Merge the DataFrames using the fuzzy-matched columns
merged_basketbal_overunder = pd.merge(
    kambi_filtered_basketbal_overunder,
    toto_filtered_basketbal_overunder,
    left_on=['Fuzzy_Participant_1', 'Fuzzy_Participant_2', 'OverUnderType', 'TimeScale'],
    right_on=['Participant_1', 'Participant_2', 'OverUnderType', 'TimeScale'],
    suffixes=('_kambi', '_toto'),
    how='inner'  # Perform an inner join
)

# Display the merged DataFrame
# print(merged_basketbal_overunder)
# Out:
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_1874/2127083471.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_basketbal_overunder['Fuzzy_Participant_1'] = kambi_filtered_basketbal_overunder['Participant_1'].apply(
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_1874/2127083471.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_basketbal_overunder['Fuzzy_Participant_2'] = kambi_filtered_basketbal_overunder['Participant_2'].apply(

# %%
merged_basketbal_overunder
# Out:
#      bet_offer_id  criterion_id                              criterion_label  \
# 0      2481382764    1001159509  Totaal Aantal Punten - Inclusief Extra Tijd
# 1      2481382764    1001159509  Totaal Aantal Punten - Inclusief Extra Tijd
# 2      2481382764    1001159509  Totaal Aantal Punten - Inclusief Extra Tijd
# 3      2481382764    1001159509  Totaal Aantal Punten - Inclusief Extra Tijd
# 4      2481382764    1001159509  Totaal Aantal Punten - Inclusief Extra Tijd
# ..            ...           ...                                          ...
# 275    2481529701    1001159947              Totaal Aantal Punten - 1e Helft
# 276    2481529701    1001159947              Totaal Aantal Punten - 1e Helft
# 277    2481529701    1001159947              Totaal Aantal Punten - 1e Helft
# 278    2481529701    1001159947              Totaal Aantal Punten - 1e Helft
# 279    2481529701    1001159947              Totaal Aantal Punten - 1e Helft
#
#                criterion_english_label occurrence_type            lifetime  \
# 0    Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# 1    Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# 2    Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# 3    Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# 4    Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# ..                                 ...             ...                 ...
# 275            Total Points - 1st Half          POINTS                 NaN
# 276            Total Points - 1st Half          POINTS                 NaN
# 277            Total Points - 1st Half          POINTS                 NaN
# 278            Total Points - 1st Half          POINTS                 NaN
# 279            Total Points - 1st Half          POINTS                 NaN
#
#      bet_offer_type_id bet_offer_type_name bet_offer_type_english_name  \
# 0                    6          Over/Onder                  Over/Under
# 1                    6          Over/Onder                  Over/Under
# 2                    6          Over/Onder                  Over/Under
# 3                    6          Over/Onder                  Over/Under
# 4                    6          Over/Onder                  Over/Under
# ..                 ...                 ...                         ...
# 275                  6          Over/Onder                  Over/Under
# 276                  6          Over/Onder                  Over/Under
# 277                  6          Over/Onder                  Over/Under
# 278                  6          Over/Onder                  Over/Under
# 279                  6          Over/Onder                  Over/Under
#
#      event_id_kambi  outcome_id outcome_label outcome_english_label    odds  \
# 0        1021227408  3598606900      Meer dan                  Over  1960.0
# 1        1021227408  3598606900      Meer dan                  Over  1960.0
# 2        1021227408  3598606900      Meer dan                  Over  1960.0
# 3        1021227408  3598606900      Meer dan                  Over  1960.0
# 4        1021227408  3598606900      Meer dan                  Over  1960.0
# ..              ...         ...           ...                   ...     ...
# 275      1021415721  3599166505      Meer dan                  Over  1670.0
# 276      1021415721  3599166508    Minder dan                 Under  2100.0
# 277      1021415721  3599166508    Minder dan                 Under  2100.0
# 278      1021415721  3599166508    Minder dan                 Under  2100.0
# 279      1021415721  3599166508    Minder dan                 Under  2100.0
#
#          line participant      type          changed_date odds_fractional  \
# 0    172000.0         NaN   OT_OVER  2024-12-24T17:18:42Z           19/20
# 1    172000.0         NaN   OT_OVER  2024-12-24T17:18:42Z           19/20
# 2    172000.0         NaN   OT_OVER  2024-12-24T17:18:42Z           19/20
# 3    172000.0         NaN   OT_OVER  2024-12-24T17:18:42Z           19/20
# 4    172000.0         NaN   OT_OVER  2024-12-24T17:18:42Z           19/20
# ..        ...         ...       ...                   ...             ...
# 275  116500.0         NaN   OT_OVER  2024-12-25T11:01:40Z             4/6
# 276  116500.0         NaN  OT_UNDER  2024-12-25T11:01:40Z           11/10
# 277  116500.0         NaN  OT_UNDER  2024-12-25T11:01:40Z           11/10
# 278  116500.0         NaN  OT_UNDER  2024-12-25T11:01:40Z           11/10
# 279  116500.0         NaN  OT_UNDER  2024-12-25T11:01:40Z           11/10
#
#      odds_american status cash_out_status  home_score  away_score  \
# 0           -105.0   OPEN         ENABLED         NaN         NaN
# 1           -105.0   OPEN         ENABLED         NaN         NaN
# 2           -105.0   OPEN         ENABLED         NaN         NaN
# 3           -105.0   OPEN         ENABLED         NaN         NaN
# 4           -105.0   OPEN         ENABLED         NaN         NaN
# ..             ...    ...             ...         ...         ...
# 275         -150.0   OPEN         ENABLED         NaN         NaN
# 276          110.0   OPEN         ENABLED         NaN         NaN
# 277          110.0   OPEN         ENABLED         NaN         NaN
# 278          110.0   OPEN         ENABLED         NaN         NaN
# 279          110.0   OPEN         ENABLED         NaN         NaN
#
#                          event_name sport_kambi group_name  \
# 0         AS Monaco vs Anadolu Efes  BASKETBALL        NaN
# 1         AS Monaco vs Anadolu Efes  BASKETBALL        NaN
# 2         AS Monaco vs Anadolu Efes  BASKETBALL        NaN
# 3         AS Monaco vs Anadolu Efes  BASKETBALL        NaN
# 4         AS Monaco vs Anadolu Efes  BASKETBALL        NaN
# ..                              ...         ...        ...
# 275  Phoenix Suns vs Denver Nuggets  BASKETBALL        NaN
# 276  Phoenix Suns vs Denver Nuggets  BASKETBALL        NaN
# 277  Phoenix Suns vs Denver Nuggets  BASKETBALL        NaN
# 278  Phoenix Suns vs Denver Nuggets  BASKETBALL        NaN
# 279  Phoenix Suns vs Denver Nuggets  BASKETBALL        NaN
#
#     Participant_1_kambi Participant_2_kambi  OverUnderType TimeScale  \
# 0             AS Monaco        Anadolu Efes              3      None
# 1             AS Monaco        Anadolu Efes              3      None
# 2             AS Monaco        Anadolu Efes              3      None
# 3             AS Monaco        Anadolu Efes              3      None
# 4             AS Monaco        Anadolu Efes              3      None
# ..                  ...                 ...            ...       ...
# 275        Phoenix Suns      Denver Nuggets              3  1e Helft
# 276        Phoenix Suns      Denver Nuggets              3  1e Helft
# 277        Phoenix Suns      Denver Nuggets              3  1e Helft
# 278        Phoenix Suns      Denver Nuggets              3  1e Helft
# 279        Phoenix Suns      Denver Nuggets              3  1e Helft
#
#     Fuzzy_Participant_1    Fuzzy_Participant_2  event_id_toto  \
# 0             AS Monaco  Anadolu Efes Istanbul        6255851
# 1             AS Monaco  Anadolu Efes Istanbul        6255851
# 2             AS Monaco  Anadolu Efes Istanbul        6255851
# 3             AS Monaco  Anadolu Efes Istanbul        6255851
# 4             AS Monaco  Anadolu Efes Istanbul        6255851
# ..                  ...                    ...            ...
# 275        Phoenix Suns         Denver Nuggets        5095864
# 276        Phoenix Suns         Denver Nuggets        5095864
# 277        Phoenix Suns         Denver Nuggets        5095864
# 278        Phoenix Suns         Denver Nuggets        5095864
# 279        Phoenix Suns         Denver Nuggets        5095864
#
#                              Event Name  \
# 0    AS Monaco vs Anadolu Efes Istanbul
# 1    AS Monaco vs Anadolu Efes Istanbul
# 2    AS Monaco vs Anadolu Efes Istanbul
# 3    AS Monaco vs Anadolu Efes Istanbul
# 4    AS Monaco vs Anadolu Efes Istanbul
# ..                                  ...
# 275      Phoenix Suns vs Denver Nuggets
# 276      Phoenix Suns vs Denver Nuggets
# 277      Phoenix Suns vs Denver Nuggets
# 278      Phoenix Suns vs Denver Nuggets
# 279      Phoenix Suns vs Denver Nuggets
#
#                                      Market Name Outcome Name  Odds (Decimal)  \
# 0               Aantal Punten - Over/Under 171.5         Over            1.91
# 1               Aantal Punten - Over/Under 171.5        Under            1.87
# 2               Aantal Punten - Over/Under 172.0         Over            1.95
# 3               Aantal Punten - Over/Under 172.0        Under            1.83
# 4               Aantal Punten - Over/Under 171.0        Under            1.93
# ..                                           ...          ...             ...
# 275  1e Helft - Aantal Punten - Over/Under 119.5        Under            1.80
# 276  1e Helft - Aantal Punten - Over/Under 118.5         Over            1.83
# 277  1e Helft - Aantal Punten - Over/Under 118.5        Under            1.93
# 278  1e Helft - Aantal Punten - Over/Under 119.5         Over            1.95
# 279  1e Helft - Aantal Punten - Over/Under 119.5        Under            1.80
#
#      Price Numerator  Price Denominator Outcome Type Outcome SubType  \
# 0                 91                100           HL               1
# 1                 87                100           HL               L
# 2                 19                 20           HL               1
# 3                 83                100           HL               L
# 4                 93                100           HL               L
# ..               ...                ...          ...             ...
# 275                4                  5           HL               L
# 276               83                100           HL               1
# 277               93                100           HL               L
# 278               19                 20           HL               1
# 279                4                  5           HL               L
#
#     sport_toto        competition Participant_1_toto     Participant_2_toto  \
# 0    Basketbal  Euroleague Mannen          AS Monaco  Anadolu Efes Istanbul
# 1    Basketbal  Euroleague Mannen          AS Monaco  Anadolu Efes Istanbul
# 2    Basketbal  Euroleague Mannen          AS Monaco  Anadolu Efes Istanbul
# 3    Basketbal  Euroleague Mannen          AS Monaco  Anadolu Efes Istanbul
# 4    Basketbal  Euroleague Mannen          AS Monaco  Anadolu Efes Istanbul
# ..         ...                ...                ...                    ...
# 275  Basketbal                NBA       Phoenix Suns         Denver Nuggets
# 276  Basketbal                NBA       Phoenix Suns         Denver Nuggets
# 277  Basketbal                NBA       Phoenix Suns         Denver Nuggets
# 278  Basketbal                NBA       Phoenix Suns         Denver Nuggets
# 279  Basketbal                NBA       Phoenix Suns         Denver Nuggets
#
#       Line
# 0    171.5
# 1    171.5
# 2    172.0
# 3    172.0
# 4    171.0
# ..     ...
# 275  119.5
# 276  118.5
# 277  118.5
# 278  119.5
# 279  119.5
#
# [280 rows x 47 columns]

# %%
[i for i in list(set(toto_filtered_basketbal_overunder['Market Name']))]
# Out:
# ['Okapi Aalstar Aantal Punten - Over/Under 80.5',
#  'Okapi Aalstar Aantal Punten - Over/Under 80.0',
#  'Olympiacos Piraeus Aantal Punten - Over/Under 85.0',
#  'Real Madrid Aantal Punten - Over/Under 91.5',
#  'Aantal Punten - Over/Under 201.0',
#  'Aantal Punten - Over/Under 171.0',
#  'Fortaleza Basquete Cearense Aantal Punten - Over/Under 73.5',
#  'Kangoeroes Basket Mechelen Aantal Punten - Over/Under 79.0',
#  'Bendigo Spirit Aantal Punten - Over/Under 79.0',
#  'AS Monaco Aantal Punten - Over/Under 88.5',
#  'Limburg United Aantal Punten - Over/Under 78.5',
#  'Turk Telekom Aantal Punten - Over/Under 81.5',
#  'Melbourne United Aantal Punten - Over/Under 99.5',
#  'Aantal Punten - Over/Under 222.5',
#  'Guandong Southern Tigers Aantal Punten - Over/Under 111.0',
#  'Aantal Punten - Over/Under 153.5',
#  'Mogi Das Cruzes Aantal Punten - Over/Under 77.0',
#  'Adelaide Lightning Aantal Punten - Over/Under 73.5',
#  'Bendigo Spirit Aantal Punten - Over/Under 77.5',
#  'Real Madrid Aantal Punten - Over/Under 90.0',
#  'Denver Nuggets Aantal Punten - Over/Under 117.0',
#  'Kangoeroes Basket Mechelen Aantal Punten - Over/Under 77.5',
#  'Beijing Ducks Aantal Punten - Over/Under 96.0',
#  'Beşiktaş JK Aantal Punten - Over/Under 85.0',
#  'Qingdao Eagles Aantal Punten - Over/Under 109.5',
#  'Qingdao Eagles Aantal Punten - Over/Under 109.0',
#  'JDA Dijon Basket Aantal Punten - Over/Under 80.5',
#  'Aantal Punten - Over/Under 169.0',
#  'Barcelona Aantal Punten - Over/Under 87.5',
#  'Spirou Charleroi Aantal Punten - Over/Under 75.5',
#  'Minas Tenis Clube MG Aantal Punten - Over/Under 85.5',
#  'Pato Basquete Aantal Punten - Over/Under 82.0',
#  'Sao Jose dos Campos Aantal Punten - Over/Under 72.5',
#  'Zhejiang Golden Bulls Aantal Punten - Over/Under 105.5',
#  'Spirou Charleroi Aantal Punten - Over/Under 74.0',
#  'Aantal Punten - Over/Under 189.5',
#  'Aantal Punten - Over/Under 201.5',
#  'Barcelona Aantal Punten - Over/Under 88.0',
#  'Perth Wildcats Aantal Punten - Over/Under 100.0',
#  'Asvel Lyon Villeurbanne Aantal Punten - Over/Under 84.0',
#  'Guandong Southern Tigers Aantal Punten - Over/Under 109.0',
#  'JDA Dijon Basket Aantal Punten - Over/Under 80.0',
#  'Aantal Punten - Over/Under 195.5',
#  'Maccabi Tel Aviv Aantal Punten - Over/Under 82.5',
#  'Shandong Kirin Aantal Punten - Over/Under 100.5',
#  'Aris Thessaloniki Aantal Punten - Over/Under 76.5',
#  'Leuven Bears Aantal Punten - Over/Under 85.5',
#  'Aantal Punten - Over/Under 157.5',
#  'Alba Berlin Aantal Punten - Over/Under 79.5',
#  'Cairns Taipans Aantal Punten - Over/Under 95.5',
#  'Aris Thessaloniki Aantal Punten - Over/Under 75.5',
#  'Aantal Punten - Over/Under 172.0',
#  'Shanghai Sharks Aantal Punten - Over/Under 124.5',
#  'Asp Promitheas Aantal Punten - Over/Under 83.5',
#  'Aantal Punten - Over/Under 164.5',
#  'Cholet Basket Aantal Punten - Over/Under 86.5',
#  'Aantal Punten - Over/Under 190.5',
#  'EA7 Emporio Armani Milano Aantal Punten - Over/Under 84.0',
#  'Mogi Das Cruzes Aantal Punten - Over/Under 77.5',
#  'Tianjin Pioneers Aantal Punten - Over/Under 96.0',
#  'Beşiktaş JK Aantal Punten - Over/Under 84.5',
#  'Aantal Punten - Over/Under 153.0',
#  'Zhejiang Golden Bulls Aantal Punten - Over/Under 106.0',
#  'Phoenix Brussels Aantal Punten - Over/Under 77.5',
#  'Aantal Punten - Over/Under 162.5',
#  'Phoenix Brussels Aantal Punten - Over/Under 76.5',
#  'Qingdao Eagles Aantal Punten - Over/Under 110.0',
#  'Canberra Capitals Aantal Punten - Over/Under 75.0',
#  'Shandong Kirin Aantal Punten - Over/Under 100.0',
#  'Okapi Aalstar Aantal Punten - Over/Under 79.0',
#  'Qingdao Eagles Aantal Punten - Over/Under 107.0',
#  'Dallas Mavericks Aantal Punten - Over/Under 112.5',
#  'AEK Athene Aantal Punten - Over/Under 83.0',
#  'Aantal Punten - Over/Under 205.5',
#  'Caxias Do Sul Aantal Punten - Over/Under 75.0',
#  'Zorg En Zekerheid Leiden Aantal Punten - Over/Under 76.0',
#  'Aantal Punten - Over/Under 161.0',
#  'Alba Berlin Aantal Punten - Over/Under 81.0',
#  'KK Split Aantal Punten - Over/Under 89.5',
#  'BMS Herlev Wolfpack Aantal Punten - Over/Under 83.5',
#  'Magnolia Hotshots Aantal Punten - Over/Under 93.5',
#  'Den Bosch Basketball Aantal Punten - Over/Under 84.0',
#  'Adelaide Lightning Aantal Punten - Over/Under 73.0',
#  'Aantal Punten - Over/Under 204.5',
#  'Cairns Taipans Aantal Punten - Over/Under 96.0',
#  'Aantal Punten - Over/Under 215.5',
#  'KK Borac Cacak Aantal Punten - Over/Under 80.5',
#  'Unifacisa Aantal Punten - Over/Under 77.0',
#  'Kortrijk Spurs Hse A Aantal Punten - Over/Under 87.0',
#  'BMS Herlev Wolfpack Aantal Punten - Over/Under 83.0',
#  'Beijing Ducks Aantal Punten - Over/Under 93.5',
#  'Aantal Punten - Over/Under 165.5',
#  'Barcelona Aantal Punten - Over/Under 87.0',
#  'Real Madrid Aantal Punten - Over/Under 91.0',
#  'Aantal Punten - Over/Under 156.0',
#  'Phoenix Brussels Aantal Punten - Over/Under 78.0',
#  'Phoenix Brussels Aantal Punten - Over/Under 76.0',
#  'BC Zalgiris Kaunas Aantal Punten - Over/Under 83.5',
#  'Aantal Punten - Over/Under 166.5',
#  'Marousi BC Aantal Punten - Over/Under 78.0',
#  'Aantal Punten - Over/Under 193.5',
#  'Lg Sakers Aantal Punten - Over/Under 75.0',
#  'KK Borac Cacak Aantal Punten - Over/Under 81.5',
#  'Melbourne United Aantal Punten - Over/Under 101.5',
#  'KK Cibona Zagreb Aantal Punten - Over/Under 82.0',
#  'Guandong Southern Tigers Aantal Punten - Over/Under 112.0',
#  'Melbourne United Aantal Punten - Over/Under 99.0',
#  'San Antonio Spurs Aantal Punten - Over/Under 108.0',
#  'Canberra Capitals Aantal Punten - Over/Under 75.5',
#  'Aantal Punten - Over/Under 212.5',
#  'Basketball Academie Limburg Aantal Punten - Over/Under 67.0',
#  '1e Helft - Aantal Punten - Over/Under 114.5',
#  'Lg Sakers Aantal Punten - Over/Under 75.5',
#  'Adelaide Lightning Aantal Punten - Over/Under 74.0',
#  'Spirou Charleroi Aantal Punten - Over/Under 75.0',
#  'Aantal Punten - Over/Under 232.5',
#  'Cairns Taipans Aantal Punten - Over/Under 96.5',
#  'Et Land Elephants Aantal Punten - Over/Under 76.5',
#  'Perth Wildcats Aantal Punten - Over/Under 101.0',
#  'BC Oostende Aantal Punten - Over/Under 87.5',
#  'Kortrijk Spurs Hse A Aantal Punten - Over/Under 87.5',
#  'Lg Sakers Aantal Punten - Over/Under 77.5',
#  'Lg Sakers Aantal Punten - Over/Under 77.0',
#  'Guandong Southern Tigers Aantal Punten - Over/Under 109.5',
#  'Aantal Punten - Over/Under 165.0',
#  'Aantal Punten - Over/Under 164.0',
#  'Shandong Kirin Aantal Punten - Over/Under 102.5',
#  'Aantal Punten - Over/Under 223.5',
#  'KK Mornar Bar Aantal Punten - Over/Under 78.0',
#  'Brasilia Basquete Aantal Punten - Over/Under 80.5',
#  'Le Mans Sarthe Basket Aantal Punten - Over/Under 79.5',
#  'Paris Basketball Aantal Punten - Over/Under 85.5',
#  'Zorg En Zekerheid Leiden Aantal Punten - Over/Under 76.5',
#  'Phoenix Suns Aantal Punten - Over/Under 115.5',
#  'Aantal Punten - Over/Under 168.0',
#  'Bahcesehir Koleji Aantal Punten - Over/Under 81.5',
#  'Lg Sakers Aantal Punten - Over/Under 76.0',
#  'EA7 Emporio Armani Milano Aantal Punten - Over/Under 83.5',
#  'Aantal Punten - Over/Under 156.5',
#  'Minnesota Timberwolves Aantal Punten - Over/Under 108.5',
#  'Aantal Punten - Over/Under 172.5',
#  'Real Madrid Aantal Punten - Over/Under 90.5',
#  'Unifacisa Aantal Punten - Over/Under 76.5',
#  'Aantal Punten - Over/Under 163.5',
#  'BC Oostende Aantal Punten - Over/Under 86.5',
#  'Aris Thessaloniki Aantal Punten - Over/Under 76.0',
#  'Et Land Elephants Aantal Punten - Over/Under 77.5',
#  'Antwerp Giants Aantal Punten - Over/Under 76.0',
#  'KK Crvena Zvezda Mts Aantal Punten - Over/Under 81.5',
#  'Aantal Punten - Over/Under 218.5',
#  'Minas Tenis Clube MG Aantal Punten - Over/Under 86.5',
#  'KK Spartak Subotica Aantal Punten - Over/Under 78.0',
#  'Aantal Punten - Over/Under 211.5',
#  'Sesi Franca BC SP Aantal Punten - Over/Under 86.0',
#  'Limburg United Aantal Punten - Over/Under 77.5',
#  'EC Uniao Corinthians Aantal Punten - Over/Under 79.0',
#  'Bendigo Spirit Aantal Punten - Over/Under 78.5',
#  'BC Oostende Aantal Punten - Over/Under 86.0',
#  'KK Cibona Zagreb Aantal Punten - Over/Under 82.5',
#  'Perth Lynx Aantal Punten - Over/Under 85.0',
#  'Shanghai Sharks Aantal Punten - Over/Under 122.5',
#  'Ratiopharm Ulm Aantal Punten - Over/Under 84.5',
#  'Et Land Elephants Aantal Punten - Over/Under 76.0',
#  'Fujian Sturgeons Aantal Punten - Over/Under 94.5',
#  'Qingdao Eagles Aantal Punten - Over/Under 106.0',
#  'Den Bosch Basketball Aantal Punten - Over/Under 82.5',
#  'EC Uniao Corinthians Aantal Punten - Over/Under 78.5',
#  'Shandong Kirin Aantal Punten - Over/Under 99.0',
#  'Caxias Do Sul Aantal Punten - Over/Under 74.0',
#  'EC Uniao Corinthians Aantal Punten - Over/Under 79.5',
#  'Et Land Elephants Aantal Punten - Over/Under 78.0',
#  'San Antonio Spurs Aantal Punten - Over/Under 107.0',
#  'Real Madrid Aantal Punten - Over/Under 89.5',
#  'AS Monaco Aantal Punten - Over/Under 88.0',
#  'Minas Tenis Clube MG Aantal Punten - Over/Under 86.0',
#  'Aantal Punten - Over/Under 148.5',
#  'Leuven Bears Aantal Punten - Over/Under 86.0',
#  'Golden State Warriors Aantal Punten - Over/Under 113.5',
#  'Bayern München Aantal Punten - Over/Under 85.0',
#  'Aantal Punten - Over/Under 233.5',
#  'Anadolu Efes Istanbul Aantal Punten - Over/Under 83.5',
#  'Beijing Ducks Aantal Punten - Over/Under 93.0',
#  'Melbourne United Aantal Punten - Over/Under 100.0',
#  'Tianjin Pioneers Aantal Punten - Over/Under 94.5',
#  'Guandong Southern Tigers Aantal Punten - Over/Under 108.5',
#  'Caxias Do Sul Aantal Punten - Over/Under 74.5',
#  'Aantal Punten - Over/Under 160.5',
#  'New York Knicks Aantal Punten - Over/Under 117.0',
#  'EA7 Emporio Armani Milano Aantal Punten - Over/Under 82.5',
#  'Botafogo Aantal Punten - Over/Under 75.5',
#  'Melbourne United Aantal Punten - Over/Under 101.0',
#  'Saski Baskonia Aantal Punten - Over/Under 85.5',
#  'Beşiktaş JK Aantal Punten - Over/Under 85.5',
#  'Adelaide 36Ers Aantal Punten - Over/Under 101.5',
#  'Et Land Elephants Aantal Punten - Over/Under 78.5',
#  'New York Knicks Aantal Punten - Over/Under 116.0',
#  'Aantal Punten - Over/Under 214.5',
#  'Aantal Punten - Over/Under 217.5',
#  'Leuven Bears Aantal Punten - Over/Under 85.0',
#  'Dallas Mavericks Aantal Punten - Over/Under 113.5',
#  'Cairns Taipans Aantal Punten - Over/Under 97.0',
#  'Cairns Taipans Aantal Punten - Over/Under 97.5',
#  'Adelaide Lightning Aantal Punten - Over/Under 74.5',
#  'BCM Gravelines Dunkerque Aantal Punten - Over/Under 82.0',
#  'Anadolu Efes Istanbul Aantal Punten - Over/Under 82.5',
#  'Sao Jose dos Campos Aantal Punten - Over/Under 73.0',
#  'Minnesota Timberwolves Aantal Punten - Over/Under 109.0',
#  'Sesi Franca BC SP Aantal Punten - Over/Under 87.0',
#  'Aantal Punten - Over/Under 197.5',
#  'Saski Baskonia Aantal Punten - Over/Under 86.5',
#  'Bendigo Spirit Aantal Punten - Over/Under 77.0',
#  'Melbourne United Aantal Punten - Over/Under 100.5',
#  'BC Oostende Aantal Punten - Over/Under 87.0',
#  'Fenerbahçe Aantal Punten - Over/Under 79.5',
#  'Panathinaikos BC Aantal Punten - Over/Under 86.0',
#  'Aantal Punten - Over/Under 224.5',
#  'Le Mans Sarthe Basket Aantal Punten - Over/Under 79.0',
#  'Aantal Punten - Over/Under 167.0',
#  'Phoenix Brussels Aantal Punten - Over/Under 77.0',
#  'Zhejiang Golden Bulls Aantal Punten - Over/Under 105.0',
#  'Fenerbahçe Aantal Punten - Over/Under 80.0',
#  'Shandong Kirin Aantal Punten - Over/Under 99.5',
#  'Olympiacos Piraeus Aantal Punten - Over/Under 84.5',
#  'BCM Gravelines Dunkerque Aantal Punten - Over/Under 81.0',
#  'Aantal Punten - Over/Under 207.5',
#  'BC Zalgiris Kaunas Aantal Punten - Over/Under 82.5',
#  'Barangay Ginebra San Miguel Aantal Punten - Over/Under 97.5',
#  'Asvel Lyon Villeurbanne Aantal Punten - Over/Under 83.0',
#  'Cairns Taipans Aantal Punten - Over/Under 95.0',
#  'Fortaleza Basquete Cearense Aantal Punten - Over/Under 74.5',
#  'Tianjin Pioneers Aantal Punten - Over/Under 95.0',
#  'KK Zadar Aantal Punten - Over/Under 75.5',
#  'Bauru Basket SP Aantal Punten - Over/Under 73.0',
#  'Virtus Bologna Aantal Punten - Over/Under 84.5',
#  'AEK Athene Aantal Punten - Over/Under 83.5',
#  'Aantal Punten - Over/Under 168.5',
#  'Fujian Sturgeons Aantal Punten - Over/Under 98.5',
#  'Aantal Punten - Over/Under 202.0',
#  'Shandong Kirin Aantal Punten - Over/Under 101.0',
#  'Aantal Punten - Over/Under 209.5',
#  'Vaerlose BBK Aantal Punten - Over/Under 81.0',
#  'AEK Athene Aantal Punten - Over/Under 84.0',
#  'JDA Dijon Basket Aantal Punten - Over/Under 79.5',
#  'Zhejiang Golden Bulls Aantal Punten - Over/Under 104.5',
#  'Bahcesehir Koleji Aantal Punten - Over/Under 82.5',
#  'Leuven Bears Aantal Punten - Over/Under 86.5',
#  'Aantal Punten - Over/Under 191.5',
#  'Marousi BC Aantal Punten - Over/Under 78.5',
#  'BC Oostende Aantal Punten - Over/Under 88.0',
#  'Flamengo Aantal Punten - Over/Under 85.5',
#  'Aantal Punten - Over/Under 171.5',
#  'Lg Sakers Aantal Punten - Over/Under 74.5',
#  'Canberra Capitals Aantal Punten - Over/Under 76.0',
#  'Botafogo Aantal Punten - Over/Under 76.5',
#  'Beşiktaş JK Aantal Punten - Over/Under 84.0',
#  'New York Knicks Aantal Punten - Over/Under 116.5',
#  'Beijing Ducks Aantal Punten - Over/Under 95.0',
#  'Virtus Bologna Aantal Punten - Over/Under 85.5',
#  'Adelaide 36Ers Aantal Punten - Over/Under 102.0',
#  'Beijing Ducks Aantal Punten - Over/Under 95.5',
#  'Olympiacos Piraeus Aantal Punten - Over/Under 86.0',
#  'EC Pinheiros SP Aantal Punten - Over/Under 81.5',
#  'KK Borac Cacak Aantal Punten - Over/Under 81.0',
#  'KK Zadar Aantal Punten - Over/Under 75.0',
#  'Bahcesehir Koleji Aantal Punten - Over/Under 82.0',
#  'Perth Lynx Aantal Punten - Over/Under 86.0',
#  '1e Helft - Aantal Punten - Over/Under 119.5',
#  'Aantal Punten - Over/Under 157.0',
#  'KK Crvena Zvezda Mts Aantal Punten - Over/Under 80.5',
#  'Et Land Elephants Aantal Punten - Over/Under 77.0',
#  'EA7 Emporio Armani Milano Aantal Punten - Over/Under 83.0',
#  'Paris Basketball Aantal Punten - Over/Under 86.0',
#  'Tianjin Pioneers Aantal Punten - Over/Under 98.0',
#  'Bayern München Aantal Punten - Over/Under 86.0',
#  'Ratiopharm Ulm Aantal Punten - Over/Under 83.5',
#  'Kangoeroes Basket Mechelen Aantal Punten - Over/Under 78.5',
#  'Magnolia Hotshots Aantal Punten - Over/Under 92.5',
#  'Aantal Punten - Over/Under 148.0',
#  'Botafogo Aantal Punten - Over/Under 76.0',
#  'Shandong Kirin Aantal Punten - Over/Under 102.0',
#  'Tianjin Pioneers Aantal Punten - Over/Under 97.5',
#  'Ratiopharm Ulm Aantal Punten - Over/Under 85.0',
#  'Tianjin Pioneers Aantal Punten - Over/Under 95.5',
#  'Kangoeroes Basket Mechelen Aantal Punten - Over/Under 79.5',
#  'Bauru Basket SP Aantal Punten - Over/Under 73.5',
#  'BC Zalgiris Kaunas Aantal Punten - Over/Under 82.0',
#  'Bayern München Aantal Punten - Over/Under 85.5',
#  'Aantal Punten - Over/Under 216.5',
#  'Marousi BC Aantal Punten - Over/Under 77.5',
#  'Aantal Punten - Over/Under 196.0',
#  'Maccabi Tel Aviv Aantal Punten - Over/Under 81.5',
#  'Zhejiang Golden Bulls Aantal Punten - Over/Under 103.0',
#  'EA7 Emporio Armani Milano Aantal Punten - Over/Under 82.0',
#  'Guandong Southern Tigers Aantal Punten - Over/Under 111.5',
#  'KK Spartak Subotica Aantal Punten - Over/Under 78.5',
#  'KK Spartak Subotica Aantal Punten - Over/Under 77.5',
#  'BC Zalgiris Kaunas Aantal Punten - Over/Under 83.0',
#  '1e Helft - Aantal Punten - Over/Under 108.5',
#  'Aantal Punten - Over/Under 162.0',
#  'Aantal Punten - Over/Under 213.5',
#  'Aantal Punten - Over/Under 196.5',
#  'Ratiopharm Ulm Aantal Punten - Over/Under 85.5',
#  'Qingdao Eagles Aantal Punten - Over/Under 106.5',
#  'Lg Sakers Aantal Punten - Over/Under 76.5',
#  'Aantal Punten - Over/Under 155.5',
#  'Beijing Ducks Aantal Punten - Over/Under 97.0',
#  'Spirou Charleroi Aantal Punten - Over/Under 74.5',
#  'Brasilia Basquete Aantal Punten - Over/Under 81.5',
#  'Asvel Lyon Villeurbanne Aantal Punten - Over/Under 83.5',
#  'KK Partizan Nis Belgrade Aantal Punten - Over/Under 82.0',
#  'EC Pinheiros SP Aantal Punten - Over/Under 82.0',
#  'Perth Lynx Aantal Punten - Over/Under 85.5',
#  'Shandong Kirin Aantal Punten - Over/Under 98.5',
#  'Qingdao Eagles Aantal Punten - Over/Under 108.0',
#  'Tianjin Pioneers Aantal Punten - Over/Under 94.0',
#  'Los Angeles Lakers Aantal Punten - Over/Under 110.5',
#  '1e Helft - Aantal Punten - Over/Under 109.5',
#  'Antwerp Giants Aantal Punten - Over/Under 75.5',
#  'Anadolu Efes Istanbul Aantal Punten - Over/Under 83.0',
#  'Zhejiang Golden Bulls Aantal Punten - Over/Under 106.5',
#  'Alba Berlin Aantal Punten - Over/Under 79.0',
#  'Cairns Taipans Aantal Punten - Over/Under 94.5',
#  'Anadolu Efes Istanbul Aantal Punten - Over/Under 84.0',
#  'BC Zalgiris Kaunas Aantal Punten - Over/Under 84.0',
#  'Adelaide 36Ers Aantal Punten - Over/Under 101.0',
#  'Guandong Southern Tigers Aantal Punten - Over/Under 110.5',
#  'Sesi Franca BC SP Aantal Punten - Over/Under 86.5',
#  'Okapi Aalstar Aantal Punten - Over/Under 81.0',
#  'Et Land Elephants Aantal Punten - Over/Under 79.0',
#  'Asp Promitheas Aantal Punten - Over/Under 84.0',
#  'Aantal Punten - Over/Under 199.5',
#  'Barangay Ginebra San Miguel Aantal Punten - Over/Under 96.5',
#  'KK Partizan Nis Belgrade Aantal Punten - Over/Under 81.5',
#  'Flamengo Aantal Punten - Over/Under 86.0',
#  'Aantal Punten - Over/Under 150.5',
#  'Qingdao Eagles Aantal Punten - Over/Under 108.5',
#  'KK Mornar Bar Aantal Punten - Over/Under 77.5',
#  'San Antonio Spurs Aantal Punten - Over/Under 107.5',
#  'Antwerp Giants Aantal Punten - Over/Under 74.0',
#  'Pato Basquete Aantal Punten - Over/Under 81.5',
#  'Magnolia Hotshots Aantal Punten - Over/Under 94.5',
#  'Limburg United Aantal Punten - Over/Under 79.0',
#  '1e Helft - Aantal Punten - Over/Under 112.5',
#  'Aantal Punten - Over/Under 154.0',
#  'Beşiktaş JK Aantal Punten - Over/Under 86.0',
#  'Vaerlose BBK Aantal Punten - Over/Under 81.5',
#  '1e Helft - Aantal Punten - Over/Under 107.5',
#  'Guandong Southern Tigers Aantal Punten - Over/Under 110.0',
#  'Aantal Punten - Over/Under 158.5',
#  '1e Helft - Aantal Punten - Over/Under 115.5',
#  'Qingdao Eagles Aantal Punten - Over/Under 107.5',
#  'Aantal Punten - Over/Under 203.5',
#  'EC Pinheiros SP Aantal Punten - Over/Under 81.0',
#  'Basketball Academie Limburg Aantal Punten - Over/Under 67.5',
#  'Fortaleza Basquete Cearense Aantal Punten - Over/Under 74.0',
#  'BMS Herlev Wolfpack Aantal Punten - Over/Under 84.0',
#  '1e Helft - Aantal Punten - Over/Under 113.5',
#  '1e Helft - Aantal Punten - Over/Under 118.5',
#  'Aantal Punten - Over/Under 169.5',
#  'Anadolu Efes Istanbul Aantal Punten - Over/Under 84.5',
#  'Aantal Punten - Over/Under 163.0',
#  'Cholet Basket Aantal Punten - Over/Under 87.0',
#  'Guandong Southern Tigers Aantal Punten - Over/Under 108.0',
#  'Cholet Basket Aantal Punten - Over/Under 86.0',
#  'Aantal Punten - Over/Under 170.5',
#  'Shanghai Sharks Aantal Punten - Over/Under 120.5',
#  'Beijing Ducks Aantal Punten - Over/Under 94.0',
#  'Kortrijk Spurs Hse A Aantal Punten - Over/Under 85.5',
#  'Spirou Charleroi Aantal Punten - Over/Under 73.5',
#  'Aantal Punten - Over/Under 149.0',
#  'Aantal Punten - Over/Under 151.5',
#  'Aantal Punten - Over/Under 219.5',
#  'Paris Basketball Aantal Punten - Over/Under 85.0',
#  'Aantal Punten - Over/Under 151.0',
#  'Minnesota Timberwolves Aantal Punten - Over/Under 108.0',
#  'Fenerbahçe Aantal Punten - Over/Under 80.5',
#  'Vaerlose BBK Aantal Punten - Over/Under 82.0',
#  'KK Mornar Bar Aantal Punten - Over/Under 78.5',
#  'KK Split Aantal Punten - Over/Under 89.0',
#  'Aantal Punten - Over/Under 166.0',
#  'Zhejiang Golden Bulls Aantal Punten - Over/Under 103.5',
#  'Zorg En Zekerheid Leiden Aantal Punten - Over/Under 75.5',
#  'Panathinaikos BC Aantal Punten - Over/Under 86.5',
#  'Aantal Punten - Over/Under 152.0',
#  'Limburg United Aantal Punten - Over/Under 78.0',
#  'Basketball Academie Limburg Aantal Punten - Over/Under 68.5',
#  'Basketball Academie Limburg Aantal Punten - Over/Under 68.0',
#  'AS Monaco Aantal Punten - Over/Under 87.0',
#  'Turk Telekom Aantal Punten - Over/Under 82.5',
#  'Olympiacos Piraeus Aantal Punten - Over/Under 85.5',
#  'Kangoeroes Basket Mechelen Aantal Punten - Over/Under 78.0',
#  'Aantal Punten - Over/Under 225.5',
#  'Flamengo Aantal Punten - Over/Under 86.5',
#  'Antwerp Giants Aantal Punten - Over/Under 75.0',
#  'Kortrijk Spurs Hse A Aantal Punten - Over/Under 86.5',
#  'Sao Jose dos Campos Aantal Punten - Over/Under 73.5',
#  'Leuven Bears Aantal Punten - Over/Under 84.5',
#  'Aantal Punten - Over/Under 197.0',
#  'Shandong Kirin Aantal Punten - Over/Under 101.5',
#  'Aantal Punten - Over/Under 160.0',
#  'Den Bosch Basketball Aantal Punten - Over/Under 82.0',
#  'Alba Berlin Aantal Punten - Over/Under 80.0',
#  'Aantal Punten - Over/Under 170.0',
#  'Maccabi Tel Aviv Aantal Punten - Over/Under 80.5',
#  'Aantal Punten - Over/Under 167.5',
#  'Aantal Punten - Over/Under 159.5',
#  'Zhejiang Golden Bulls Aantal Punten - Over/Under 107.0',
#  'Okapi Aalstar Aantal Punten - Over/Under 79.5',
#  'AS Monaco Aantal Punten - Over/Under 87.5',
#  'Maccabi Tel Aviv Aantal Punten - Over/Under 81.0',
#  'Aantal Punten - Over/Under 220.5',
#  'Perth Wildcats Aantal Punten - Over/Under 100.5',
#  'Ratiopharm Ulm Aantal Punten - Over/Under 84.0',
#  'Asp Promitheas Aantal Punten - Over/Under 84.5',
#  'Zhejiang Golden Bulls Aantal Punten - Over/Under 104.0',
#  'Pato Basquete Aantal Punten - Over/Under 82.5',
#  'Bauru Basket SP Aantal Punten - Over/Under 72.5',
#  '1e Helft - Aantal Punten - Over/Under 110.5',
#  'Den Bosch Basketball Aantal Punten - Over/Under 83.0',
#  'KK Partizan Nis Belgrade Aantal Punten - Over/Under 81.0',
#  'Beijing Ducks Aantal Punten - Over/Under 96.5',
#  'Virtus Bologna Aantal Punten - Over/Under 85.0',
#  'Aantal Punten - Over/Under 231.5',
#  'Maccabi Tel Aviv Aantal Punten - Over/Under 82.0',
#  'Bendigo Spirit Aantal Punten - Over/Under 78.0',
#  'Panathinaikos BC Aantal Punten - Over/Under 87.0',
#  'AS Monaco Aantal Punten - Over/Under 89.0',
#  'Fujian Sturgeons Aantal Punten - Over/Under 96.5',
#  'Aantal Punten - Over/Under 188.5',
#  'Saski Baskonia Aantal Punten - Over/Under 86.0',
#  'Beijing Ducks Aantal Punten - Over/Under 94.5',
#  'Tianjin Pioneers Aantal Punten - Over/Under 97.0',
#  'Basketball Academie Limburg Aantal Punten - Over/Under 66.5',
#  'Barangay Ginebra San Miguel Aantal Punten - Over/Under 95.5',
#  'BCM Gravelines Dunkerque Aantal Punten - Over/Under 81.5',
#  'Kortrijk Spurs Hse A Aantal Punten - Over/Under 86.0',
#  'KK Split Aantal Punten - Over/Under 88.5',
#  'Aantal Punten - Over/Under 161.5',
#  'Melbourne United Aantal Punten - Over/Under 102.0',
#  'KK Crvena Zvezda Mts Aantal Punten - Over/Under 81.0',
#  'KK Zadar Aantal Punten - Over/Under 76.0',
#  'KK Cibona Zagreb Aantal Punten - Over/Under 81.5',
#  'Den Bosch Basketball Aantal Punten - Over/Under 83.5',
#  'Zorg En Zekerheid Leiden Aantal Punten - Over/Under 75.0',
#  'Le Mans Sarthe Basket Aantal Punten - Over/Under 78.5',
#  'Brasilia Basquete Aantal Punten - Over/Under 81.0',
#  'Aantal Punten - Over/Under 152.5',
#  'Tianjin Pioneers Aantal Punten - Over/Under 96.5',
#  'Adelaide Lightning Aantal Punten - Over/Under 72.5',
#  'Aantal Punten - Over/Under 221.5',
#  '1e Helft - Aantal Punten - Over/Under 111.5',
#  'Mogi Das Cruzes Aantal Punten - Over/Under 76.5',
#  'Alba Berlin Aantal Punten - Over/Under 80.5',
#  'Aantal Punten - Over/Under 159.0',
#  'Dallas Mavericks Aantal Punten - Over/Under 113.0',
#  'Zorg En Zekerheid Leiden Aantal Punten - Over/Under 77.0',
#  'Unifacisa Aantal Punten - Over/Under 77.5',
#  'Antwerp Giants Aantal Punten - Over/Under 74.5',
#  'Turk Telekom Aantal Punten - Over/Under 82.0',
#  'Limburg United Aantal Punten - Over/Under 77.0',
#  'Olympiacos Piraeus Aantal Punten - Over/Under 86.5']

# %%
toto_filtered_basketbal_overunder.to_excel('totodev_overunder.xlsx')
kambi_filtered_basketbal_overunder.to_excel('kambidev_overunder.xlsx')

# %%
kambi_filtered_basketbal_overunder[kambi_filtered_basketbal_overunder['OverUnderType']==3]
# Out:
#        bet_offer_id  criterion_id  \
# 37247    2481231962    1001159509
# 37249    2481231962    1001159509
# 37281    2481382764    1001159509
# 37283    2481382764    1001159509
# 37303    2481250457    1001159509
# ...             ...           ...
# 67402    2481524574    1001159509
# 67426    2481467182    1001159509
# 67428    2481467182    1001159509
# 72590    2481232038    1001159509
# 72591    2481232038    1001159509
#
#                                    criterion_label  \
# 37247  Totaal Aantal Punten - Inclusief Extra Tijd
# 37249  Totaal Aantal Punten - Inclusief Extra Tijd
# 37281  Totaal Aantal Punten - Inclusief Extra Tijd
# 37283  Totaal Aantal Punten - Inclusief Extra Tijd
# 37303  Totaal Aantal Punten - Inclusief Extra Tijd
# ...                                            ...
# 67402  Totaal Aantal Punten - Inclusief Extra Tijd
# 67426  Totaal Aantal Punten - Inclusief Extra Tijd
# 67428  Totaal Aantal Punten - Inclusief Extra Tijd
# 72590  Totaal Aantal Punten - Inclusief Extra Tijd
# 72591  Totaal Aantal Punten - Inclusief Extra Tijd
#
#                  criterion_english_label occurrence_type            lifetime  \
# 37247  Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# 37249  Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# 37281  Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# 37283  Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# 37303  Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# ...                                  ...             ...                 ...
# 67402  Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# 67426  Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# 67428  Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# 72590  Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
# 72591  Total Points - Including Overtime          POINTS  FULL_TIME_OVERTIME
#
#        bet_offer_type_id bet_offer_type_name bet_offer_type_english_name  \
# 37247                  6          Over/Onder                  Over/Under
# 37249                  6          Over/Onder                  Over/Under
# 37281                  6          Over/Onder                  Over/Under
# 37283                  6          Over/Onder                  Over/Under
# 37303                  6          Over/Onder                  Over/Under
# ...                  ...                 ...                         ...
# 67402                  6          Over/Onder                  Over/Under
# 67426                  6          Over/Onder                  Over/Under
# 67428                  6          Over/Onder                  Over/Under
# 72590                  6          Over/Onder                  Over/Under
# 72591                  6          Over/Onder                  Over/Under
#
#          event_id  outcome_id outcome_label outcome_english_label    odds  \
# 37247  1021227418  3598105298      Meer dan                  Over  1870.0
# 37249  1021227418  3598105304    Minder dan                 Under  1950.0
# 37281  1021227408  3598606900      Meer dan                  Over  1960.0
# 37283  1021227408  3598606901    Minder dan                 Under  1870.0
# 37303  1021227415  3598108409      Meer dan                  Over  1910.0
# ...           ...         ...           ...                   ...     ...
# 67402  1022413366  3599089445    Minder dan                 Under  1950.0
# 67426  1022412723  3598908427      Meer dan                  Over  1850.0
# 67428  1022412723  3598908428    Minder dan                 Under  1950.0
# 72590  1021173057  3598105715      Meer dan                  Over  1940.0
# 72591  1021173057  3598105717    Minder dan                 Under  1860.0
#
#            line participant      type          changed_date odds_fractional  \
# 37247  169000.0         NaN   OT_OVER  2024-12-24T17:23:59Z           17/20
# 37249  169000.0         NaN  OT_UNDER  2024-12-24T17:23:59Z           19/20
# 37281  172000.0         NaN   OT_OVER  2024-12-24T17:18:42Z           19/20
# 37283  172000.0         NaN  OT_UNDER  2024-12-24T17:18:42Z           17/20
# 37303  164500.0         NaN   OT_OVER  2024-12-23T09:57:10Z           10/11
# ...         ...         ...       ...                   ...             ...
# 67402  132500.0         NaN  OT_UNDER  2024-12-25T07:14:27Z           19/20
# 67426  136500.0         NaN   OT_OVER  2024-12-24T22:26:57Z           17/20
# 67428  136500.0         NaN  OT_UNDER  2024-12-24T22:26:57Z           19/20
# 72590  171000.0         NaN   OT_OVER  2024-12-23T10:05:54Z           23/25
# 72591  171000.0         NaN  OT_UNDER  2024-12-23T10:05:54Z           17/20
#
#        odds_american status cash_out_status  home_score  away_score  \
# 37247         -115.0   OPEN         ENABLED         NaN         NaN
# 37249         -106.0   OPEN         ENABLED         NaN         NaN
# 37281         -105.0   OPEN         ENABLED         NaN         NaN
# 37283         -115.0   OPEN         ENABLED         NaN         NaN
# 37303         -110.0   OPEN         ENABLED         NaN         NaN
# ...              ...    ...             ...         ...         ...
# 67402         -106.0   OPEN         ENABLED         NaN         NaN
# 67426         -118.0   OPEN         ENABLED         NaN         NaN
# 67428         -106.0   OPEN         ENABLED         NaN         NaN
# 72590         -107.0   OPEN         ENABLED         NaN         NaN
# 72591         -117.0   OPEN         ENABLED         NaN         NaN
#
#                                               event_name       sport  \
# 37247              Alba Berlin vs Real Madrid Baloncesto  BASKETBALL
# 37249              Alba Berlin vs Real Madrid Baloncesto  BASKETBALL
# 37281                          AS Monaco vs Anadolu Efes  BASKETBALL
# 37283                          AS Monaco vs Anadolu Efes  BASKETBALL
# 37303                Maccabi Tel Aviv vs Žalgiris Kaunas  BASKETBALL
# ...                                                  ...         ...
# 67402  Hawaii Rainbow Warriors vs Oakland Golden Griz...  BASKETBALL
# 67426       Nebraska Cornhuskers vs Oregon State Beavers  BASKETBALL
# 67428       Nebraska Cornhuskers vs Oregon State Beavers  BASKETBALL
# 72590                         Ratiopharm Ulm vs Besiktas  BASKETBALL
# 72591                         Ratiopharm Ulm vs Besiktas  BASKETBALL
#
#       group_name            Participant_1             Participant_2  \
# 37247        NaN              Alba Berlin    Real Madrid Baloncesto
# 37249        NaN              Alba Berlin    Real Madrid Baloncesto
# 37281        NaN                AS Monaco              Anadolu Efes
# 37283        NaN                AS Monaco              Anadolu Efes
# 37303        NaN         Maccabi Tel Aviv           Žalgiris Kaunas
# ...          ...                      ...                       ...
# 67402        NaN  Hawaii Rainbow Warriors  Oakland Golden Grizzlies
# 67426        NaN     Nebraska Cornhuskers      Oregon State Beavers
# 67428        NaN     Nebraska Cornhuskers      Oregon State Beavers
# 72590    EuroCup           Ratiopharm Ulm                  Besiktas
# 72591    EuroCup           Ratiopharm Ulm                  Besiktas
#
#        OverUnderType
# 37247              3
# 37249              3
# 37281              3
# 37283              3
# 37303              3
# ...              ...
# 67402              3
# 67426              3
# 67428              3
# 72590              3
# 72591              3
#
# [118 rows x 30 columns]

# %%
toto_filtered_basketbal_overunder[toto_filtered_basketbal_overunder['OverUnderType']==3]
# Out:
#        event_id                                         Event Name  \
# 5       5983675  Guandong Southern Tigers vs Zhejiang Golden Bulls
# 6       5983675  Guandong Southern Tigers vs Zhejiang Golden Bulls
# 13      5983675  Guandong Southern Tigers vs Zhejiang Golden Bulls
# 14      5983675  Guandong Southern Tigers vs Zhejiang Golden Bulls
# 35      5983675  Guandong Southern Tigers vs Zhejiang Golden Bulls
# ...         ...                                                ...
# 24346   6296133                     Et Land Elephants vs Lg Sakers
# 24391   6296133                     Et Land Elephants vs Lg Sakers
# 24392   6296133                     Et Land Elephants vs Lg Sakers
# 24395   6296133                     Et Land Elephants vs Lg Sakers
# 24396   6296133                     Et Land Elephants vs Lg Sakers
#
#                             Market Name Outcome Name  Odds (Decimal)  \
# 5      Aantal Punten - Over/Under 217.5        Under            1.71
# 6      Aantal Punten - Over/Under 217.5         Over            2.00
# 13     Aantal Punten - Over/Under 219.5        Under            1.59
# 14     Aantal Punten - Over/Under 219.5         Over            2.20
# 35     Aantal Punten - Over/Under 215.5         Over            1.87
# ...                                 ...          ...             ...
# 24346  Aantal Punten - Over/Under 153.5         Over            1.83
# 24391  Aantal Punten - Over/Under 153.0        Under            1.91
# 24392  Aantal Punten - Over/Under 153.0         Over            1.80
# 24395  Aantal Punten - Over/Under 154.0        Under            1.80
# 24396  Aantal Punten - Over/Under 154.0         Over            1.87
#
#        Price Numerator  Price Denominator Outcome Type Outcome SubType  \
# 5                   71                100           HL               L
# 6                    1                  1           HL               1
# 13                  59                100           HL               L
# 14                   6                  5           HL               1
# 35                  87                100           HL               1
# ...                ...                ...          ...             ...
# 24346               83                100           HL               1
# 24391               91                100           HL               L
# 24392                4                  5           HL               1
# 24395                4                  5           HL               L
# 24396               87                100           HL               1
#
#            sport     competition             Participant_1  \
# 5      Basketbal       China CBA  Guandong Southern Tigers
# 6      Basketbal       China CBA  Guandong Southern Tigers
# 13     Basketbal       China CBA  Guandong Southern Tigers
# 14     Basketbal       China CBA  Guandong Southern Tigers
# 35     Basketbal       China CBA  Guandong Southern Tigers
# ...          ...             ...                       ...
# 24346  Basketbal  Zuid-Korea KBL         Et Land Elephants
# 24391  Basketbal  Zuid-Korea KBL         Et Land Elephants
# 24392  Basketbal  Zuid-Korea KBL         Et Land Elephants
# 24395  Basketbal  Zuid-Korea KBL         Et Land Elephants
# 24396  Basketbal  Zuid-Korea KBL         Et Land Elephants
#
#                Participant_2   Line  OverUnderType
# 5      Zhejiang Golden Bulls  217.5              3
# 6      Zhejiang Golden Bulls  217.5              3
# 13     Zhejiang Golden Bulls  219.5              3
# 14     Zhejiang Golden Bulls  219.5              3
# 35     Zhejiang Golden Bulls  215.5              3
# ...                      ...    ...            ...
# 24346              Lg Sakers  153.5              3
# 24391              Lg Sakers  153.0              3
# 24392              Lg Sakers  153.0              3
# 24395              Lg Sakers  154.0              3
# 24396              Lg Sakers  154.0              3
#
# [408 rows x 15 columns]

# %%
toto_filtered_basketbal_overunder[toto_filtered_basketbal_overunder['Event Name'].str.contains('Golden State')]
# Out:
#      event_id                                   Event Name  \
# 532   5095863  Golden State Warriors vs Los Angeles Lakers
# 533   5095863  Golden State Warriors vs Los Angeles Lakers
# 534   5095863  Golden State Warriors vs Los Angeles Lakers
# 535   5095863  Golden State Warriors vs Los Angeles Lakers
# 536   5095863  Golden State Warriors vs Los Angeles Lakers
# 537   5095863  Golden State Warriors vs Los Angeles Lakers
# 538   5095863  Golden State Warriors vs Los Angeles Lakers
# 539   5095863  Golden State Warriors vs Los Angeles Lakers
# 540   5095863  Golden State Warriors vs Los Angeles Lakers
# 541   5095863  Golden State Warriors vs Los Angeles Lakers
# 552   5095863  Golden State Warriors vs Los Angeles Lakers
# 553   5095863  Golden State Warriors vs Los Angeles Lakers
# 554   5095863  Golden State Warriors vs Los Angeles Lakers
# 555   5095863  Golden State Warriors vs Los Angeles Lakers
#
#                                            Market Name Outcome Name  \
# 532                   Aantal Punten - Over/Under 225.5         Over
# 533                   Aantal Punten - Over/Under 225.5        Under
# 534                   Aantal Punten - Over/Under 223.5         Over
# 535                   Aantal Punten - Over/Under 223.5        Under
# 536  Los Angeles Lakers Aantal Punten - Over/Under ...        Under
# 537  Los Angeles Lakers Aantal Punten - Over/Under ...         Over
# 538                   Aantal Punten - Over/Under 224.5         Over
# 539                   Aantal Punten - Over/Under 224.5        Under
# 540  Golden State Warriors Aantal Punten - Over/Und...         Over
# 541  Golden State Warriors Aantal Punten - Over/Und...        Under
# 552        1e Helft - Aantal Punten - Over/Under 114.5         Over
# 553        1e Helft - Aantal Punten - Over/Under 114.5        Under
# 554        1e Helft - Aantal Punten - Over/Under 115.5         Over
# 555        1e Helft - Aantal Punten - Over/Under 115.5        Under
#
#      Odds (Decimal)  Price Numerator  Price Denominator Outcome Type  \
# 532            1.95               19                 20           HL
# 533            1.73               73                100           HL
# 534            1.87               87                100           HL
# 535            1.95               19                 20           HL
# 536            1.87               87                100           HL
# 537            1.87               87                100           HL
# 538            1.95               19                 20           HL
# 539            1.87               87                100           HL
# 540            1.83               83                100           HL
# 541            1.91               91                100           HL
# 552            1.83               83                100           HL
# 553            1.91               91                100           HL
# 554            1.95               19                 20           HL
# 555            1.80                4                  5           HL
#
#     Outcome SubType      sport competition   Line
# 532               1  Basketbal         NBA  225.5
# 533               L  Basketbal         NBA  225.5
# 534               1  Basketbal         NBA  223.5
# 535               L  Basketbal         NBA  223.5
# 536               L  Basketbal         NBA  110.5
# 537               1  Basketbal         NBA  110.5
# 538               1  Basketbal         NBA  224.5
# 539               L  Basketbal         NBA  224.5
# 540               1  Basketbal         NBA  113.5
# 541               L  Basketbal         NBA  113.5
# 552               1  Basketbal         NBA  114.5
# 553               L  Basketbal         NBA  114.5
# 554               1  Basketbal         NBA  115.5
# 555               L  Basketbal         NBA  115.5

# %%
kambi_filtered_basketbal_overunder[kambi_filtered_basketbal_overunder['event_name'].str.contains('Golden State')]
# Out:
#        bet_offer_id  criterion_id  \
# 49552    2481277702    1001159509
# 49554    2481277702    1001159509
# 49676    2481423956    1001159837
# 49678    2481423956    1001159837
# 49782    2481423983    1001159855
# 49784    2481423983    1001159855
# 50536    2481543437    1001159947
# 50538    2481543437    1001159947
# 50556    2481543442    1001159802
# 50558    2481543442    1001159802
# 50626    2481543460    1001159579
# 50628    2481543460    1001159579
# 50630    2481543462    1001159726
# 50632    2481543462    1001159726
# 50654    2481543468    1001906823
# 50656    2481543468    1001906823
# 50658    2481543469    1001906832
# 50660    2481543469    1001906832
# 50742    2481543491    1002167438
# 50744    2481543491    1002167438
# 50746    2481543492    1001906822
# 50748    2481543492    1001906822
# 50774    2481543692    1001159567
# 50776    2481543692    1001159567
# 50778    2481543703    1002167437
# 50780    2481543703    1002167437
# 50782    2481543704    1001906821
# 50784    2481543704    1001906821
#
#                                          criterion_label  \
# 49552        Totaal Aantal Punten - Inclusief Extra Tijd
# 49554        Totaal Aantal Punten - Inclusief Extra Tijd
# 49676  Totaal Aantal Punten door Los Angeles Lakers -...
# 49678  Totaal Aantal Punten door Los Angeles Lakers -...
# 49782  Totaal Aantal Punten door Golden State Warrior...
# 49784  Totaal Aantal Punten door Golden State Warrior...
# 50536                    Totaal Aantal Punten - 1e Helft
# 50538                    Totaal Aantal Punten - 1e Helft
# 50556                    Totaal Aantal Punten - 1e Kwart
# 50558                    Totaal Aantal Punten - 1e Kwart
# 50626  Totaal Aantal Punten door Los Angeles Lakers -...
# 50628  Totaal Aantal Punten door Los Angeles Lakers -...
# 50630  Totaal Aantal Punten - Resultaat Aan het Eind ...
# 50632  Totaal Aantal Punten - Resultaat Aan het Eind ...
# 50654                    Totaal Aantal Punten - 4e Kwart
# 50656                    Totaal Aantal Punten - 4e Kwart
# 50658                    Totaal Aantal Punten - 2e Helft
# 50660                    Totaal Aantal Punten - 2e Helft
# 50742  Totaal Aantal Punten door Los Angeles Lakers -...
# 50744  Totaal Aantal Punten door Los Angeles Lakers -...
# 50746                    Totaal Aantal Punten - 3e Kwart
# 50748                    Totaal Aantal Punten - 3e Kwart
# 50774  Totaal Aantal Punten door Golden State Warrior...
# 50776  Totaal Aantal Punten door Golden State Warrior...
# 50778  Totaal Aantal Punten door Golden State Warrior...
# 50780  Totaal Aantal Punten door Golden State Warrior...
# 50782                    Totaal Aantal Punten - 2e Kwart
# 50784                    Totaal Aantal Punten - 2e Kwart
#
#                                  criterion_english_label occurrence_type  \
# 49552                  Total Points - Including Overtime          POINTS
# 49554                  Total Points - Including Overtime          POINTS
# 49676  Total Points by Los Angeles Lakers - Including...             NaN
# 49678  Total Points by Los Angeles Lakers - Including...             NaN
# 49782  Total Points by Golden State Warriors - Includ...             NaN
# 49784  Total Points by Golden State Warriors - Includ...             NaN
# 50536                            Total Points - 1st Half          POINTS
# 50538                            Total Points - 1st Half          POINTS
# 50556                           Total Points - Quarter 1          POINTS
# 50558                           Total Points - Quarter 1          POINTS
# 50626      Total Points by Los Angeles Lakers - 1st Half             NaN
# 50628      Total Points by Los Angeles Lakers - 1st Half             NaN
# 50630          Total Points - Result at end of Quarter 3          POINTS
# 50632          Total Points - Result at end of Quarter 3          POINTS
# 50654                           Total Points - Quarter 4          POINTS
# 50656                           Total Points - Quarter 4          POINTS
# 50658                            Total Points - 2nd Half          POINTS
# 50660                            Total Points - 2nd Half          POINTS
# 50742     Total Points by Los Angeles Lakers - Quarter 1             NaN
# 50744     Total Points by Los Angeles Lakers - Quarter 1             NaN
# 50746                           Total Points - Quarter 3          POINTS
# 50748                           Total Points - Quarter 3          POINTS
# 50774   Total Points by Golden State Warriors - 1st Half             NaN
# 50776   Total Points by Golden State Warriors - 1st Half             NaN
# 50778  Total Points by Golden State Warriors - Quarter 1             NaN
# 50780  Total Points by Golden State Warriors - Quarter 1             NaN
# 50782                           Total Points - Quarter 2          POINTS
# 50784                           Total Points - Quarter 2          POINTS
#
#                  lifetime  bet_offer_type_id bet_offer_type_name  \
# 49552  FULL_TIME_OVERTIME                  6          Over/Onder
# 49554  FULL_TIME_OVERTIME                  6          Over/Onder
# 49676  FULL_TIME_OVERTIME                  6          Over/Onder
# 49678  FULL_TIME_OVERTIME                  6          Over/Onder
# 49782  FULL_TIME_OVERTIME                  6          Over/Onder
# 49784  FULL_TIME_OVERTIME                  6          Over/Onder
# 50536                 NaN                  6          Over/Onder
# 50538                 NaN                  6          Over/Onder
# 50556                 NaN                  6          Over/Onder
# 50558                 NaN                  6          Over/Onder
# 50626                 NaN                  6          Over/Onder
# 50628                 NaN                  6          Over/Onder
# 50630                 NaN                  6          Over/Onder
# 50632                 NaN                  6          Over/Onder
# 50632                 Under  1920.0  169500.0         NaN  OT_UNDER
# 50654                  Over  1830.0   52500.0         NaN   OT_OVER
# 50656                 Under  1920.0   52500.0         NaN  OT_UNDER
# 50658                  Over  1880.0  108500.0         NaN   OT_OVER
# 50660                 Under  1860.0  108500.0         NaN  OT_UNDER
# 50742                  Over  1980.0   28500.0         NaN   OT_OVER
# 50744                 Under  1770.0   28500.0         NaN  OT_UNDER
# 50746                  Over  1860.0   55500.0         NaN   OT_OVER
# 50748                 Under  1890.0   55500.0         NaN  OT_UNDER
# 50774                  Over  1790.0   57500.0         NaN   OT_OVER
# 50776                 Under  1960.0   57500.0         NaN  OT_UNDER
# 50778                  Over  1980.0   29500.0         NaN   OT_OVER
# 50780                 Under  1760.0   29500.0         NaN  OT_UNDER
# 50782                  Over  1790.0   56500.0         NaN   OT_OVER
# 50784                 Under  1960.0   56500.0         NaN  OT_UNDER
#
#                changed_date odds_fractional  odds_american status  \
# 49552  2024-12-25T11:03:05Z           33/20          165.0   OPEN
# 49554  2024-12-25T11:03:05Z             4/9         -225.0   OPEN
# 49676  2024-12-25T11:03:05Z           21/20          107.0   OPEN
# 49678  2024-12-25T11:03:05Z            7/10         -139.0   OPEN
# 49782  2024-12-25T11:03:05Z           21/20          105.0   OPEN
# 49784  2024-12-25T11:03:05Z            8/11         -136.0   OPEN
# 50536  2024-12-25T11:03:05Z             4/6         -150.0   OPEN
# 50538  2024-12-25T11:03:05Z           11/10          110.0   OPEN
# 50556  2024-12-25T11:03:05Z             3/4         -134.0   OPEN
# 50558  2024-12-25T11:03:05Z           Evens          102.0   OPEN
# 50626  2024-12-25T11:03:05Z           23/25         -107.0   OPEN
# 50628  2024-12-25T11:03:05Z             4/5         -124.0   OPEN
# 50630  2024-12-25T11:03:05Z             5/6         -120.0   OPEN
# 50632  2024-12-25T11:03:05Z           10/11         -109.0   OPEN
# 50654  2024-12-25T11:03:05Z           41/50         -121.0   OPEN
# 50656  2024-12-25T11:03:05Z           10/11         -109.0   OPEN
# 50658  2024-12-25T11:03:05Z           22/25         -114.0   OPEN
# 50660  2024-12-25T11:03:05Z           17/20         -117.0   OPEN
# 50742  2024-12-25T11:03:05Z           49/50         -103.0   OPEN
# 50744  2024-12-25T11:03:05Z             3/4         -130.0   OPEN
# 50746  2024-12-25T11:03:05Z           17/20         -117.0   OPEN
# 50748  2024-12-25T11:03:05Z           22/25         -113.0   OPEN
# 50774  2024-12-25T11:03:05Z           10/13         -127.0   OPEN
# 50776  2024-12-25T11:03:05Z           19/20         -105.0   OPEN
# 50778  2024-12-25T11:03:05Z           49/50         -103.0   OPEN
# 50780  2024-12-25T11:03:05Z             3/4         -132.0   OPEN
# 50782  2024-12-25T11:03:05Z           10/13         -127.0   OPEN
# 50784  2024-12-25T11:03:05Z           19/20         -105.0   OPEN
#
#       cash_out_status  home_score  away_score  \
# 49552         ENABLED         NaN         NaN
# 49554         ENABLED         NaN         NaN
# 49676         ENABLED         NaN         NaN
# 49678         ENABLED         NaN         NaN
# 49782         ENABLED         NaN         NaN
# 49784         ENABLED         NaN         NaN
# 50536         ENABLED         NaN         NaN
# 50538         ENABLED         NaN         NaN
# 50556         ENABLED         NaN         NaN
# 50558         ENABLED         NaN         NaN
# 50626         ENABLED         NaN         NaN
# 50628         ENABLED         NaN         NaN
# 50630         ENABLED         NaN         NaN
# 50632         ENABLED         NaN         NaN
# 50654         ENABLED         NaN         NaN
# 50656         ENABLED         NaN         NaN
# 50658         ENABLED         NaN         NaN
# 50660         ENABLED         NaN         NaN
# 50742         ENABLED         NaN         NaN
# 50744         ENABLED         NaN         NaN
# 50746         ENABLED         NaN         NaN
# 50748         ENABLED         NaN         NaN
# 50774         ENABLED         NaN         NaN
# 50776         ENABLED         NaN         NaN
# 50778         ENABLED         NaN         NaN
# 50780         ENABLED         NaN         NaN
# 50782         ENABLED         NaN         NaN
# 50784         ENABLED         NaN         NaN
#
#                                         event_name       sport group_name
# 49552  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 49554  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 49676  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 49678  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 49782  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 49784  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50536  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50538  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50556  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50558  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50626  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50628  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50630  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50632  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50654  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50656  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50658  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50660  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50742  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50744  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50746  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50748  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50774  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50776  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50778  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50780  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50782  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN
# 50784  Golden State Warriors vs Los Angeles Lakers  BASKETBALL        NaN

# %%
import pandas as pd
from fuzzywuzzy import fuzz, process


# Step 1: Standardize Event Names with Fuzzy Matching
def match_event_names(kambi_events, toto_events):
    matched_events = {}
    for event in kambi_events:
        match, score = process.extractOne(event, toto_events, scorer=fuzz.token_sort_ratio)
        if score > 90:  # Adjust the threshold as necessary
            matched_events[event] = match
        else:
            matched_events[event] = event  # Fallback to original if no good match
    return matched_events

# Map matched events from kambi to toto
matched_events = match_event_names(kambi_filtered_basketbal['event_name'].unique(), toto_filtered_basketbal['Event Name'].unique())
kambi_filtered_basketbal['standard_event_name'] = kambi_filtered_basketbal['event_name'].map(matched_events)

# Reverse the matched events dictionary for use in the toto table
reversed_matched_events = {v: k for k, v in matched_events.items()}
toto_filtered_basketbal['standard_event_name'] = toto_filtered_basketbal['Event Name'].map(reversed_matched_events).fillna(toto_filtered_basketbal['Event Name'])

# Step 2: Ensure Line Consistency
toto_filtered_basketbal['Line'] = kambi_filtered_basketbal['line'] / 10000  # Adjust to decimal
# kambi['Line'] = kambi['Line'].fillna('Placeholder')
toto_filtered_basketbal['Line'] = toto_filtered_basketbal['Market Name'].str.extract(r'(\d+\.?\d*)').astype(float)
# toto['Line'] = toto['Line'].fillna('Placeholder')

# Step 3: Standardize Betting Types
bet_type_mapping = {
    'goals over/under': 'Total Goals',
    'Winnaar Gevecht': 'Wedstrijdnotering'
    # Add more mappings as necessary
}
kambi_filtered_basketbal['standard_bet_type'] = kambi_filtered_basketbal['criterion_label'].replace(bet_type_mapping)
toto_filtered_basketbal['standard_bet_type'] = toto_filtered_basketbal['Market Name'].replace(bet_type_mapping)

# Step 4
kambi_filtered_basketbal['standard_outcome'] = kambi_filtered_basketbal['outcome_label'].apply(
    lambda x: ' '.join(x.split(', ')[::-1]) if ',' in x else x
)

# Assign kambi 'outcome_label' directly to 'standard_outcome' as it's already in the desired format
toto_filtered_basketbal['standard_outcome'] = toto_filtered_basketbal['Outcome Name']

# Step 5: Merge DataFrames on Standardized Columns
merged_data = pd.merge(
    kambi_filtered_basketbal,
    toto_filtered_basketbal,
    left_on=['standard_event_name', 'standard_bet_type', 'standard_outcome', 'line'],
    right_on=['standard_event_name', 'standard_bet_type', 'standard_outcome', 'Line'],
    suffixes=('_kambi', '_toto')
)

# Output merged results with odds side by side
print(merged_data[['event_name', 'Market Name', 'criterion_label', 'outcome_label', 'Line']])
# Out:
# Empty DataFrame
# Columns: [event_name, Market Name, criterion_label, outcome_label, Line]
# Index: []
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_26390/1697250585.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_basketbal['standard_event_name'] = kambi_filtered_basketbal['event_name'].map(matched_events)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_26390/1697250585.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_basketbal['standard_bet_type'] = kambi_filtered_basketbal['criterion_label'].replace(bet_type_mapping)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_26390/1697250585.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kambi_filtered_basketbal['standard_outcome'] = kambi_filtered_basketbal['outcome_label'].apply(

# %%
merged_data = merged_data[['event_id_toto', 'sport_toto','event_id_kambi', 'sport_kambi', 'standard_event_name', 'standard_bet_type', 'standard_outcome', 'Outcome Type', 'bet_offer_type_name','Line', 'odds', 'Odds (Decimal)']].drop_duplicates()
merged_data['odds'] = merged_data['odds'] / 1000

# %%
merged_data
# Out:
# Empty DataFrame
# Columns: [event_id_toto, sport_toto, event_id_kambi, sport_kambi, standard_event_name, standard_bet_type, standard_outcome, Outcome Type, bet_offer_type_name, Line, odds, Odds (Decimal)]
# Index: []

# %% [markdown]
# ## Analyze results match

# %%
# Calculate the absolute difference between 'odds' and 'Odds (Decimal)'
merged_data['difference'] = abs(merged_data['odds'] - merged_data['Odds (Decimal)'])

# Only keep records where there are 2 outcomes
merged_data = merged_data.groupby(
    ['event_id_toto', 'sport_toto', 'event_id_kambi', 'sport_kambi', 'standard_event_name', 'standard_bet_type']
).filter(lambda x: len(x) == 2)

# Sort by the difference in descending order
top_differences = merged_data.sort_values(by='difference', ascending=False)

# Get the top records with the biggest differences
top_records = top_differences.head(20)

top_records
# Out:
# Empty DataFrame
# Columns: [event_id_toto, sport_toto, event_id_kambi, sport_kambi, standard_event_name, standard_bet_type, standard_outcome, Line, odds, Odds (Decimal), difference]
# Index: []

# %%
# Split 'standard_event_name' into two parts
split_names = merged_data['standard_event_name'].str.split(' vs ', expand=True)

# Recode 'standard_outcome'
merged_data['standard_outcome'] = merged_data.apply(
    lambda row: '1' if row['standard_outcome'] == split_names.loc[row.name, 0] 
                else ('2' if row['standard_outcome'] == split_names.loc[row.name, 1] else row['standard_outcome']),
    axis=1
)

merged_data['standard_outcome'] = merged_data['standard_outcome'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/sl/1m_7cj8j3dj7j13w2_rhnsvh0000gp/T/ipykernel_97584/957700488.py in ?()
#       1 # Split 'standard_event_name' into two parts
#       2 split_names = merged_data['standard_event_name'].str.split(' vs ', expand=True)
#       3
#       4 # Recode 'standard_outcome'
# ----> 5 merged_data['standard_outcome'] = merged_data.apply(
#       6     lambda row: '1' if row['standard_outcome'] == split_names.loc[row.name, 0]
#       7                 else ('2' if row['standard_outcome'] == split_names.loc[row.name, 1] else row['standard_outcome']),
#       8     axis=1
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#    4304             and not self.columns.is_unique
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4425             loc = self.columns.get_loc(key)
#    4426             cols = self.columns[loc]
#    4427             len_cols = 1 if is_scalar(cols) or isinstance(cols, tuple) else len(cols)
#    4428             if len_cols != len(value.columns):
# -> 4429                 raise ValueError("Columns must be same length as key")
#    4430
#    4431             # align right-hand-side columns if self.columns
#    4432             # is multi-index and self[key] is a sub-frame
#
# ValueError: Columns must be same length as key

# %%
merged_data[merged_data['standard_bet_type'] == 'Jannik Sinner Wint een Set']
# Out:
#    event_id_toto sport_toto  event_id_kambi sport_kambi  \
# 2        5944135     Tennis      1022071872      TENNIS
# 3        5944135     Tennis      1022071872      TENNIS
#
#              standard_event_name           standard_bet_type standard_outcome  \
# 2  Jannik Sinner vs Taylor Fritz  Jannik Sinner Wint een Set               Ja
# 3  Jannik Sinner vs Taylor Fritz  Jannik Sinner Wint een Set              Nee
#
#    Line   odds  Odds (Decimal)  difference
# 2   NaN   1.04            1.04        0.00
# 3   NaN  12.50            8.25        4.25

# %%
## Get odds for single event on 1 record
# Filter groups with exactly two rows
filtered_df = merged_data.groupby(
    ['event_id_toto', 'sport_toto', 'event_id_kambi', 'sport_kambi', 'standard_event_name', 'standard_bet_type']
).filter(lambda x: len(x) == 2)

# Proceed with pivoting only if there are any valid groups left
if not filtered_df.empty:
    # Pivot the filtered DataFrame
    reshaped_df = filtered_df.pivot(
        index=['event_id_toto', 'sport_toto', 'event_id_kambi', 'sport_kambi', 'standard_event_name', 'standard_bet_type'],
        columns='standard_outcome',
        values=['Line', 'odds', 'Odds (Decimal)', 'difference']
    )

    # Flatten the multi-index columns for readability
    reshaped_df.columns = ['_'.join(col).strip() for col in reshaped_df.columns.values]

    # Reset index to turn multi-index into columns
    reshaped_df.reset_index(inplace=True)
else:
    reshaped_df = pd.DataFrame()  # Create an empty DataFrame if no groups qualify

reshaped_df
# Out:
#     event_id_toto          sport_toto  event_id_kambi   sport_kambi  \
# 0         5468089  Mixed Martial Arts      1021633417  MARTIAL_ARTS
# 1         5699912             Voetbal      1020719873      FOOTBALL
# 2         5825551  Mixed Martial Arts      1021633419  MARTIAL_ARTS
# 3         5848540             Voetbal      1021874423      FOOTBALL
# 4         5850619             Voetbal      1021874421      FOOTBALL
# 5         5850658             Voetbal      1021874447      FOOTBALL
# 6         5850661             Voetbal      1021874448      FOOTBALL
# 7         5865420  Mixed Martial Arts      1022019255  MARTIAL_ARTS
# 8         5880676  Mixed Martial Arts      1022019259  MARTIAL_ARTS
# 9         5885309  Mixed Martial Arts      1022019261  MARTIAL_ARTS
# 10        5887010  Mixed Martial Arts      1022019258  MARTIAL_ARTS
# 21                      Burundi vs Malawi             Beide Teams Scoren
# 22           Richie Burnett vs Adam Mould                      Wedstrijd
# 23         Tommy Morris vs Johann Brouwer                      Wedstrijd
# 24         Tommy Morris vs Richie Burnett                      Wedstrijd
# 25       Reece Robinson vs Johann Brouwer                      Wedstrijd
# 26       Johann Brouwer vs Richie Burnett                      Wedstrijd
# 27           Adam Mould vs Reece Robinson                      Wedstrijd
# 28       Richie Burnett vs Reece Robinson                      Wedstrijd
# 29             Adam Mould vs Tommy Morris                      Wedstrijd
# 30           Stephen Bunting vs Josh Rock                      Wedstrijd
# 31        Luke Littler vs Lourence Ilagan                      Wedstrijd
# 32  Jermaine Wattimena vs Mensur Suljovic                      Wedstrijd
# 33        Charlton Athletic vs Bromley FC             Beide Teams Scoren
# 34      Northampton Town vs Burton Albion             Beide Teams Scoren
# 35             Walsall vs Shrewsbury Town             Beide Teams Scoren
# 36      Wycombe Wanderers vs Crawley Town             Beide Teams Scoren
# 37        Alexander Zverev vs Casper Ruud  Alexander Zverev Wint een Set
# 38        Alexander Zverev vs Casper Ruud       Casper Ruud Wint een Set
# 39        Carlos Alcaraz vs Andrey Rublev     Andrey Rublev Wint een Set
# 40        Carlos Alcaraz vs Andrey Rublev    Carlos Alcaraz Wint een Set
# 41          Jannik Sinner vs Taylor Fritz     Jannik Sinner Wint een Set
# 42          Jannik Sinner vs Taylor Fritz      Taylor Fritz Wint een Set
# 43           Martin Lukeman vs Ross Smith                      Wedstrijd
# 44          James Wade vs Cameron Menzies                      Wedstrijd
# 45           Ritchie Edhouse vs Rob Cross                      Wedstrijd
#
#     Line_1  Line_2  Line_Ja  Line_Nee  odds_1  odds_2  odds_Ja  odds_Nee  \
# 0      NaN     NaN      NaN       NaN    1.15    5.75      NaN       NaN
# 1      NaN     NaN      NaN       NaN     NaN     NaN     2.35      1.53
# 2      NaN     NaN      NaN       NaN    1.11    7.00      NaN       NaN
# 3      NaN     NaN      NaN       NaN     NaN     NaN     2.08      1.65
# 4      NaN     NaN      NaN       NaN     NaN     NaN     2.17      1.60
# 5      NaN     NaN      NaN       NaN     NaN     NaN     2.14      1.65
# 6      NaN     NaN      NaN       NaN     NaN     NaN     2.63      1.44
# 7      NaN     NaN      NaN       NaN    2.18    1.68      NaN       NaN
# 8      NaN     NaN      NaN       NaN    2.10    1.74      NaN       NaN
# 9      NaN     NaN      NaN       NaN    2.23    1.65      NaN       NaN
# 10     NaN     NaN      NaN       NaN    1.76    2.07      NaN       NaN
# 11     NaN     NaN      NaN       NaN    1.11    7.00      NaN       NaN
# 12     NaN     NaN      NaN       NaN     NaN     NaN     2.23      1.58
# 13     NaN     NaN      NaN       NaN     NaN     NaN     2.70      1.41
# 14     NaN     NaN      NaN       NaN     NaN     NaN     2.15      1.63
# 15     NaN     NaN      NaN       NaN     NaN     NaN     2.33      1.54
# 16     NaN     NaN      NaN       NaN     NaN     NaN     2.18      1.61
# 17     NaN     NaN      NaN       NaN     NaN     NaN     2.18      1.62
# 18     NaN     NaN      NaN       NaN     NaN     NaN     2.25      1.57
# 24              1.73              1.99                NaN                 NaN
# 25              1.48              2.47                NaN                 NaN
# 26              2.28              1.56                NaN                 NaN
# 27              1.86              1.85                NaN                 NaN
# 28              1.61              2.18                NaN                 NaN
# 29              2.01              1.72                NaN                 NaN
# 30              1.81              2.01                NaN                 NaN
# 31              1.06              9.25                NaN                 NaN
# 32              1.40              3.00                NaN                 NaN
# 33               NaN               NaN               1.67                2.00
# 34               NaN               NaN               1.61                2.10
# 35               NaN               NaN               1.78                1.83
# 36               NaN               NaN               1.83                1.83
# 37               NaN               NaN               1.05                8.00
# 38               NaN               NaN               2.42                1.50
# 39               NaN               NaN               1.86                1.84
# 40               NaN               NaN               1.11                5.50
# 41               NaN               NaN               1.04                8.25
# 42               NaN               NaN               2.37                1.52
# 43              2.51              1.53                NaN                 NaN
# 44              1.87              1.94                NaN                 NaN
# 45              2.14              1.72                NaN                 NaN
#
#     difference_1  difference_2  difference_Ja  difference_Nee
# 0           0.01          0.50            NaN             NaN
# 1            NaN           NaN           0.02            0.01
# 2           0.03          0.25            NaN             NaN
# 3            NaN           NaN           0.24            0.11
# 4            NaN           NaN           0.05            0.04
# 5            NaN           NaN           0.04            0.00
# 6            NaN           NaN           0.16            0.04
# 7           0.08          0.01            NaN             NaN
# 8           0.00          0.07            NaN             NaN
# 9           0.02          0.06            NaN             NaN
# 10          0.03          0.07            NaN             NaN
# 11          0.00          1.00            NaN             NaN
# 12           NaN           NaN           0.18            0.03
# 13           NaN           NaN           0.30            0.06
# 14           NaN           NaN           0.10            0.00
# 15           NaN           NaN           0.02            0.07
# 16           NaN           NaN           0.08            0.00
# 17           NaN           NaN           0.08            0.01
# 18           NaN           NaN           0.10            0.01
# 19           NaN           NaN           0.10            0.00
# 20           NaN           NaN           0.09            0.15
# 21           NaN           NaN           0.08            0.00
# 22          0.12          0.14            NaN             NaN
# 23          0.08          0.35            NaN             NaN
# 24          0.10          0.24            NaN             NaN
# 25          0.08          0.28            NaN             NaN
# 26          0.08          0.08            NaN             NaN
# 27          0.01          0.02            NaN             NaN
# 28          0.06          0.03            NaN             NaN
# 29          0.09          0.05            NaN             NaN
# 30          0.06          0.07            NaN             NaN
# 31          0.02          1.75            NaN             NaN
# 32          0.00          0.00            NaN             NaN
# 33           NaN           NaN           0.07            0.00
# 34           NaN           NaN           0.00            0.10
# 35           NaN           NaN           0.01            0.11
# 36           NaN           NaN           0.07            0.15
# 37           NaN           NaN           0.01            5.00
# 38           NaN           NaN           0.21            0.01
# 39           NaN           NaN           0.03            0.14
# 40           NaN           NaN           0.02            0.75
# 41           NaN           NaN           0.00            4.25
# 42           NaN           NaN           0.11            0.02
# 43          0.01          0.01            NaN             NaN
# 44          0.07          0.06            NaN             NaN
# 45          0.04          0.01            NaN             NaN

# %%
reshaped_df
# Out:
#                                                                                                                                        Line  \
# standard_outcome                                                                                                                 Adam Mould
# event_id_toto sport_toto         event_id_kambi sport_kambi  standard_event_name                   standard_bet_type
#  'Stanislav Olejarcik vs Hruska Snr., Vaclav': 'Stanislav Olejarcik vs Vaclav Hruska',
#  'Pavel Sprynar vs Vladimir Kubat': 'Pavel Sprynar vs Vladimir Kubat',
#  'Petr Holas vs Petr Machovec': 'Petr Holas vs Petr Machovec',
#  'Milan Klement vs Jaroslav Cerny': 'Milan Klement vs Jaroslav Cerny',
#  'Tibor Kolenic vs Stanislav Olejarcik': 'Tibor Kolenic vs Stanislav Olejarcik',
#  'Jaroslav Strnad (1961) vs Pavel Sprynar': 'Jaroslav  Strnad (1961) vs Pavel Sprynar',
#  'Jakub Dvorak vs Petr Holas': 'Jakub Dvorak vs Petr Holas',
#  'Rostyslav Kliuchuk vs Jan Sucharda': 'Rostyslav Kliuchuk vs Jan Sucharda',
#  'Hruska Snr., Vaclav vs Rostislav Hasmanda': 'Vaclav Hruska vs Rotislav Hasmanda',
#  'Petr Machovec vs Vaclav Stinil': 'Petr Machovec vs Vaclav Stinil',
#  'Vladimir Kubat vs Cesta Havrda': 'Vladimir Kubat vs Cesta Havrda',
#  'Jan Sucharda vs Jaroslav Cerny': 'Jan Sucharda vs Jaroslav Cerny',
#  'Cesta Havrda vs Pavel Sprynar': 'Cesta Havrda vs Pavel Sprynar',
#  'Rostislav Hasmanda vs Stanislav Olejarcik': 'Rotislav Hasmanda vs Stanislav Olejarcik',
#  'Vaclav Stinil vs Petr Holas': 'Vaclav Stinil vs Petr Holas',
#  'Milan Klement vs Rostyslav Kliuchuk': 'Milan Klement vs Rostyslav Kliuchuk',
#  'Jakub Dvorak vs Petr Machovec': 'Jakub Dvorak vs Petr Machovec',
#  'Tibor Kolenic vs Hruska Snr., Vaclav': 'Tibor Kolenic vs Vaclav Hruska',
#  'Jaroslav Strnad (1961) vs Vladimir Kubat': 'Jaroslav  Strnad (1961) vs Vladimir Kubat',
#  'Zdenek Bilek vs Tomas Turek': 'Zdenek Bilek vs Tomas Turek',
#  'Josef Grill vs Zdenek Kasinski': 'Josef Grill vs Zdenek Kasinski',
#  'Petr Jakes vs Milan Fikar': 'Petr Jakes vs Milan Fikar',
#  'Jan Kanera vs Radek Rose': 'Jan Kanera vs Radek Rose',
#  'Lubor Sulava vs Stanislav Olejarcik': 'Lubor Sulava vs Stanislav Olejarcik',
#  'Ondrej Mista vs Jiri Beranek': 'Ondrej Mista vs Jiri Beranek',
#  'Milan Fikar vs Ondrej Mista': 'Milan Fikar vs Ondrej Mista',
#  'Tomas Turek vs Jan Kanera': 'Tomas Turek vs Jan Kanera',
#  'Zdenek Kasinski vs Lubor Sulava': 'Zdenek Kasinski vs Lubor Sulava',
#  'Jiri Beranek vs Petr Jakes': 'Jiri Beranek vs Petr Jakes',
#  'Stanislav Olejarcik vs Josef Grill': 'Stanislav Olejarcik vs Josef Grill',
#  'Radek Rose vs Zdenek Bilek': 'Radek Rose vs Zdenek Bilek',
#  'Zdenek Bilek vs Jan Kanera': 'Zdenek Bilek vs Jan Kanera',
#  'Josef Grill vs Lubor Sulava': 'Josef Grill vs Lubor Sulava',
#  'Zbynek Pagac vs Jiri Ruzicka': 'Zbynek Pagac vs Jiri Ruzicka',
#  'Milan Fikar vs Jiri Beranek': 'Milan Fikar vs Jiri Beranek',
#  'Tomas Turek vs Radek Rose': 'Tomas Turek vs Radek Rose',
#  'Zdenek Kasinski vs Stanislav Olejarcik': 'Zdenek Kasinski vs Stanislav Olejarcik',
#  'Detroit Pistons vs Miami Heat': 'Detroit Pistons vs Miami Heat',
#  'Boston Celtics vs Atlanta Hawks': 'Boston Celtics vs Atlanta Hawks',
#  'Orlando Magic vs Charlotte Hornets': 'Orlando Magic vs Charlotte Hornets',
#  'Philadelphia 76ers vs New York Knicks': 'Philadelphia 76ers vs New York Knicks',
#  'Milwaukee Bucks vs Toronto Raptors': 'Milwaukee Bucks vs Toronto Raptors',
#  'Utah Jazz vs Phoenix Suns': 'Utah Jazz vs Phoenix Suns',
#  'Golden State Warriors vs Dallas Mavericks': 'Golden State Warriors vs Dallas Mavericks',
#  'Portland Trail Blazers vs Minnesota Timberwolves': 'Portland Trail Blazers vs Minnesota Timberwolves',
#  'Portugal vs Poland': 'Portugal vs Polen',
#  'San Marino vs Gibraltar': 'San Marino vs Gibraltar',
#  'Luxembourg vs Bulgaria': 'Luxemburg vs Bulgarije',
#  'Liberia vs Togo': 'Liberia vs Togo',
#  'Chad vs Sierra Leone': 'Chad vs Sierra Leone',
#  'Equatorial Guinea vs Algeria': 'Equatoriaal-Guinea vs Algerije',
#  'Burundi vs Malawi': 'Burundi vs Malawi',
#  'Madagascar vs Tunisia': 'Madagascar vs Tunesië',
#  'Burkina Faso vs Senegal': 'Burkina Faso vs Senegal',
#  'Benin vs Nigeria': 'Benin vs Nigeria',
#  'Botswana vs Mauritania': 'Botswana vs Mauritanië',
#  'Zimbabwe vs Kenya': 'Zimbabwe vs Kenia',
#  'Eswatini vs Guinea-Bissau': 'Eswatini vs Guinea-Bissau',
#  'Mozambique vs Mali': 'Mozambique vs Mali',
#  'Angola vs Ghana': 'Angola vs Ghana',
#  'Ethiopia vs Tanzania': 'Ethiopia vs Tanzania',
#  'Guinea vs DR Congo': 'Guinea vs DR Congo',
#  'SC Telstar vs VVV Venlo': 'Telstar vs VVV Venlo',
#  'Mickey Gall vs Ramiz Brahimaj': 'Mickey Gall vs Ramiz Brahimaj',
#  'Jonathan Martinez vs Marcus McGhee': 'Jonathan Martinez vs Marcus McGhee',
#  'Mauricio Ruffy vs James Llontop': 'Mauricio Ruffy vs James Llontop',
#  'Oban Elliott vs Bassil Hafez': 'Bassil Hafez vs Oban Elliott',
#  'Jim Miller vs Damon Jackson': 'Jim Miller vs Damon Jackson',
#  'Chris Weidman vs Eryk Anders': 'Chris Weidman vs Eryk Anders',
#  'Charles Oliveira vs Michael Chandler': 'Charles Oliveira vs Michael Chandler',
#  'Bo Nickal vs Paul Craig': 'Bo Nickal vs Paul Craig',
#  'Jon Jones vs Stipe Miocic': 'Jon Jones vs Stipe Miocic',
#  'De Phil Fries vs Darko Stosic': 'Philip de Fries vs Darko Stosic',
#  'Milwaukee Admirals vs Manitoba Moose': 'Milwaukee Admirals vs Manitoba Moose',
#  'Cleveland Monsters vs Toronto Marlies': 'Cleveland Monsters vs Toronto Marlies',
#  'Belleville Senators vs Syracuse Crunch': 'Belleville Senators vs Syracuse Crunch',
#  'Lehigh Valley Phantoms vs Wilkes-Barre/Scranton Penguins': 'Lehigh Valley Phantoms vs Wilkes-Barre/Scranton Penguins',
#  'Rochester Americans vs Laval Rocket': 'Rochester Americans vs Laval Rocket',
#  'Ontario Reign vs Tucson Roadrunners': 'Ontario Reign vs Tucson Roadrunners',
#  'San Jose Barracuda vs San Diego Gulls': 'San Jose Barracuda vs San Diego Gulls',
#  'Lausanne HC vs Genève-Servette HC': 'HC Lausanne vs Geneve Servette HC',
#  'Sheffield Steelers vs Eisbären Berlin': 'Sheffield Steelers vs Eisbaren Berlin',
#  'Milton Keynes Dons vs Leyton Orient': 'Milton Keynes Dons vs Leyton Orient FC',
#  'Northampton Town vs Burton Albion': 'Northampton Town vs Burton Albion',
#  'Wycombe Wanderers vs Crawley Town': 'Wycombe Wanderers vs Crawley Town',
#  'Walsall vs Shrewsbury Town': 'Walsall vs Shrewsbury Town',
#  'Stockport County vs Tranmere Rovers': 'Stockport County FC vs Tranmere Rovers',
#  'Charlton Athletic vs Bromley FC': 'Charlton Athletic vs Bromley FC',
#  'Stevenage FC vs Gillingham': 'Stevenage FC vs Gillingham FC',
#  'Chesterfield vs Grimsby Town': 'Chesterfield FC vs Grimsby Town',
#  'Reading vs Newport County': 'Reading vs Newport County AFC',
#  'Port Vale vs Wrexham': 'Port Vale vs Wrexham AFC'}

# %%
# event name is key
# event keys: Wedstrijd = Wedstrijd, outcome = 1 vs 2
#             Over/Under criterion_label + line : 'Totaal Aantal Gewonnen Games door Alcaraz, Carlos' + 125000.0 vs Market Name: 'Carlos Alcaraz Aantal Games - Over/Under 12.5'
set(kambi_filtered[kambi_filtered['sport'] == 'TENNIS'][['criterion_label',
       'criterion_english_label', 'occurrence_type', 'lifetime',
       'bet_offer_type_id', 'bet_offer_type_name',
       'bet_offer_type_english_name', 'event_id', 'outcome_id',
       'outcome_label', 'outcome_english_label', 'odds', 'line', 'participant',
       'type', 'status',
       'cash_out_status', 'home_score', 'away_score', 'event_name']].criterion_label)
# Out:
# {'Alex Minaur Wint een Set',
#  'Alexander Zverev Wint een Set',
#  'Andrey Rublev Wint een Set',
#  'Carlos Alcaraz Wint een Set',
#  'Casper Ruud Wint een Set',
#  'Correcte Score - Set 1',
#  'Daniil Medvedev Wint een Set',
#  'Game Handicap',
#  'Game Handicap - Set 1',
#  'Jannik Sinner Wint een Set',
#  'Meeste aces',
#  'Set Handicap',
#  'Setwedden',
#  'Taylor Fritz Wint een Set',
#  'Totaal Aantal Games',
#  'Totaal Aantal Games - Set 1',
#  'Totaal Aantal Games - Set 2',
#  'Totaal Aantal Gewonnen Games door Alcaraz, Carlos',
#  'Totaal Aantal Gewonnen Games door De Minaur, Alex',
#  'Totaal Aantal Gewonnen Games door Fritz, Taylor',
#  'Totaal Aantal Gewonnen Games door Medvedev, Daniil',
#  'Totaal Aantal Gewonnen Games door Rublev, Andrey',
#  'Totaal Aantal Gewonnen Games door Ruud, Casper',
#  'Totaal Aantal Gewonnen Games door Sinner, Jannik',
#  'Totaal Aantal Gewonnen Games door Zverev, Alexander',
#  'Totaal Aantal Sets',
#  'Totaal Aantal Tiebreaks',
#  'Totaal aantal minuten',
#  'Totaal aantal servicebreaks',
#  'Wedstrijdnotering'}

# %%
kambi_filtered[kambi_filtered['criterion_label']!='Wedstrijd'][['criterion_label',
       'criterion_english_label', 'occurrence_type', 'lifetime',
       'bet_offer_type_id', 'bet_offer_type_name',
       'bet_offer_type_english_name', 'event_id', 'outcome_id',
       'outcome_label', 'outcome_english_label', 'odds', 'line', 'participant',
       'type', 'status',
       'cash_out_status', 'home_score', 'away_score', 'event_name']].tail(60)
# Out:
#                                criterion_label  \
# 81408                  Dubbele Kans - 1e Helft
# 81409                  Dubbele Kans - 1e Helft
# 81410                           3-Way Handicap
# 81411                           3-Way Handicap
# 81412                           3-Way Handicap
# 81413      Beide Teams Scoren in Beide Helften
# 81414      Beide Teams Scoren in Beide Helften
# 81415                           Correcte Score
# 81416                           Correcte Score
# 81417                           Correcte Score
# 81418                           Correcte Score
# 81419                           Correcte Score
# 81420                           Correcte Score
# 81421                           Correcte Score
# 81422                           Correcte Score
# 81423                           Correcte Score
# 81424                           Correcte Score
# 81425                           Correcte Score
# 81426                           Correcte Score
# 81427                           Correcte Score
# 81428                           Correcte Score
# 81429                           Correcte Score
# 81430                           Correcte Score
# 81431                           Correcte Score
# 81432                           Correcte Score
# 81433                           Correcte Score
# 81434                           Correcte Score
# 81435                           Correcte Score
# 81436                           Correcte Score
# 81437                           Correcte Score
# 81438                           Correcte Score
# 81439                           Correcte Score
# 81440                           Correcte Score
# 81441                           Correcte Score
# 81442                           Correcte Score
# 81443                           Correcte Score
# 81444                           Correcte Score
# 81445                             Asian Totaal
# 81446                             Asian Totaal
# 81447     Totaal Aantal Doelpunten Oneven/Even
# 81448     Totaal Aantal Doelpunten Oneven/Even
# 81449                             Asian Totaal
# 81450                             Asian Totaal
# 81451                           3-Way Handicap
# 81452                           3-Way Handicap
# 81453                           3-Way Handicap
# 81454                 Totaal Aantal Doelpunten
# 81455                 Totaal Aantal Doelpunten
# 81456  Totaal Aantal Doelpunten door Port Vale
# 81457  Totaal Aantal Doelpunten door Port Vale
# 81458                           Asian Handicap
# 81459                           Asian Handicap
# 81460     Port Vale Wint en Beide Teams Scoren
# 81461     Port Vale Wint en Beide Teams Scoren
# 81462       Wrexham Wint en Beide Teams Scoren
# 81463       Wrexham Wint en Beide Teams Scoren
# 81464                Doelpunt in Beide Helften
# 81465                Doelpunt in Beide Helften
# 81466                Asian Handicap – 1e Helft
# 81467                Asian Handicap – 1e Helft
#
#                         criterion_english_label occurrence_type   lifetime  \
# 81408                  Double Chance - 1st Half           GOALS        NaN
# 81409                  Double Chance - 1st Half           GOALS        NaN
# 81410                            3-Way Handicap           GOALS  FULL_TIME
# 81411                            3-Way Handicap           GOALS  FULL_TIME
# 81412                            3-Way Handicap           GOALS  FULL_TIME
# 81413        Both Teams to Score in Both Halves             NaN        NaN
# 81414        Both Teams to Score in Both Halves             NaN        NaN
# 81415                             Correct Score           GOALS  FULL_TIME
# 81416                             Correct Score           GOALS  FULL_TIME
# 81417                             Correct Score           GOALS  FULL_TIME
# 81418                             Correct Score           GOALS  FULL_TIME
# 81419                             Correct Score           GOALS  FULL_TIME
# 81420                             Correct Score           GOALS  FULL_TIME
# 81421                             Correct Score           GOALS  FULL_TIME
# 81422                             Correct Score           GOALS  FULL_TIME
# 81423                             Correct Score           GOALS  FULL_TIME
# 81424                             Correct Score           GOALS  FULL_TIME
# 81425                             Correct Score           GOALS  FULL_TIME
# 81426                             Correct Score           GOALS  FULL_TIME
# 81427                             Correct Score           GOALS  FULL_TIME
# 81428                             Correct Score           GOALS  FULL_TIME
# 81429                             Correct Score           GOALS  FULL_TIME
# 81430                             Correct Score           GOALS  FULL_TIME
# 81431                             Correct Score           GOALS  FULL_TIME
# 81432                             Correct Score           GOALS  FULL_TIME
# 81433                             Correct Score           GOALS  FULL_TIME
# 81434                             Correct Score           GOALS  FULL_TIME
# 81435                             Correct Score           GOALS  FULL_TIME
# 81436                             Correct Score           GOALS  FULL_TIME
# 81437                             Correct Score           GOALS  FULL_TIME
# 81438                             Correct Score           GOALS  FULL_TIME
# 81439                             Correct Score           GOALS  FULL_TIME
# 81440                             Correct Score           GOALS  FULL_TIME
# 81441                             Correct Score           GOALS  FULL_TIME
# 81442                             Correct Score           GOALS  FULL_TIME
# 81443                             Correct Score           GOALS  FULL_TIME
# 81444                             Correct Score           GOALS  FULL_TIME
# 81445                               Asian Total           GOALS  FULL_TIME
# 81446                               Asian Total           GOALS  FULL_TIME
# 81447                      Total Goals Odd/Even           GOALS  FULL_TIME
# 81448                      Total Goals Odd/Even           GOALS  FULL_TIME
# 81449                               Asian Total           GOALS  FULL_TIME
# 81450                               Asian Total           GOALS  FULL_TIME
# 81451                            3-Way Handicap           GOALS  FULL_TIME
# 81452                            3-Way Handicap           GOALS  FULL_TIME
# 81453                            3-Way Handicap           GOALS  FULL_TIME
# 81454                               Total Goals           GOALS  FULL_TIME
# 81455                               Total Goals           GOALS  FULL_TIME
# 81456                  Total Goals by Port Vale             NaN  FULL_TIME
# 81457                  Total Goals by Port Vale             NaN  FULL_TIME
# 81458                            Asian Handicap           GOALS  FULL_TIME
# 81459                            Asian Handicap           GOALS  FULL_TIME
# 81460  Port Vale to Win and Both Teams To Score             NaN        NaN
# 81461  Port Vale to Win and Both Teams To Score             NaN        NaN
# 81462    Wrexham to Win and Both Teams To Score             NaN        NaN
# 81463    Wrexham to Win and Both Teams To Score             NaN        NaN
# 81464                       Goal in Both Halves             NaN        NaN
# 81465                       Goal in Both Halves             NaN        NaN
# 81466                 Asian Handicap - 1st Half           GOALS        NaN
# 81467                 Asian Handicap - 1st Half           GOALS        NaN
# 81465  1021152946  3565547710           Nee                    No    1920.0
# 81466  1021152946  3565547685     Port Vale             Port Vale    1340.0
# 81467  1021152946  3565547692       Wrexham               Wrexham    2950.0
#
#          line participant             type status cash_out_status  home_score  \
# 81408     NaN         NaN    OT_ONE_OR_TWO   OPEN         ENABLED         NaN
# 81409     NaN         NaN  OT_CROSS_OR_TWO   OPEN         ENABLED         NaN
# 81410 -1000.0   Port Vale                1   OPEN         ENABLED         NaN
# 81411 -1000.0         NaN         OT_CROSS   OPEN         ENABLED         NaN
# 81412 -1000.0     Wrexham                2   OPEN         ENABLED         NaN
# 81413     NaN         NaN           OT_YES   OPEN         ENABLED         NaN
# 81414     NaN         NaN            OT_NO   OPEN         ENABLED         NaN
# 81415     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         0.0
# 81416     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         0.0
# 81417     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         0.0
# 81418     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         0.0
# 81419     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         0.0
# 81420     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         0.0
# 81421     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         1.0
# 81422     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         1.0
# 81423     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         1.0
# 81424     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         1.0
# 81425     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         1.0
# 81426     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         1.0
# 81427     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         2.0
# 81428     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         2.0
# 81429     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         2.0
# 81430     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         2.0
# 81431     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         2.0
# 81432     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         2.0
# 81433     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         3.0
# 81434     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         3.0
# 81435     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         3.0
# 81436     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         3.0
# 81437     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         3.0
# 81438     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         4.0
# 81439     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         4.0
# 81440     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         4.0
# 81441     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         4.0
# 81442     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         5.0
# 81443     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         5.0
# 81444     NaN         NaN       OT_UNTYPED   OPEN         ENABLED         5.0
# 81445  2250.0         NaN          OT_OVER   OPEN        DISABLED         NaN
# 81446  2250.0         NaN         OT_UNDER   OPEN        DISABLED         NaN
# 81447     NaN         NaN          OT_EVEN   OPEN         ENABLED         NaN
# 81448     NaN         NaN           OT_ODD   OPEN         ENABLED         NaN
# 81449  2750.0         NaN          OT_OVER   OPEN        DISABLED         NaN
# 81450  2750.0         NaN         OT_UNDER   OPEN        DISABLED         NaN
# 81451  1000.0   Port Vale                1   OPEN         ENABLED         NaN
# 81452  1000.0         NaN         OT_CROSS   OPEN         ENABLED         NaN
# 81453  1000.0     Wrexham                2   OPEN         ENABLED         NaN
# 81454   500.0         NaN          OT_OVER   OPEN         ENABLED         NaN
# 81455   500.0         NaN         OT_UNDER   OPEN         ENABLED         NaN
# 81456   500.0         NaN          OT_OVER   OPEN         ENABLED         NaN
# 81457   500.0         NaN         OT_UNDER   OPEN         ENABLED         NaN
# 81458   500.0   Port Vale       OT_UNTYPED   OPEN        DISABLED         NaN
# 81459  -500.0     Wrexham       OT_UNTYPED   OPEN        DISABLED         NaN
# 81460     NaN         NaN           OT_YES   OPEN         ENABLED         NaN
# 81461     NaN         NaN            OT_NO   OPEN         ENABLED         NaN
# 81462     NaN         NaN           OT_YES   OPEN         ENABLED         NaN
# 81463     NaN         NaN            OT_NO   OPEN         ENABLED         NaN
# 81464     NaN         NaN           OT_YES   OPEN         ENABLED         NaN
# 81465     NaN         NaN            OT_NO   OPEN         ENABLED         NaN
# 81466   500.0   Port Vale       OT_UNTYPED   OPEN        DISABLED         NaN
# 81467  -500.0     Wrexham       OT_UNTYPED   OPEN        DISABLED         NaN
# 99                     Daniil Medvedev            2.05               21
# 102                                Nee            1.02                1
# 105                                 Ja           10.50               19
# 108                               Over            1.23               23
# 111                              Under            4.00                3
# 114                              Under            2.75                7
# 117                               Over            1.41               41
# 120                               Over            1.94               47
# 123                              Under            1.80                4
# 126                              Under            2.07              107
# 129                               Over            1.73               73
# 132                              Under            1.40                2
# 135                               Over            2.80                9
# 138                     Alex De Minaur            2.26               63
# 141                    Daniil Medvedev            1.57               57
# 144           Daniil Medvedev en Under            3.65               53
# 147             Alex De Minaur en Over            3.40               12
#
#      Price Denominator Outcome Type Outcome SubType   sport  \
# 0                   20           --             NaN  Tennis
# 3                   20           --             NaN  Tennis
# 6                  100           HH               2  Tennis
# 9                   25           HH               1  Tennis
# 12                 100           OE               1  Tennis
# 15                 100           OE               2  Tennis
# 18                  20           WH               2  Tennis
# 21                  20           WH               1  Tennis
# 24                 100           --             NaN  Tennis
# 27                 100           --             NaN  Tennis
# 30                   4           CS               S  Tennis
# 33                  20           CS               S  Tennis
# 36                   4           CS               S  Tennis
# 39                   1           CS               S  Tennis
# 42                  20           WH               2  Tennis
# 45                  20           WH               1  Tennis
# 48                  20           --             NaN  Tennis
# 51                  20           --             NaN  Tennis
# 54                 100           --             NaN  Tennis
# 57                   1           --             NaN  Tennis
# 60                  50           --             NaN  Tennis
# 63                   1           --             NaN  Tennis
# 66                  50           HL               1  Tennis
# 69                  50           HL               L  Tennis
# 72                  50           HL               L  Tennis
# 75                  50           HL               1  Tennis
# 78                  50           HL               1  Tennis
# 81                  25           HL               L  Tennis
# 84                   5           HL               L  Tennis
# 87                 100           HL               1  Tennis
# 90                  20           HL               1  Tennis
# 93                  20           HL               L  Tennis
# 96                 100           WH               2  Tennis
# 99                  20           WH               1  Tennis
# 102                 50           --             NaN  Tennis
# 105                  2           --             NaN  Tennis
# 108                100           HL               1  Tennis
# 111                  1           HL               L  Tennis
# 114                  4           HL               L  Tennis
# 117                100           HL               1  Tennis
# 120                 50           HL               1  Tennis
# 123                  5           HL               L  Tennis
# 126                100           HL               L  Tennis
# 129                100           HL               1  Tennis
# 132                  5           HL               L  Tennis
# 135                  5           HL               1  Tennis
# 138                 50           WH               2  Tennis
# 141                100           WH               1  Tennis
# 144                 20           --             NaN  Tennis
# 147                  5           --             NaN  Tennis
#
#                competition
# 0    ATP Finals, Enkelspel
# 3    ATP Finals, Enkelspel
# 6    ATP Finals, Enkelspel
# 9    ATP Finals, Enkelspel
# 12   ATP Finals, Enkelspel
# 15   ATP Finals, Enkelspel
# 18   ATP Finals, Enkelspel
# 21   ATP Finals, Enkelspel
# 24   ATP Finals, Enkelspel
# 27   ATP Finals, Enkelspel
# 30   ATP Finals, Enkelspel
# 33   ATP Finals, Enkelspel
# 36   ATP Finals, Enkelspel
# 39   ATP Finals, Enkelspel
# 42   ATP Finals, Enkelspel
# 45   ATP Finals, Enkelspel
# 48   ATP Finals, Enkelspel
# 51   ATP Finals, Enkelspel
# 54   ATP Finals, Enkelspel
# 57   ATP Finals, Enkelspel
# 60   ATP Finals, Enkelspel
# 63   ATP Finals, Enkelspel
# 66   ATP Finals, Enkelspel
# 69   ATP Finals, Enkelspel
# 72   ATP Finals, Enkelspel
# 75   ATP Finals, Enkelspel
# 78   ATP Finals, Enkelspel
# 81   ATP Finals, Enkelspel
# 84   ATP Finals, Enkelspel
# 87   ATP Finals, Enkelspel
# 90   ATP Finals, Enkelspel
# 93   ATP Finals, Enkelspel
# 96   ATP Finals, Enkelspel
# 99   ATP Finals, Enkelspel
# 102  ATP Finals, Enkelspel
# 105  ATP Finals, Enkelspel
# 108  ATP Finals, Enkelspel
# 111  ATP Finals, Enkelspel
# 114  ATP Finals, Enkelspel
# 117  ATP Finals, Enkelspel
# 120  ATP Finals, Enkelspel
# 123  ATP Finals, Enkelspel
# 126  ATP Finals, Enkelspel
# 129  ATP Finals, Enkelspel
# 132  ATP Finals, Enkelspel
# 135  ATP Finals, Enkelspel
# 138  ATP Finals, Enkelspel
# 141  ATP Finals, Enkelspel
# 144  ATP Finals, Enkelspel
# 147  ATP Finals, Enkelspel

# %%
import pandas as pd
import re
from fuzzywuzzy import fuzz, process

# Function to normalize names
def normalize_name(name):
    name = re.sub(r'\b(de|het|een)\b', '', name, flags=re.IGNORECASE)  # Remove articles
    name = re.sub(r'\s+', ' ', name).strip()  # Remove extra spaces
    return name

# Function to match names using fuzzy matching
def match_names(kambi_names, toto_names):
    normalized_toto = {name: normalize_name(name) for name in toto_names}
    normalized_kambi = {name: normalize_name(name) for name in kambi_names}
    matched_names = {}
    for kambi_name, normalized_kambi_name in normalized_kambi.items():
        match, score = process.extractOne(normalized_kambi_name, normalized_toto.values(), scorer=fuzz.token_sort_ratio)
        if score > 85:  # Adjust threshold
            matched_names[kambi_name] = [k for k, v in normalized_toto.items() if v == match][0]
        else:
            matched_names[kambi_name] = kambi_name
    return matched_names

# Normalize and map names in Kambi and Toto
kambi_names = kambi_filtered['bet_offer_type_name'].unique()
toto_names = toto_filtered['Market Name'].unique()
matched_names = match_names(kambi_names, toto_names)
kambi_filtered['normalized_bet_offer_type'] = kambi_filtered['bet_offer_type_name'].map(matched_names)
toto_filtered['normalized_market_name'] = toto_filtered['Market Name'].apply(normalize_name)

# Merge DataFrames using normalized columns
merged_data = pd.merge(
    kambi_filtered,
    toto_filtered,
    left_on=['standard_event_name', 'normalized_bet_offer_type', 'standard_outcome', 'Line'],
    right_on=['standard_event_name', 'normalized_market_name', 'standard_outcome', 'Line'],
    suffixes=('_kambi', '_toto')
)

# Output merged results
print(merged_data[['event_name', 'Market Name', 'criterion_label', 'outcome_label', 'Line']].drop_duplicates())
# Out:
#                           event_name Market Name             criterion_label  \
# 0      Jannik Sinner vs Taylor Fritz   Wedstrijd           Wedstrijdnotering
# 1      Jannik Sinner vs Taylor Fritz   Wedstrijd           Wedstrijdnotering
# 2    Carlos Alcaraz vs Andrey Rublev   Wedstrijd           Wedstrijdnotering
# 3    Carlos Alcaraz vs Andrey Rublev   Wedstrijd           Wedstrijdnotering
# 4    Alexander Zverev vs Casper Ruud   Wedstrijd           Wedstrijdnotering
# ..                               ...         ...                         ...
# 236       Mark Selby vs Shaun Murphy   Wedstrijd                     Frame 1
# 238       Mark Selby vs Shaun Murphy   Wedstrijd       Meeste Century Breaks
# 240       Mark Selby vs Shaun Murphy   Wedstrijd       Meeste Century Breaks
# 242       Mark Selby vs Shaun Murphy   Wedstrijd  Meeste Half-Century Breaks
# 244       Mark Selby vs Shaun Murphy   Wedstrijd  Meeste Half-Century Breaks
#
#          outcome_label  Line
# 0       Sinner, Jannik   NaN
# 1        Fritz, Taylor   NaN
# 2      Alcaraz, Carlos   NaN
# 3       Rublev, Andrey   NaN
# 4    Zverev, Alexander   NaN
# ..                 ...   ...
# 236      Murphy, Shaun   NaN
# 238        Selby, Mark   NaN
# 240      Murphy, Shaun   NaN
# 242        Selby, Mark   NaN
# 244      Murphy, Shaun   NaN
#
# [182 rows x 5 columns]

# %%
merged_data[['event_name', 'Market Name', 'criterion_label', 'outcome_label', 'Line', 'odds', 'Odds (Decimal)','sport_toto']].drop_duplicates()
# Out:
#                           event_name Market Name             criterion_label  \
# 0      Jannik Sinner vs Taylor Fritz   Wedstrijd           Wedstrijdnotering
# 1      Jannik Sinner vs Taylor Fritz   Wedstrijd           Wedstrijdnotering
# 2    Carlos Alcaraz vs Andrey Rublev   Wedstrijd           Wedstrijdnotering
# 3    Carlos Alcaraz vs Andrey Rublev   Wedstrijd           Wedstrijdnotering
# 4    Alexander Zverev vs Casper Ruud   Wedstrijd           Wedstrijdnotering
# ..                               ...         ...                         ...
# 236       Mark Selby vs Shaun Murphy   Wedstrijd                     Frame 1
# 238       Mark Selby vs Shaun Murphy   Wedstrijd       Meeste Century Breaks
# 240       Mark Selby vs Shaun Murphy   Wedstrijd       Meeste Century Breaks
# 242       Mark Selby vs Shaun Murphy   Wedstrijd  Meeste Half-Century Breaks
# 244       Mark Selby vs Shaun Murphy   Wedstrijd  Meeste Half-Century Breaks
#
#          outcome_label  Line    odds  Odds (Decimal) sport_toto
# 0       Sinner, Jannik   NaN  1150.0            1.15     Tennis
# 1        Fritz, Taylor   NaN  5800.0            6.00     Tennis
# 2      Alcaraz, Carlos   NaN  1340.0            1.30     Tennis
# 3       Rublev, Andrey   NaN  3350.0            3.65     Tennis
# 4    Zverev, Alexander   NaN  1140.0            1.15     Tennis
# ..                 ...   ...     ...             ...        ...
# 236      Murphy, Shaun   NaN  1910.0            2.10    Snooker
# 238        Selby, Mark   NaN  3000.0            1.73    Snooker
# 240      Murphy, Shaun   NaN  3250.0            2.10    Snooker
# 242        Selby, Mark   NaN  2000.0            1.73    Snooker
# 244      Murphy, Shaun   NaN  2380.0            2.10    Snooker
#
# [182 rows x 8 columns]

# %%
    left_on=['standard_event_name', 'normalized_bet_offer_type', 'standard_outcome', 'Line'],
    right_on['standard_event_name', 'normalized_market_name', 'standard_outcome', 'Line']=,

# %%
toto_filtered[(toto_filtered['sport']=='Voetbal') & (toto_filtered['Event Name'].str.lower().str.contains('peru')) & (toto_filtered['normalized_market_name'].str.contains('Over/Under'))][['standard_event_name', 'normalized_market_name', 'standard_outcome', 'Line']]
# Out:
#       standard_event_name         normalized_market_name standard_outcome  \
# 14439       Peru vs Chile  Aantal Goals - Over/Under 2.5             Over
# 14441       Peru vs Chile  Aantal Goals - Over/Under 2.5            Under
# 14443       Peru vs Chile  Aantal Goals - Over/Under 3.5             Over
# 14445       Peru vs Chile  Aantal Goals - Over/Under 3.5            Under
# 14447       Peru vs Chile  Aantal Goals - Over/Under 0.5            Under
# 14449       Peru vs Chile  Aantal Goals - Over/Under 0.5             Over
# 14451       Peru vs Chile  Aantal Goals - Over/Under 1.5             Over
# 14453       Peru vs Chile  Aantal Goals - Over/Under 1.5            Under
# 14455       Peru vs Chile  Aantal Goals - Over/Under 4.5            Under
# 14457       Peru vs Chile  Aantal Goals - Over/Under 4.5             Over
# 18851   Argentina vs Peru  Aantal Goals - Over/Under 0.5             Over
# 18853   Argentina vs Peru  Aantal Goals - Over/Under 0.5            Under
# 18855   Argentina vs Peru  Aantal Goals - Over/Under 4.5             Over
# 18857   Argentina vs Peru  Aantal Goals - Over/Under 4.5            Under
# 18859   Argentina vs Peru  Aantal Goals - Over/Under 2.5             Over
# 18861   Argentina vs Peru  Aantal Goals - Over/Under 2.5            Under
# 18863   Argentina vs Peru  Aantal Goals - Over/Under 1.5             Over
# 18865   Argentina vs Peru  Aantal Goals - Over/Under 1.5            Under
# 18867   Argentina vs Peru  Aantal Goals - Over/Under 3.5             Over
# 18869   Argentina vs Peru  Aantal Goals - Over/Under 3.5            Under
#
#        Line
# 14439   2.5
# 14441   2.5
# 14443   3.5
# 14445   3.5
# 14447   0.5
# 14449   0.5
# 14451   1.5
# 14453   1.5
# 14455   4.5
# 14457   4.5
# 18851   0.5
# 18853   0.5
# 18855   4.5
# 18857   4.5
# 18859   2.5
# 18861   2.5
# 18863   1.5
# 18865   1.5
# 18867   3.5
# 18869   3.5

# %%
kambi_filterd[(kambi_filtered['sport']=='FOOTBALL') & kambi_filtered['event_name'].str.lower().str.contains('peru') & (kambi_filtered['normalized_bet_offer_type']=='Over/Onder')].head(60)
# Out:
#        bet_offer_id  criterion_id  \
# 67964    2470331702    1001159633
# 67965    2470331702    1001159633
# 67986    2470331715    1001159926
# 67987    2470331715    1001159926
# 67991    2470331718    1001159967
# 67992    2470331718    1001159967
# 68006    2470331724    1001159532
# 68007    2470331724    1001159532
# 68008    2470331725    1001159926
# 68009    2470331725    1001159926
# 68010    2470331726    1001159967
# 68011    2470331726    1001159967
# 68020    2470331737    1001159926
# 68021    2470331737    1001159926
# 68022    2470331738    1001159926
# 68023    2470331738    1001159926
# 68037    2470331748    1001159926
# 68038    2470331748    1001159926
# 68042    2470331752    1001159532
# 68043    2470331752    1001159532
# 68044    2470331753    1001243173
# 68045    2470331753    1001243173
# 68048    2470331757    1001159633
# 68049    2470331757    1001159633
# 68061    2470434177    1001159633
# 68062    2470434177    1001159633
# 68063    2470434180    1001159967
# 68064    2470434180    1001159967
# 68077    2471221326    1001159532
# 68078    2471221326    1001159532
# 68083    2471856635    1002035671
# 68084    2471856635    1002035671
# 68088    2471856677    1002035671
# 68089    2471856677    1002035671
# 68099    2471856743    1002035667
# 68100    2471856743    1002035667
# 68103    2471856748    1003194958
# 68104    2471856748    1003194958
# 68110    2471856774    1002035672
# 68111    2471856774    1002035672
# 68112    2471856781    1003194956
# 68113    2471856781    1003194956
# 68114    2471856789    1002035672
# 68115    2471856789    1002035672
# 68119    2471856802    1002035667
# 68120    2471856802    1002035667
# 68148    2471856907    1002035672
# 68149    2471856907    1002035672
# 68214    2471875335    1002035667
# 68215    2471875335    1002035667
# 68217    2471875338    1002035667
# 68218    2471875338    1002035667
# 68221    2471875345    1002035672
# 68222    2471875345    1002035672
# 68236    2471875408    1002035671
# 68237    2471875408    1002035671
# 69030    2470349339    1001159967
# 69031    2470349339    1001159967
# 69038    2470349344    1001159532
# 69039    2470349344    1001159532
#
#                                          criterion_label  \
# 67964                Totaal Aantal Doelpunten door Chili
# 67965                Totaal Aantal Doelpunten door Chili
# 67986                           Totaal Aantal Doelpunten
# 67987                           Totaal Aantal Doelpunten
# 67991                 Totaal Aantal Doelpunten door Peru
# 67992                 Totaal Aantal Doelpunten door Peru
# 68006                Totaal Aantal Doelpunten - 1e Helft
# 68007                Totaal Aantal Doelpunten - 1e Helft
# 68008                           Totaal Aantal Doelpunten
# 68009                           Totaal Aantal Doelpunten
# 68010                 Totaal Aantal Doelpunten door Peru
# 68011                 Totaal Aantal Doelpunten door Peru
# 68020                           Totaal Aantal Doelpunten
# 68021                           Totaal Aantal Doelpunten
# 68022                           Totaal Aantal Doelpunten
# 68023                           Totaal Aantal Doelpunten
# 68037                           Totaal Aantal Doelpunten
# 68038                           Totaal Aantal Doelpunten
# 68042                Totaal Aantal Doelpunten - 1e Helft
# 68043                Totaal Aantal Doelpunten - 1e Helft
# 68044                Totaal Aantal Doelpunten - 2e Helft
# 68045                Totaal Aantal Doelpunten - 2e Helft
# 68048                Totaal Aantal Doelpunten door Chili
# 68049                Totaal Aantal Doelpunten door Chili
# 68061                Totaal Aantal Doelpunten door Chili
# 68062                Totaal Aantal Doelpunten door Chili
# 68063                 Totaal Aantal Doelpunten door Peru
# 68064                 Totaal Aantal Doelpunten door Peru
# 68077                Totaal Aantal Doelpunten - 1e Helft
# 68078                Totaal Aantal Doelpunten - 1e Helft
# 68083  Totaal Aantal Schoten op Doel door Chili (Afge...
# 68084  Totaal Aantal Schoten op Doel door Chili (Afge...
# 68088  Totaal Aantal Schoten op Doel door Chili (Afge...
# 68089  Totaal Aantal Schoten op Doel door Chili (Afge...
# 68099  Totaal Aantal Schoten op Doel (Afgehandeld Vol...
# 68100  Totaal Aantal Schoten op Doel (Afgehandeld Vol...
# 68103      Totaal Aantal Doelpunten door Peru - 1e Helft
# 68104      Totaal Aantal Doelpunten door Peru - 1e Helft
# 68110  Totaal Aantal Schoten op Doel door Peru (Afgeh...
# 68111  Totaal Aantal Schoten op Doel door Peru (Afgeh...
# 68112     Totaal Aantal Doelpunten door Chili - 1e Helft
# 68113     Totaal Aantal Doelpunten door Chili - 1e Helft
# 68114  Totaal Aantal Schoten op Doel door Peru (Afgeh...
# 68115  Totaal Aantal Schoten op Doel door Peru (Afgeh...
# 68119  Totaal Aantal Schoten op Doel (Afgehandeld Vol...
# 68120  Totaal Aantal Schoten op Doel (Afgehandeld Vol...
# 68148  Totaal Aantal Schoten op Doel door Peru (Afgeh...
# 68149  Totaal Aantal Schoten op Doel door Peru (Afgeh...
# 68214  Totaal Aantal Schoten op Doel (Afgehandeld Vol...
# 68215  Totaal Aantal Schoten op Doel (Afgehandeld Vol...
# 68217  Totaal Aantal Schoten op Doel (Afgehandeld Vol...
# 68218  Totaal Aantal Schoten op Doel (Afgehandeld Vol...
# 68221  Totaal Aantal Schoten op Doel door Peru (Afgeh...
# 68222  Totaal Aantal Schoten op Doel door Peru (Afgeh...
# 68236  Totaal Aantal Schoten op Doel door Chili (Afge...
# 68237  Totaal Aantal Schoten op Doel door Chili (Afge...
# 69030           Totaal Aantal Doelpunten door Argentinië
# 69031           Totaal Aantal Doelpunten door Argentinië
# 69038                Totaal Aantal Doelpunten - 1e Helft
# 69039                Totaal Aantal Doelpunten - 1e Helft
#
#                                  criterion_english_label occurrence_type  \
# 67964                               Total Goals by Chile             NaN
# 67965                               Total Goals by Chile             NaN
# 67986                                        Total Goals           GOALS
# 67987                                        Total Goals           GOALS
# 67991                                Total Goals by Peru             NaN
# 67992                                Total Goals by Peru             NaN
# 68006                             Total Goals - 1st Half           GOALS
# 68007                             Total Goals - 1st Half           GOALS
# 68008                                        Total Goals           GOALS
# 68009                                        Total Goals           GOALS
# 68010                                Total Goals by Peru             NaN
# 68011                                Total Goals by Peru             NaN
# 68020                                        Total Goals           GOALS
# 68021                                        Total Goals           GOALS
# 68022                                        Total Goals           GOALS
# 68023                                        Total Goals           GOALS
# 68037                                        Total Goals           GOALS
# 68038                                        Total Goals           GOALS
# 68042                             Total Goals - 1st Half           GOALS
# 68043                             Total Goals - 1st Half           GOALS
# 68044                             Total Goals - 2nd Half           GOALS
# 68045                             Total Goals - 2nd Half           GOALS
# 68048                               Total Goals by Chile             NaN
# 68049                               Total Goals by Chile             NaN
# 68061                               Total Goals by Chile             NaN
# 68062                               Total Goals by Chile             NaN
# 68063                                Total Goals by Peru             NaN
# 68064                                Total Goals by Peru             NaN
# 68077                             Total Goals - 1st Half           GOALS
# 68078                             Total Goals - 1st Half           GOALS
# 68083  Total Shots on Target by Chile (Settled using ...             NaN
# 68084  Total Shots on Target by Chile (Settled using ...             NaN
# 68088  Total Shots on Target by Chile (Settled using ...             NaN
# 68089  Total Shots on Target by Chile (Settled using ...             NaN
# 68099    Total Shots on Target (Settled using Opta data)             NaN
# 68100    Total Shots on Target (Settled using Opta data)             NaN
# 68103                     Total Goals by Peru - 1st Half             NaN
# 68104                     Total Goals by Peru - 1st Half             NaN
# 68110  Total Shots on Target by Peru (Settled using O...             NaN
# 68111  Total Shots on Target by Peru (Settled using O...             NaN
# 68112                    Total Goals by Chile - 1st Half             NaN
# 68113                    Total Goals by Chile - 1st Half             NaN
# 68114  Total Shots on Target by Peru (Settled using O...             NaN
# 68115  Total Shots on Target by Peru (Settled using O...             NaN
# 68119    Total Shots on Target (Settled using Opta data)             NaN
# 68120    Total Shots on Target (Settled using Opta data)             NaN
# 68148  Total Shots on Target by Peru (Settled using O...             NaN
# 68149  Total Shots on Target by Peru (Settled using O...             NaN
# 68214    Total Shots on Target (Settled using Opta data)             NaN
# 68215    Total Shots on Target (Settled using Opta data)             NaN
# 68217    Total Shots on Target (Settled using Opta data)             NaN
# 68218    Total Shots on Target (Settled using Opta data)             NaN
# 68221  Total Shots on Target by Peru (Settled using O...             NaN
# 68222  Total Shots on Target by Peru (Settled using O...             NaN
# 68236  Total Shots on Target by Chile (Settled using ...             NaN
# 68237  Total Shots on Target by Chile (Settled using ...             NaN
# 69030                           Total Goals by Argentina             NaN
# 69031                           Total Goals by Argentina             NaN
# 69038                             Total Goals - 1st Half           GOALS
# 69039                             Total Goals - 1st Half           GOALS
#
#         lifetime  bet_offer_type_id bet_offer_type_name  \
# 67964  FULL_TIME                  6          Over/Onder
# 67965  FULL_TIME                  6          Over/Onder
# 67986  FULL_TIME                  6          Over/Onder
# 67987  FULL_TIME                  6          Over/Onder
# 67991  FULL_TIME                  6          Over/Onder
# 67992  FULL_TIME                  6          Over/Onder
# 68006        NaN                  6          Over/Onder
# 68007        NaN                  6          Over/Onder
# 68008  FULL_TIME                  6          Over/Onder
# 68009  FULL_TIME                  6          Over/Onder
# 68010  FULL_TIME                  6          Over/Onder
# 68011  FULL_TIME                  6          Over/Onder
# 68020  FULL_TIME                  6          Over/Onder
# 68021  FULL_TIME                  6          Over/Onder
# 68022  FULL_TIME                  6          Over/Onder
# 68023  FULL_TIME                  6          Over/Onder
# 68037  FULL_TIME                  6          Over/Onder
# 68038  FULL_TIME                  6          Over/Onder
# 68042        NaN                  6          Over/Onder
# 68043        NaN                  6          Over/Onder
# 68044        NaN                  6          Over/Onder
# 68045        NaN                  6          Over/Onder
# 68048  FULL_TIME                  6          Over/Onder
# 68049  FULL_TIME                  6          Over/Onder
# 68061  FULL_TIME                  6          Over/Onder
# 68062  FULL_TIME                  6          Over/Onder
# 68063  FULL_TIME                  6          Over/Onder
# 68064  FULL_TIME                  6          Over/Onder
# 68077        NaN                  6          Over/Onder
# 68078        NaN                  6          Over/Onder
# 68083  FULL_TIME                  6          Over/Onder
# 68084  FULL_TIME                  6          Over/Onder
# 68088  FULL_TIME                  6          Over/Onder
# 68089  FULL_TIME                  6          Over/Onder
# 68099  FULL_TIME                  6          Over/Onder
# 68100  FULL_TIME                  6          Over/Onder
# 68103        NaN                  6          Over/Onder
# 68104        NaN                  6          Over/Onder
# 68110  FULL_TIME                  6          Over/Onder
# 68111  FULL_TIME                  6          Over/Onder
# 68112        NaN                  6          Over/Onder
# 68113        NaN                  6          Over/Onder
# 68114  FULL_TIME                  6          Over/Onder
# 68115  FULL_TIME                  6          Over/Onder
# 68119  FULL_TIME                  6          Over/Onder
# 68120  FULL_TIME                  6          Over/Onder
# 68148  FULL_TIME                  6          Over/Onder
# 68149  FULL_TIME                  6          Over/Onder
# 68214  FULL_TIME                  6          Over/Onder
# 68215  FULL_TIME                  6          Over/Onder
# 68217  FULL_TIME                  6          Over/Onder
# 68218  FULL_TIME                  6          Over/Onder
# 68221  FULL_TIME                  6          Over/Onder
# 68222  FULL_TIME                  6          Over/Onder
# 68236  FULL_TIME                  6          Over/Onder
# 68237  FULL_TIME                  6          Over/Onder
# 69030  FULL_TIME                  6          Over/Onder
# 69031  FULL_TIME                  6          Over/Onder
# 69038        NaN                  6          Over/Onder
# 69039        NaN                  6          Over/Onder
#
#       bet_offer_type_english_name    event_id  outcome_id outcome_label  \
# 67964                  Over/Under  1021874459  3560403762      Meer dan
# 67965                  Over/Under  1021874459  3560403766    Minder dan
# 67986                  Over/Under  1021874459  3560403804      Meer dan
# 67987                  Over/Under  1021874459  3560403806    Minder dan
# 67991                  Over/Under  1021874459  3560403809      Meer dan
# 67992                  Over/Under  1021874459  3560403812    Minder dan
# 68006                  Over/Under  1021874459  3560403827      Meer dan
# 68007                  Over/Under  1021874459  3560403833    Minder dan
# 68008                  Over/Under  1021874459  3560403835      Meer dan
# 68009                  Over/Under  1021874459  3560403842    Minder dan
# 68010                  Over/Under  1021874459  3560403839      Meer dan
# 68011                  Over/Under  1021874459  3560403846    Minder dan
# 68020                  Over/Under  1021874459  3560403880      Meer dan
# 68021                  Over/Under  1021874459  3560403887    Minder dan
# 68022                  Over/Under  1021874459  3560403883      Meer dan
# 68023                  Over/Under  1021874459  3560403891    Minder dan
# 68037                  Over/Under  1021874459  3560403935      Meer dan
# 68038                  Over/Under  1021874459  3560403942    Minder dan
# 68042                  Over/Under  1021874459  3560403955      Meer dan
# 68043                  Over/Under  1021874459  3560403963    Minder dan
# 68044                  Over/Under  1021874459  3560403964    Minder dan
# 68045                  Over/Under  1021874459  3560403972      Meer dan
# 68048                  Over/Under  1021874459  3560403987      Meer dan
# 68049                  Over/Under  1021874459  3560403994    Minder dan
# 68061                  Over/Under  1021874459  3560687702      Meer dan
# 68062                  Over/Under  1021874459  3560687705    Minder dan
# 68063                  Over/Under  1021874459  3560687720      Meer dan
# 68064                  Over/Under  1021874459  3560687722    Minder dan
# 68077                  Over/Under  1021874459  3563537920      Meer dan
# 68078                  Over/Under  1021874459  3563537921    Minder dan
# 68083                  Over/Under  1021874459  3565754599    Minder dan
# 68084                  Over/Under  1021874459  3565754600      Meer dan
# 68088                  Over/Under  1021874459  3565754678    Minder dan
# 68089                  Over/Under  1021874459  3565754703      Meer dan
# 68099                  Over/Under  1021874459  3565754819      Meer dan
# 68100                  Over/Under  1021874459  3565754853    Minder dan
# 68103                  Over/Under  1021874459  3565754832      Meer dan
# 68104                  Over/Under  1021874459  3565754867    Minder dan
# 68110                  Over/Under  1021874459  3565754880      Meer dan
# 68111                  Over/Under  1021874459  3565754922    Minder dan
# 68112                  Over/Under  1021874459  3565754892      Meer dan
# 68113                  Over/Under  1021874459  3565754937    Minder dan
# 68114                  Over/Under  1021874459  3565754908      Meer dan
# 68115                  Over/Under  1021874459  3565754951    Minder dan
# 68119                  Over/Under  1021874459  3565754939      Meer dan
# 68120                  Over/Under  1021874459  3565754981    Minder dan
# 68148                  Over/Under  1021874459  3565755162      Meer dan
# 68149                  Over/Under  1021874459  3565755190    Minder dan
# 68214                  Over/Under  1021874459  3565757088      Meer dan
# 68215                  Over/Under  1021874459  3565757089    Minder dan
# 68217                  Over/Under  1021874459  3565757093      Meer dan
# 68218                  Over/Under  1021874459  3565757096    Minder dan
# 68221                  Over/Under  1021874459  3565757108      Meer dan
# 68222                  Over/Under  1021874459  3565757109    Minder dan
# 68236                  Over/Under  1021874459  3565765613    Minder dan
# 68237                  Over/Under  1021874459  3565765614      Meer dan
# 69030                  Over/Under  1021874450  3560424078      Meer dan
# 69031                  Over/Under  1021874450  3560424083    Minder dan
# 69038                  Over/Under  1021874450  3560424087      Meer dan
# 69039                  Over/Under  1021874450  3560424093    Minder dan
#
#       outcome_english_label     odds    line participant      type  \
# 67964                  Over   3550.0  1500.0         NaN   OT_OVER
# 67965                 Under   1250.0  1500.0         NaN  OT_UNDER
# 67986                  Over   6000.0  3500.0         NaN   OT_OVER
# 67987                 Under   1130.0  3500.0         NaN  OT_UNDER
# 67991                  Over   2800.0  1500.0         NaN   OT_OVER
# 67992                 Under   1380.0  1500.0         NaN  OT_UNDER
# 68006                  Over   1560.0   500.0         NaN   OT_OVER
# 68007                 Under   2230.0   500.0         NaN  OT_UNDER
# 68008                  Over   2750.0  2500.0         NaN   OT_OVER
# 68009                 Under   1450.0  2500.0         NaN  OT_UNDER
# 68010                  Over   1370.0   500.0         NaN   OT_OVER
# 68011                 Under   2800.0   500.0         NaN  OT_UNDER
# 68020                  Over   1090.0   500.0         NaN   OT_OVER
# 68021                 Under   7500.0   500.0         NaN  OT_UNDER
# 68022                  Over   1520.0  1500.0         NaN   OT_OVER
# 68023                 Under   2550.0  1500.0         NaN  OT_UNDER
# 68037                  Over  15000.0  4500.0         NaN   OT_OVER
# 68038                 Under   1020.0  4500.0         NaN  OT_UNDER
# 68042                  Over   3650.0  1500.0         NaN   OT_OVER
# 68043                 Under   1240.0  1500.0         NaN  OT_UNDER
# 68044                 Under   1410.0  1500.0         NaN  OT_UNDER
# 68045                  Over   2650.0  1500.0         NaN   OT_OVER
# 68048                  Over   1500.0   500.0         NaN   OT_OVER
# 68049                 Under   2330.0   500.0         NaN  OT_UNDER
# 68061                  Over   8500.0  2500.0         NaN   OT_OVER
# 68062                 Under   1040.0  2500.0         NaN  OT_UNDER
# 68063                  Over   6500.0  2500.0         NaN   OT_OVER
# 68064                 Under   1070.0  2500.0         NaN  OT_UNDER
# 68077                  Over   9500.0  2500.0         NaN   OT_OVER
# 68078                 Under   1030.0  2500.0         NaN  OT_UNDER
# 68083                 Under   1490.0  3500.0         NaN  OT_UNDER
# 68084                  Over   2430.0  3500.0         NaN   OT_OVER
# 68088                 Under   1200.0  4500.0         NaN  OT_UNDER
# 68089                  Over   3950.0  4500.0         NaN   OT_OVER
# 68099                  Over   3650.0  8500.0         NaN   OT_OVER
# 68100                 Under   1230.0  8500.0         NaN  OT_UNDER
# 68103                  Over   2320.0   500.0         NaN   OT_OVER
# 68104                 Under   1530.0   500.0         NaN  OT_UNDER
# 68110                  Over   1980.0  3500.0         NaN   OT_OVER
# 68111                 Under   1720.0  3500.0         NaN  OT_UNDER
# 68112                  Over   2630.0   500.0         NaN   OT_OVER
# 68113                 Under   1420.0   500.0         NaN  OT_UNDER
# 68114                  Over   3050.0  4500.0         NaN   OT_OVER
# 68115                 Under   1300.0  4500.0         NaN  OT_UNDER
# 68119                  Over   2550.0  7500.0         NaN   OT_OVER
# 68120                 Under   1440.0  7500.0         NaN  OT_UNDER
# 68148                  Over   4900.0  5500.0         NaN   OT_OVER
# 68149                 Under   1130.0  5500.0         NaN  OT_UNDER
# 68214                  Over   1480.0  5500.0         NaN   OT_OVER
# 68215                 Under   2430.0  5500.0         NaN  OT_UNDER
# 68217                  Over   1900.0  6500.0         NaN   OT_OVER
# 68218                 Under   1790.0  6500.0         NaN  OT_UNDER
# 68221                  Over   1410.0  2500.0         NaN   OT_OVER
# 68222                 Under   2650.0  2500.0         NaN  OT_UNDER
# 68236                 Under   2150.0  2500.0         NaN  OT_UNDER
# 68237                  Over   1630.0  2500.0         NaN   OT_OVER
# 69030                  Over   2230.0  2500.0         NaN   OT_OVER
# 69031                 Under   1600.0  2500.0         NaN  OT_UNDER
# 69038                  Over   1270.0   500.0         NaN   OT_OVER
# 69039                 Under   3400.0   500.0         NaN  OT_UNDER
#
#                changed_date odds_fractional  odds_american status  \
# 67964  2024-11-11T12:45:13Z             5/2          255.0   OPEN
# 67965  2024-11-11T12:45:13Z             1/4         -400.0   OPEN
# 67986  2024-11-11T12:45:13Z             5/1          500.0   OPEN
# 67987  2024-11-11T12:45:13Z             1/8         -770.0   OPEN
# 67991  2024-11-11T12:45:13Z             9/5          180.0   OPEN
# 67992  2024-11-11T12:45:13Z            4/11         -265.0   OPEN
# 68006  2024-11-11T12:45:13Z           11/20         -180.0   OPEN
# 68007  2024-11-11T12:45:13Z             6/5          123.0   OPEN
# 68008  2024-11-11T12:45:13Z             7/4          175.0   OPEN
# 68009  2024-11-11T12:45:13Z             4/9         -225.0   OPEN
# 68010  2024-11-11T12:45:14Z            4/11         -275.0   OPEN
# 68011  2024-11-11T12:45:14Z             9/5          180.0   OPEN
# 68020  2024-11-11T12:45:14Z            1/12        -1115.0   OPEN
# 68021  2024-11-11T12:45:14Z            13/2          650.0   OPEN
# 68022  2024-11-11T12:45:13Z           13/25         -195.0   OPEN
# 68023  2024-11-11T12:45:13Z           31/20          155.0   OPEN
# 68037  2024-11-11T12:45:12Z            14/1         1400.0   OPEN
# 68038  2024-11-11T12:45:12Z            1/50        -5000.0   OPEN
# 68114  Totaal Aantal Schoten op Doel door Peru (Afgeh...         Meer dan
# 68115  Totaal Aantal Schoten op Doel door Peru (Afgeh...       Minder dan
# 68119  Totaal Aantal Schoten op Doel (Afgehandeld Vol...         Meer dan
# 68120  Totaal Aantal Schoten op Doel (Afgehandeld Vol...       Minder dan
# 68148  Totaal Aantal Schoten op Doel door Peru (Afgeh...         Meer dan
# 68149  Totaal Aantal Schoten op Doel door Peru (Afgeh...       Minder dan
# 68214  Totaal Aantal Schoten op Doel (Afgehandeld Vol...         Meer dan
# 68215  Totaal Aantal Schoten op Doel (Afgehandeld Vol...       Minder dan
# 68217  Totaal Aantal Schoten op Doel (Afgehandeld Vol...         Meer dan
# 68218  Totaal Aantal Schoten op Doel (Afgehandeld Vol...       Minder dan
# 68221  Totaal Aantal Schoten op Doel door Peru (Afgeh...         Meer dan
# 68222  Totaal Aantal Schoten op Doel door Peru (Afgeh...       Minder dan
# 68236  Totaal Aantal Schoten op Doel door Chili (Afge...       Minder dan
# 68237  Totaal Aantal Schoten op Doel door Chili (Afge...         Meer dan
# 69030           Totaal Aantal Doelpunten door Argentinië         Meer dan
# 69031           Totaal Aantal Doelpunten door Argentinië       Minder dan
# 69038                Totaal Aantal Doelpunten - 1e Helft         Meer dan
# 69039                Totaal Aantal Doelpunten - 1e Helft       Minder dan
#
#       normalized_bet_offer_type
# 67964                Over/Onder
# 67965                Over/Onder
# 67986                Over/Onder
# 67987                Over/Onder
# 67991                Over/Onder
# 67992                Over/Onder
# 68006                Over/Onder
# 68007                Over/Onder
# 68008                Over/Onder
# 68009                Over/Onder
# 68010                Over/Onder
# 68011                Over/Onder
# 68020                Over/Onder
# 68021                Over/Onder
# 68022                Over/Onder
# 68023                Over/Onder
# 68037                Over/Onder
# 68038                Over/Onder
# 68042                Over/Onder
# 68043                Over/Onder
# 68044                Over/Onder
# 68045                Over/Onder
# 68048                Over/Onder
# 68049                Over/Onder
# 68061                Over/Onder
# 68062                Over/Onder
# 68063                Over/Onder
# 68064                Over/Onder
# 68077                Over/Onder
# 68078                Over/Onder
# 68083                Over/Onder
# 68084                Over/Onder
# 68088                Over/Onder
# 68089                Over/Onder
# 68099                Over/Onder
# 68100                Over/Onder
# 68103                Over/Onder
# 68104                Over/Onder
# 68110                Over/Onder
# 68111                Over/Onder
# 68112                Over/Onder
# 68113                Over/Onder
# 68114                Over/Onder
# 68115                Over/Onder
# 68119                Over/Onder
# 68120                Over/Onder
# 68148                Over/Onder
# 68149                Over/Onder
# 68214                Over/Onder
# 68215                Over/Onder
# 68217                Over/Onder
# 68218                Over/Onder
# 68221                Over/Onder
# 68222                Over/Onder
# 68236                Over/Onder
# 68237                Over/Onder
# 69030                Over/Onder
# 69031                Over/Onder
# 69038                Over/Onder
# 69039                Over/Onder

# %%
# toto: kambi
voetbal_map = {'Resultaat': 'Wedstrijd',
               'Aantal Goals - Over/Under 0.5': 'Totaal Aantal Doelpunten' #icm line & kambi['outcome_english_label'] = 'Over' &
               }
