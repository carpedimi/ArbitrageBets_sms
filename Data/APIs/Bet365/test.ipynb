# %%
import requests
import pandas as pd
import json

# %% [markdown]
# 1.	Over/Under Full Time Markets:
# 	Each market has a specific handicap (e.g., 0.5, 1.5, etc.), which represents the total goals threshold.
# 	For each handicap, two outcomes are listed: “Over” and “Under”.
# 	Odds are provided for each outcome from a specific bookmaker (Bet365 in this case), with both the “bestPrice” (best odds available) and the bookmaker’s specific odds.
# 	Example:
# 	Handicap 0.5: “Over” at 1.03, “Under” at 15.0
# 	Handicap 1.5: “Over” at 1.2, “Under” at 4.5
# 2.	Over/Under Team-Specific Markets:
# 	Similar structure to the full-time markets, but focused on individual teams (Team 1 and Team 2).
# 	These markets predict the goals scored by a single team over/under a threshold.
# 	Example for Team 1:
# 	Handicap 2.5: “Over” at 2.75, “Under” at 1.4
# 3.	Payout Information:
# 	Each over/under market includes a “payout” percentage, representing the bookmaker’s estimated payout for the market.
# 	The payout percentage is usually below 100%, allowing the bookmaker to ensure a profit margin.

# %%
# Leverages https://rapidapi.com/odds-papi-odds-papi-default/api/bet36528
# Get upcoming events
# API endpoint and headers
url = 'https://bet36528.p.rapidapi.com/next/events?sport=soccer&hours=12'
headers = {
    'x-rapidapi-host': 'bet36528.p.rapidapi.com',
    'x-rapidapi-key': '8ee549ab37mshb8211f4581e7ef8p1b9d85jsnaa4b43655b13'
}

# Make the GET request
response = requests.get(url, headers=headers)

# Ensure we have a valid response
if response.status_code == 200:
    # Convert the response text to a Python dictionary
    data = json.loads(response.text)
    
    # List to hold event data
    events_data = []
    
    # Loop through the data and extract relevant details
    for tournament in data:
        for season in tournament['seasons']:
            for event in season['events'].values():
                event_info = {
                    'categoryName': tournament['categoryName'],
                    'tournamentName': tournament['name'],
                    'eventId': event['eventId'],
                    'participant1': event['participant1'],
                    'participant2': event['participant2'],
                    'date': event['date'],
                    'time': event['time'],
                    'eventStatus': event['eventStatus']
                }
                events_data.append(event_info)
    
    # Create a DataFrame from the events_data
    df = pd.DataFrame(events_data)
    
    # Display the DataFrame
    print(df.head())
else:
    print(f"Failed to retrieve data: {response.status_code}")

# You can save the dataframe to a CSV if needed
df.to_csv('events_data.csv', index=False)
# Out:
#   categoryName    tournamentName            eventId          participant1  \
# 0      Algeria           Ligue 2  id101432154878287            Ben Aknoun
# 1    Argentina  Liga Profesional  id100015546657149      Barracas Central
# 2    Argentina  Liga Profesional  id100015546657147  Instituto AC Cordoba
# 3    Argentina  Liga Profesional  id100015546657145           CA Banfield
# 4    Argentina  Liga Profesional  id100015546657135          Boca Juniors
#
#   participant2        date      time eventStatus
# 0   GC Mascara  2024-11-06  14:00:00    pre-game
# 1  Racing Club  2024-11-06  18:00:00    pre-game
# 2  River Plate  2024-11-06  20:00:00    pre-game
# 3  CA Belgrano  2024-11-06  20:00:00    pre-game
# 4   Godoy Cruz  2024-11-06  22:30:00    pre-game

# %%
list(set(df.tournamentName))
# Out:
# ['Premiership',
#  'Slovensky Pohar',
#  'Liga Profesional',
#  'Primera Division, Apertura',
#  'Premijer Liga',
#  'Stars League',
#  'Copa Federacion',
#  'Russian Cup',
#  'Copa de SM La Reina',
#  'Championship',
#  'Liga Premier Serie A',
#  'Premier League, Women',
#  'Carioca, Serie B1',
#  'U20 Copa do Brasil',
#  'AFC Champions League Two',
#  'UEFA Champions League',
#  'Superliga',
#  'Ligue 2',
#  'National League North',
#  'Copa Rio',
#  'EFL Trophy',
#  'National League South',
#  'Premier League',
#  'Primera A, Clausura',
#  'Jordan 1st Division',
#  'Primera Federacion',
#  'Svenska Cup Women',
#  'Superleague, Women',
#  'U23 Liga MX',
#  'UEFA Europa League',
#  '3. Liga, East',
#  'Coppa Italia, Women',
#  'Cyprus Cup',
#  'U23 Liga Revelacao',
#  'A Lyga',
#  'Liga Nacional, Apertura',
#  'Serie D, Group D',
#  'Primera Division, Women',
#  'Cup',
#  '2. Liga',
#  'Liga Premier Serie B',
#  'Omani League',
#  'Cup Crne Gore',
#  'Indian Super League',
#  'Brasileiro Serie A',
#  'MSFL']

# %%
df[df['tournamentName']=='UEFA Europa League']['eventId']
# Out:
# 54    id100067953160651
# Name: eventId, dtype: object

# %%
import requests

url = "https://bet36528.p.rapidapi.com/odds_bet365"
querystring = {
    "eventId": "id100003750868145",
    "oddsFormat": "decimal",
    "raw": "false"
}

headers = {
    "x-rapidapi-host": "bet36528.p.rapidapi.com",
    "x-rapidapi-key": "8ee549ab37mshb8211f4581e7ef8p1b9d85jsnaa4b43655b13"
}

response = requests.get(url, headers=headers, params=querystring)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Request failed with status code {response.status_code}: {response.text}")
# Out:
# {'betradarId': 50868145, 'bookmakers': {'bet365': {'eventPath': 'https://www.bet365.com/#/AC/B1/C1/D8/E162900913', 'name': 'bet365'}}, 'date': '2024-10-27', 'eventId': 'id100003750868145', 'eventStatus': 'pre-game', 'markets': {'101': {'handicap': '0', 'marketName': 'Full Time Result', 'marketNameShort': '1X2', 'oddsType': '3Way', 'outcomes': {'101': {'bookmakers': {'bestPrice': {'price': 1.222}, 'bet365': {'bookmakerOutcomeId': '1384094955', 'price': 1.222}}, 'outcomeName': '1'}, '102': {'bookmakers': {'bestPrice': {'price': 7.0}, 'bet365': {'bookmakerOutcomeId': '1384094956', 'price': 7.0}}, 'outcomeName': 'X'}, '103': {'bookmakers': {'bestPrice': {'price': 11.0}, 'bet365': {'bookmakerOutcomeId': '1384094957', 'price': 11.0}}, 'outcomeName': '2'}}, 'payouts': {'bestPrice': 95.048, 'bet365': 95.048}}, '104': {'handicap': '0', 'marketName': 'Both Teams To Score', 'marketNameShort': 'Both Score', 'oddsType': 'Totals', 'outcomes': {'104': {'bookmakers': {'bestPrice': {'price': 1.909}, 'bet365': {'bookmakerOutcomeId': '1401962652', 'price': 1.909}}, 'outcomeName': 'Yes'}, '105': {'bookmakers': {'bestPrice': {'price': 1.909}, 'bet365': {'bookmakerOutcomeId': '1401962653', 'price': 1.909}}, 'outcomeName': 'No'}}, 'payouts': {'bestPrice': 95.45, 'bet365': 95.45}}, '106': {'handicap': '0.5', 'marketName': 'Over Under Full Time', 'marketNameShort': 'Total', 'oddsType': 'Over/Under', 'outcomes': {'106': {'bookmakers': {'bestPrice': {'price': 1.012}, 'bet365': {'bookmakerOutcomeId': '1401962498', 'price': 1.012}}, 'outcomeName': 'Over'}, '107': {'bookmakers': {'bestPrice': {'price': 23.0}, 'bet365': {'bookmakerOutcomeId': '1401962487', 'price': 23.0}}, 'outcomeName': 'Under'}}, 'payouts': {'bestPrice': 96.935, 'bet365': 96.935}}, '108': {'handicap': '1.5', 'marketName': 'Over Under Full Time', 'marketNameShort': 'Total', 'oddsType': 'Over/Under', 'outcomes': {'108': {'bookmakers': {'bestPrice': {'price': 1.111}, 'bet365': {'bookmakerOutcomeId': '1401962483', 'price': 1.111}}, 'outcomeName': 'Over'}, '109': {'bookmakers': {'bestPrice': {'price': 6.5}, 'bet365': {'bookmakerOutcomeId': '1401962488', 'price': 6.5}}, 'outcomeName': 'Under'}}, 'payouts': {'bestPrice': 94.882, 'bet365': 94.882}}, '1012': {'handicap': '3.5', 'marketName': 'Over Under Full Time', 'marketNameShort': 'Total', 'oddsType': 'Over/Under', 'outcomes': {'1012': {'bookmakers': {'bestPrice': {'price': 1.909}, 'bet365': {'bookmakerOutcomeId': '1401962484', 'price': 1.909}}, 'outcomeName': 'Over'}, '1013': {'bookmakers': {'bestPrice': {'price': 1.8}, 'bet365': {'bookmakerOutcomeId': '1401962485', 'price': 1.8}}, 'outcomeName': 'Under'}}, 'payouts': {'bestPrice': 92.645, 'bet365': 92.645}}, '1014': {'handicap': '4.5', 'marketName': 'Over Under Full Time', 'marketNameShort': 'Total', 'oddsType': 'Over/Under', 'outcomes': {'1014': {'bookmakers': {'bestPrice': {'price': 3.25}, 'bet365': {'bookmakerOutcomeId': '1401962489', 'price': 3.25}}, 'outcomeName': 'Over'}, '1015': {'bookmakers': {'bestPrice': {'price': 1.333}, 'bet365': {'bookmakerOutcomeId': '1401962495', 'price': 1.333}}, 'outcomeName': 'Under'}}, 'payouts': {'bestPrice': 94.529, 'bet365': 94.529}}, '1016': {'handicap': '5.5', 'marketName': 'Over Under Full Time', 'marketNameShort': 'Total', 'oddsType': 'Over/Under', 'outcomes': {'1016': {'bookmakers': {'bestPrice': {'price': 6.0}, 'bet365': {'bookmakerOutcomeId': '1401962486', 'price': 6.0}}, 'outcomeName': 'Over'}, '1017': {'bookmakers': {'bestPrice': {'price': 1.125}, 'bet365': {'bookmakerOutcomeId': '1401962480', 'price': 1.125}}, 'outcomeName': 'Under'}}, 'payouts': {'bestPrice': 94.737, 'bet365': 94.737}}, '1018': {'handicap': '6.5', 'marketName': 'Over Under Full Time', 'marketNameShort': 'Total', 'oddsType': 'Over/Under', 'outcomes': {'1018': {'bookmakers': {'bestPrice': {'price': 11.0}, 'bet365': {'bookmakerOutcomeId': '1401962482', 'price': 11.0}}, 'outcomeName': 'Over'}, '1019': {'bookmakers': {'bestPrice': {'price': 1.05}, 'bet365': {'bookmakerOutcomeId': ' ...

# %%
import requests
import pandas as pd

# Base URL and headers for the API request
url = "https://bet36528.p.rapidapi.com/odds_bet365"
headers = {
    "x-rapidapi-host": "bet36528.p.rapidapi.com",
    "x-rapidapi-key": "8ee549ab37mshb8211f4581e7ef8p1b9d85jsnaa4b43655b13"
}

# List to store all rows of data
all_rows = []

# Loop over each event ID in df_event_ids['eventId']
for event_id in df[df['tournamentName']=='UEFA Europa League']['eventId']:
    # Define query parameters
    querystring = {
        "eventId": event_id,
        "oddsFormat": "decimal",
        "raw": "false"
    }

    # Send request
    response = requests.get(url, headers=headers, params=querystring)

    if response.status_code == 200:
        data = response.json()
        
        # Extract and store data
        try:
            # Iterate over each market in the response
            for market_id, market_data in data.get('markets', {}).items():
                market_name = market_data['marketName']
                market_short_name = market_data.get('marketNameShort', '')
                odds_type = market_data.get('oddsType', '')
                handicap = market_data.get('handicap', '')

                # Iterate over outcomes within each market
                for outcome_id, outcome_data in market_data.get('outcomes', {}).items():
                    outcome_name = outcome_data['outcomeName']
                    price = outcome_data['bookmakers']['bet365']['price']
                    
                    # Append each row of relevant details
                    all_rows.append({
                        'Event ID': event_id,
                        'Event Date': data.get('date', ''),
                        'Market Name': market_name,
                        'Outcome Name': outcome_name,
                        'Price': price,
                        'Handicap': handicap,
                        'Odds Type': odds_type,
                        'Bookmaker': 'bet365'
                    })
        
        except KeyError:
            print(f"Event {event_id} does not have the expected structure or data may be missing.")
    
    else:
        print(f"Request for event {event_id} failed with status code {response.status_code}: {response.text}")

# Create a DataFrame from the accumulated rows
df_events = pd.DataFrame(all_rows)

# Display the final DataFrame
print(df_events)
# Out:
#              Event ID  Event Date                      Market Name  \
# 0   id100067953160651  2024-11-06                 Full Time Result
# 1   id100067953160651  2024-11-06                 Full Time Result
# 2   id100067953160651  2024-11-06                 Full Time Result
# 3   id100067953160651  2024-11-06              Both Teams To Score
# 4   id100067953160651  2024-11-06              Both Teams To Score
# ..                ...         ...                              ...
# 57  id100067953160651  2024-11-06            Over Under First Half
# 58  id100067953160651  2024-11-06   Both Teams To Score First Half
# 59  id100067953160651  2024-11-06   Both Teams To Score First Half
# 60  id100067953160651  2024-11-06  Both Teams To Score Second Half
# 61  id100067953160651  2024-11-06  Both Teams To Score Second Half
#
#    Outcome Name  Price Handicap   Odds Type Bookmaker
# 0             1  1.615        0        3Way    bet365
# 1             X  4.100        0        3Way    bet365
# 2             2  5.250        0        3Way    bet365
# 3           Yes  1.666        0      Totals    bet365
# 4            No  2.100        0      Totals    bet365
# ..          ...    ...      ...         ...       ...
# 57        Under  1.025      3.5  Over/Under    bet365
# 58          Yes  4.000        0       Score    bet365
# 59           No  1.222        0       Score    bet365
# 60          Yes  3.000        0       Score    bet365
# 61           No  1.363        0       Score    bet365
#
# [62 rows x 8 columns]

# %%
response.json()
# Out:
# {'betradarId': 53160651,
#  'bookmakers': {'bet365': {'eventPath': 'https://www.bet365.com/#/AC/B1/C1/D8/E163949211',
#    'name': 'bet365'}},
#  'date': '2024-11-06',
#  'eventId': 'id100067953160651',
#  'eventStatus': 'pre-game',
#  'markets': {'101': {'handicap': '0',
#    'marketName': 'Full Time Result',
#    'marketNameShort': '1X2',
#    'oddsType': '3Way',
#    'outcomes': {'101': {'bookmakers': {'bestPrice': {'price': 1.615},
#       'bet365': {'bookmakerOutcomeId': '1520702314', 'price': 1.615}},
#      'outcomeName': '1'},
#     '102': {'bookmakers': {'bestPrice': {'price': 4.1},
#       'bet365': {'bookmakerOutcomeId': '1520702315', 'price': 4.1}},
#      'outcomeName': 'X'},
#     '103': {'bookmakers': {'bestPrice': {'price': 5.25},
#       'bet365': {'bookmakerOutcomeId': '1520702316', 'price': 5.25}},
#      'outcomeName': '2'}},
#    'payouts': {'bestPrice': 94.915, 'bet365': 94.915}},
#   '104': {'handicap': '0',
#    'marketName': 'Both Teams To Score',
#    'marketNameShort': 'Both Score',
#    'oddsType': 'Totals',
#    'outcomes': {'104': {'bookmakers': {'bestPrice': {'price': 1.666},
#       'bet365': {'bookmakerOutcomeId': '1589891936', 'price': 1.666}},
#      'outcomeName': 'Yes'},
#     '105': {'bookmakers': {'bestPrice': {'price': 2.1},
#       'bet365': {'bookmakerOutcomeId': '1589891937', 'price': 2.1}},
#      'outcomeName': 'No'}},
#    'payouts': {'bestPrice': 92.9, 'bet365': 92.9}},
#   '106': {'handicap': '0.5',
#    'marketName': 'Over Under Full Time',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'106': {'bookmakers': {'bestPrice': {'price': 1.03},
#       'bet365': {'bookmakerOutcomeId': '1589891766', 'price': 1.03}},
#      'outcomeName': 'Over'},
#     '107': {'bookmakers': {'bestPrice': {'price': 15.0},
#       'bet365': {'bookmakerOutcomeId': '1589891767', 'price': 15.0}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 96.382, 'bet365': 96.382}},
#   '108': {'handicap': '1.5',
#    'marketName': 'Over Under Full Time',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'108': {'bookmakers': {'bestPrice': {'price': 1.2},
#       'bet365': {'bookmakerOutcomeId': '1589891761', 'price': 1.2}},
#      'outcomeName': 'Over'},
#     '109': {'bookmakers': {'bestPrice': {'price': 4.5},
#       'bet365': {'bookmakerOutcomeId': '1589891773', 'price': 4.5}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 94.737, 'bet365': 94.737}},
#   '1012': {'handicap': '3.5',
#    'marketName': 'Over Under Full Time',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'1012': {'bookmakers': {'bestPrice': {'price': 2.625},
#       'bet365': {'bookmakerOutcomeId': '1589891762', 'price': 2.625}},
#      'outcomeName': 'Over'},
#     '1013': {'bookmakers': {'bestPrice': {'price': 1.5},
#       'bet365': {'bookmakerOutcomeId': '1589891770', 'price': 1.5}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 95.455, 'bet365': 95.455}},
#   '1014': {'handicap': '4.5',
#    'marketName': 'Over Under Full Time',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'1014': {'bookmakers': {'bestPrice': {'price': 4.5},
#       'bet365': {'bookmakerOutcomeId': '1589891774', 'price': 4.5}},
#      'outcomeName': 'Over'},
#     '1015': {'bookmakers': {'bestPrice': {'price': 1.2},
#       'bet365': {'bookmakerOutcomeId': '1589891771', 'price': 1.2}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 94.737, 'bet365': 94.737}},
#   '1016': {'handicap': '5.5',
#    'marketName': 'Over Under Full Time',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'1016': {'bookmakers': {'bestPrice': {'price': 9.0},
#       'bet365': {'bookmakerOutcomeId': '1589891772', 'price': 9.0}},
#      'outcomeName': 'Over'},
#     '1017': {'bookmakers': {'bestPrice': {'price': 1.071},
#       'bet365': {'bookmakerOutcomeId': '1589891769', 'price': 1.071}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 95.71, 'bet365': 95.71}},
#   '1018': {'handicap': '6.5',
#    'marketName': 'Over Under Full Time',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'1018': {'bookmakers': {'bestPrice': {'price': 19.0},
#       'bet365': {'bookmakerOutcomeId': '1589891760', 'price': 19.0}},
#      'outcomeName': 'Over'},
#     '1019': {'bookmakers': {'bestPrice': {'price': 1.02},
#       'bet365': {'bookmakerOutcomeId': '1589891763', 'price': 1.02}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 96.803, 'bet365': 96.803}},
#   '1020': {'handicap': '7.5',
#    'marketName': 'Over Under Full Time',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'1020': {'bookmakers': {'bestPrice': {'price': 34.0},
#       'bet365': {'bookmakerOutcomeId': '1589891764', 'price': 34.0}},
#      'outcomeName': 'Over'},
#     '1021': {'bookmakers': {'bestPrice': {'price': 1.005},
#       'bet365': {'bookmakerOutcomeId': '1589891765', 'price': 1.005}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 97.615, 'bet365': 97.615}},
#   '1064': {'handicap': '-1.00',
#    'marketName': 'Asian Handicap',
#    'marketNameShort': 'Asian Handicap',
#    'oddsType': 'Asian Handicap',
#    'outcomes': {'1064': {'bookmakers': {'bestPrice': {'price': 2.09},
#       'bet365': {'bookmakerOutcomeId': '1520702319', 'price': 2.09}},
#      'outcomeName': '1'},
#     '1065': {'bookmakers': {'bestPrice': {'price': 1.81},
#       'bet365': {'bookmakerOutcomeId': '1520702320', 'price': 1.81}},
#      'outcomeName': '2'}},
#    'payouts': {'bestPrice': 96.997, 'bet365': 96.997}},
#   '1066': {'handicap': '-0.75',
#    'marketName': 'Asian Handicap',
#    'marketNameShort': 'Asian Handicap',
#    'oddsType': 'Asian Handicap',
#    'outcomes': {'1066': {'bookmakers': {'bestPrice': {'price': 1.82},
#       'bet365': {'bookmakerOutcomeId': '1520702319', 'price': 1.82}},
#      'outcomeName': '1'},
#     '1067': {'bookmakers': {'bestPrice': {'price': 2.08},
#       'bet365': {'bookmakerOutcomeId': '1520702320', 'price': 2.08}},
#      'outcomeName': '2'}},
#    'payouts': {'bestPrice': 97.067, 'bet365': 97.067}},
#   '10208': {'handicap': '0',
#    'marketName': 'First Half Result',
#    'marketNameShort': '1st Half 1X2',
#    'oddsType': '3Way',
#    'outcomes': {'10208': {'bookmakers': {'bestPrice': {'price': 2.2},
#       'bet365': {'bookmakerOutcomeId': '1589891251', 'price': 2.2}},
#      'outcomeName': '1'},
#     '10209': {'bookmakers': {'bestPrice': {'price': 2.4},
#       'bet365': {'bookmakerOutcomeId': '1589891252', 'price': 2.4}},
#      'outcomeName': 'X'},
#     '10210': {'bookmakers': {'bestPrice': {'price': 5.0},
#       'bet365': {'bookmakerOutcomeId': '1589891249', 'price': 5.0}},
#      'outcomeName': '2'}},
#    'payouts': {'bestPrice': 93.352, 'bet365': 93.352}},
#   '10214': {'handicap': '0',
#    'marketName': 'Draw No Bet',
#    'marketNameShort': 'Draw No Bet',
#    'oddsType': '2Way',
#    'outcomes': {'10214': {'bookmakers': {'bestPrice': {'price': 1.25},
#       'bet365': {'bookmakerOutcomeId': '1589891244', 'price': 1.25}},
#      'outcomeName': '1'},
#     '10215': {'bookmakers': {'bestPrice': {'price': 3.75},
#       'bet365': {'bookmakerOutcomeId': '1589891245', 'price': 3.75}},
#      'outcomeName': '2'}},
#    'payouts': {'bestPrice': 93.75, 'bet365': 93.75}},
#   '10222': {'handicap': '0',
#    'marketName': 'Odd Even Full Time',
#    'marketNameShort': 'Odd/Even',
#    'oddsType': '2Way',
#    'outcomes': {'10222': {'bookmakers': {'bestPrice': {'price': 1.975},
#       'bet365': {'bookmakerOutcomeId': '1589891592', 'price': 1.975}},
#      'outcomeName': 'Odd'},
#     '10223': {'bookmakers': {'bestPrice': {'price': 1.875},
#       'bet365': {'bookmakerOutcomeId': '1589891591', 'price': 1.875}},
#      'outcomeName': 'Even'}},
#    'payouts': {'bestPrice': 96.185, 'bet365': 96.185}},
#   '10224': {'handicap': '0.5',
#    'marketName': 'Over Under Team 1',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10224': {'bookmakers': {'bestPrice': {'price': 1.111},
#       'bet365': {'bookmakerOutcomeId': '1589891921', 'price': 1.111}},
#      'outcomeName': 'Over'},
#     '10225': {'bookmakers': {'bestPrice': {'price': 6.5},
#       'bet365': {'bookmakerOutcomeId': '1589891915', 'price': 6.5}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 94.882, 'bet365': 94.882}},
#   '10226': {'handicap': '1.5',
#    'marketName': 'Over Under Team 1',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10226': {'bookmakers': {'bestPrice': {'price': 1.571},
#       'bet365': {'bookmakerOutcomeId': '1589891925', 'price': 1.571}},
#      'outcomeName': 'Over'},
#     '10227': {'bookmakers': {'bestPrice': {'price': 2.25},
#       'bet365': {'bookmakerOutcomeId': '1589891923', 'price': 2.25}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 92.509, 'bet365': 92.509}},
#   '10228': {'handicap': '2.5',
#    'marketName': 'Over Under Team 1',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10228': {'bookmakers': {'bestPrice': {'price': 2.75},
#       'bet365': {'bookmakerOutcomeId': '1589891918', 'price': 2.75}},
#      'outcomeName': 'Over'},
#     '10229': {'bookmakers': {'bestPrice': {'price': 1.4},
#       'bet365': {'bookmakerOutcomeId': '1589891919', 'price': 1.4}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 92.771, 'bet365': 92.771}},
#   '10230': {'handicap': '3.5',
#    'marketName': 'Over Under Team 1',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10230': {'bookmakers': {'bestPrice': {'price': 6.0},
#       'bet365': {'bookmakerOutcomeId': '1589891920', 'price': 6.0}},
#      'outcomeName': 'Over'},
#     '10231': {'bookmakers': {'bestPrice': {'price': 1.125},
#       'bet365': {'bookmakerOutcomeId': '1589891932', 'price': 1.125}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 94.737, 'bet365': 94.737}},
#   '10232': {'handicap': '4.5',
#    'marketName': 'Over Under Team 1',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10232': {'bookmakers': {'bestPrice': {'price': 15.0},
#       'bet365': {'bookmakerOutcomeId': '1589891933', 'price': 15.0}},
#      'outcomeName': 'Over'},
#     '10233': {'bookmakers': {'bestPrice': {'price': 1.03},
#       'bet365': {'bookmakerOutcomeId': '1589891934', 'price': 1.03}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 96.382, 'bet365': 96.382}},
#   '10234': {'handicap': '5.5',
#    'marketName': 'Over Under Team 1',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10234': {'bookmakers': {'bestPrice': {'price': 29.0},
#       'bet365': {'bookmakerOutcomeId': '1589891935', 'price': 29.0}},
#      'outcomeName': 'Over'},
#     '10235': {'bookmakers': {'bestPrice': {'price': 1.006},
#       'bet365': {'bookmakerOutcomeId': '1589891930', 'price': 1.006}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 97.227, 'bet365': 97.227}},
#   '10240': {'handicap': '0.5',
#    'marketName': 'Over Under Team 2',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10240': {'bookmakers': {'bestPrice': {'price': 1.444},
#       'bet365': {'bookmakerOutcomeId': '1589891922', 'price': 1.444}},
#      'outcomeName': 'Over'},
#     '10241': {'bookmakers': {'bestPrice': {'price': 2.625},
#       'bet365': {'bookmakerOutcomeId': '1589891916', 'price': 2.625}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 93.156, 'bet365': 93.156}},
#   '10242': {'handicap': '1.5',
#    'marketName': 'Over Under Team 2',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10242': {'bookmakers': {'bestPrice': {'price': 3.4},
#       'bet365': {'bookmakerOutcomeId': '1589891917', 'price': 3.4}},
#      'outcomeName': 'Over'},
#     '10243': {'bookmakers': {'bestPrice': {'price': 1.3},
#       'bet365': {'bookmakerOutcomeId': '1589891931', 'price': 1.3}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 94.043, 'bet365': 94.043}},
#   '10244': {'handicap': '2.5',
#    'marketName': 'Over Under Team 2',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10244': {'bookmakers': {'bestPrice': {'price': 10.0},
#       'bet365': {'bookmakerOutcomeId': '1589891926', 'price': 10.0}},
#      'outcomeName': 'Over'},
#     '10245': {'bookmakers': {'bestPrice': {'price': 1.062},
#       'bet365': {'bookmakerOutcomeId': '1589891927', 'price': 1.062}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 96.004, 'bet365': 96.004}},
#   '10246': {'handicap': '3.5',
#    'marketName': 'Over Under Team 2',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10246': {'bookmakers': {'bestPrice': {'price': 26.0},
#       'bet365': {'bookmakerOutcomeId': '1589891914', 'price': 26.0}},
#      'outcomeName': 'Over'},
#     '10247': {'bookmakers': {'bestPrice': {'price': 1.01},
#       'bet365': {'bookmakerOutcomeId': '1589891924', 'price': 1.01}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 97.223, 'bet365': 97.223}},
#   '10256': {'handicap': '0.5',
#    'marketName': 'Over Under First Half',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10256': {'bookmakers': {'bestPrice': {'price': 1.3},
#       'bet365': {'bookmakerOutcomeId': '1589892770', 'price': 1.3}},
#      'outcomeName': 'Over'},
#     '10257': {'bookmakers': {'bestPrice': {'price': 3.4},
#       'bet365': {'bookmakerOutcomeId': '1589892771', 'price': 3.4}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 94.043, 'bet365': 94.043}},
#   '10258': {'handicap': '1.5',
#    'marketName': 'Over Under First Half',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10258': {'bookmakers': {'bestPrice': {'price': 2.375},
#       'bet365': {'bookmakerOutcomeId': '1589892772', 'price': 2.375}},
#      'outcomeName': 'Over'},
#     '10259': {'bookmakers': {'bestPrice': {'price': 1.533},
#       'bet365': {'bookmakerOutcomeId': '1589892773', 'price': 1.533}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 93.165, 'bet365': 93.165}},
#   '10260': {'handicap': '2.5',
#    'marketName': 'Over Under First Half',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10260': {'bookmakers': {'bestPrice': {'price': 6.0},
#       'bet365': {'bookmakerOutcomeId': '1589892774', 'price': 6.0}},
#      'outcomeName': 'Over'},
#     '10261': {'bookmakers': {'bestPrice': {'price': 1.125},
#       'bet365': {'bookmakerOutcomeId': '1589892775', 'price': 1.125}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 94.737, 'bet365': 94.737}},
#   '10262': {'handicap': '3.5',
#    'marketName': 'Over Under First Half',
#    'marketNameShort': 'Total',
#    'oddsType': 'Over/Under',
#    'outcomes': {'10262': {'bookmakers': {'bestPrice': {'price': 17.0},
#       'bet365': {'bookmakerOutcomeId': '1589892777', 'price': 17.0}},
#      'outcomeName': 'Over'},
#     '10263': {'bookmakers': {'bestPrice': {'price': 1.025},
#       'bet365': {'bookmakerOutcomeId': '1589892779', 'price': 1.025}},
#      'outcomeName': 'Under'}},
#    'payouts': {'bestPrice': 96.671, 'bet365': 96.671}},
#   '10300': {'handicap': '0',
#    'marketName': 'Both Teams To Score First Half',
#    'marketNameShort': 'Both Score',
#    'oddsType': 'Score',
#    'outcomes': {'10300': {'bookmakers': {'bestPrice': {'price': 4.0},
#       'bet365': {'bookmakerOutcomeId': '1589893530', 'price': 4.0}},
#      'outcomeName': 'Yes'},
#     '10301': {'bookmakers': {'bestPrice': {'price': 1.222},
#       'bet365': {'bookmakerOutcomeId': '1589893537', 'price': 1.222}},
#      'outcomeName': 'No'}},
#    'payouts': {'bestPrice': 93.604, 'bet365': 93.604}},
#   '10302': {'handicap': '0',
#    'marketName': 'Both Teams To Score Second Half',
#    'marketNameShort': 'Both Score',
#    'oddsType': 'Score',
#    'outcomes': {'10302': {'bookmakers': {'bestPrice': {'price': 3.0},
#       'bet365': {'bookmakerOutcomeId': '1589892794', 'price': 3.0}},
#      'outcomeName': 'Yes'},
#     '10303': {'bookmakers': {'bestPrice': {'price': 1.363},
#       'bet365': {'bookmakerOutcomeId': '1589892795', 'price': 1.363}},
#      'outcomeName': 'No'}},
#    'payouts': {'bestPrice': 93.72, 'bet365': 93.72}}},
#  'participant1': 'Besiktas JK',
#  'participant2': 'Malmo FF',
#  'sportSlug': 'soccer',
#  'startTime': 1730907000,
#  'time': '15:30:00',
#  'tournamentId': 679,
#  'updated': 1730894607}

# %%
data
# Out:
# [{'categoryName': 'Algeria',
#   'categorySlug': 'algeria',
#   'name': 'Ligue 1',
#   'seasons': [{'end': 1749945599,
#     'events': {'0': {'date': '2024-11-07',
#       'eventId': 'id100084153130039',
#       'eventStatus': 'pre-game',
#       'participant1': 'MC Oran',
#       'participant1Id': 45001,
#       'participant2': 'ES Setif',
#       'participant2Id': 41756,
#       'startTime': 1731004200,
#       'time': '18:30:00'}},
#     'seasonId': 121135,
#     'start': 1726099200}],
#   'slug': 'ligue-1',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 841},
#  {'categoryName': 'Algeria',
#   'categorySlug': 'algeria',
#   'name': 'Ligue 1, Reserves',
#   'seasons': [{'end': 1749945599,
#     'events': {'0': {'date': '2024-11-07',
#       'eventId': 'id103618953654555',
#       'eventStatus': 'pre-game',
#       'participant1': 'Aso Chlef',
#       'participant1Id': 342634,
#       'participant2': 'MC El Bayadh',
#       'participant2Id': 847686,
#       'startTime': 1730988000,
#       'time': '14:00:00'},
#      '1': {'date': '2024-11-07',
#       'eventId': 'id103618953654553',
#       'eventStatus': 'pre-game',
#       'participant1': 'ES Mostaganem',
#       'participant1Id': 473929,
#       'participant2': 'Cr Belouizdad',
#       'participant2Id': 342638,
#       'startTime': 1730988000,
#       'time': '14:00:00'},
#      '2': {'date': '2024-11-07',
#       'eventId': 'id103618953654545',
#       'eventStatus': 'pre-game',
#       'participant1': 'AC Paradou',
#       'participant1Id': 371364,
#       'participant2': 'US Khenchela',
#       'participant2Id': 784534,
#       'startTime': 1730988000,
#       'time': '14:00:00'},
#      '3': {'date': '2024-11-07',
#       'eventId': 'id103618953654547',
#       'eventStatus': 'pre-game',
#       'participant1': 'CS Constantine',
#       'participant1Id': 342648,
#       'participant2': 'Olympique Akbou U21',
#       'participant2Id': 1063380,
#       'startTime': 1730988000,
#       'time': '14:00:00'},
#      '4': {'date': '2024-11-07',
#       'eventId': 'id103618953654549',
#       'eventStatus': 'pre-game',
#       'participant1': 'MC Oran',
#       'participant1Id': 342672,
#       'participant2': 'ES Setif',
#       'participant2Id': 342642,
#       'startTime': 1730988000,
#       'time': '14:00:00'}},
#     'seasonId': 123863,
#     'start': 1726704000}],
#   'slug': 'ligue-1-reserves',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 36189},
#  {'categoryName': 'Algeria',
#   'categorySlug': 'algeria',
#   'name': 'Ligue 2',
#   'seasons': [{'end': 1748131199,
#     'events': {'0': {'date': '2024-11-06',
#       'eventId': 'id101432154878287',
#       'eventStatus': 'pre-game',
#       'participant1': 'Ben Aknoun',
#       'participant1Id': 133444,
#       'participant2': 'GC Mascara',
#       'participant2Id': 284549,
#       'startTime': 1730901600,
#       'time': '14:00:00'}},
#     'seasonId': 122455,
#     'start': 1726790400}],
#   'slug': 'ligue-2',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 14321},
#  {'categoryName': 'Argentina',
#   'categorySlug': 'argentina',
#   'name': 'Liga Profesional',
#   'seasons': [{'end': 1734393599,
#     'events': {'0': {'date': '2024-11-06',
#       'eventId': 'id100015546657149',
#       'eventStatus': 'pre-game',
#       'participant1': 'Barracas Central',
#       'participant1Id': 65668,
#       'participant2': 'Racing Club',
#       'participant2Id': 3215,
#       'startTime': 1730916000,
#       'time': '18:00:00'},
#      '1': {'date': '2024-11-06',
#       'eventId': 'id100015546657147',
#       'eventStatus': 'pre-game',
#       'participant1': 'Instituto AC Cordoba',
#       'participant2': 'River Plate',
#       'startTime': 1730923200,
#       'time': '20:00:00'},
#      '2': {'date': '2024-11-06',
#       'eventId': 'id100015546657145',
#       'eventStatus': 'pre-game',
#       'participant1': 'CA Banfield',
#       'participant1Id': 3219,
#       'participant2': 'CA Belgrano',
#       'participant2Id': 3203,
#       'startTime': 1730923200,
#       'time': '20:00:00'},
#      '3': {'date': '2024-11-06',
#       'eventId': 'id100015546657135',
#       'eventStatus': 'pre-game',
#       'participant1': 'Boca Juniors',
#       'participant1Id': 3202,
#       'participant2': 'Godoy Cruz',
#       'participant2Id': 6074,
#       'startTime': 1730932200,
#       'time': '22:30:00'},
#      '4': {'date': '2024-11-07',
#       'eventId': 'id100015554879045',
#       'eventStatus': 'pre-game',
#       'participant1': 'Instituto AC Cordoba',
#       'participant1Id': 4937,
#       'participant2': 'River Plate',
#       'participant2Id': 3211,
#       'startTime': 1730939400,
#       'time': '00:30:00'},
#      '5': {'date': '2024-11-07',
#       'eventId': 'id100015546657143',
#       'eventStatus': 'pre-game',
#       'participant1': 'Defensa y Justicia',
#       'participant1Id': 36839,
#       'participant2': 'Argentinos Juniors',
#       'participant2Id': 3216,
#       'startTime': 1731015900,
#       'time': '21:45:00'},
#      '6': {'date': '2024-11-07',
#       'eventId': 'id100015546657137',
#       'eventStatus': 'pre-game',
#       'participant1': 'CA Talleres de Cordoba',
#       'participant1Id': 3210,
#       'participant2': 'CA Lanus',
#       'participant2Id': 3218,
#       'startTime': 1731015900,
#       'time': '21:45:00'},
#      '7': {'date': '2024-11-08',
#       'eventId': 'id100015546657139',
#       'eventStatus': 'pre-game',
#       'participant1': 'CA Platense',
#       'participant1Id': 36837,
#       'participant2': 'Deportivo Riestra',
#       'participant2Id': 191648,
#       'startTime': 1731024000,
#       'time': '00:00:00'},
#      '8': {'date': '2024-11-08',
#       'eventId': 'id100015546657141',
#       'eventStatus': 'pre-game',
#       'participant1': 'Velez Sarsfield',
#       'participant1Id': 3208,
#       'participant2': 'CA Tigre',
#       'participant2Id': 7628,
#       'startTime': 1731024000,
#       'time': '00:00:00'},
#      '9': {'date': '2024-11-09',
#       'eventId': 'id100015546657177',
#       'eventStatus': 'pre-game',
#       'participant1': 'Union de Santa Fe',
#       'participant1Id': 3204,
#       'participant2': 'Atletico Tucuman',
#       'participant2Id': 36833,
#       'startTime': 1731181500,
#       'time': '19:45:00'},
#      '10': {'date': '2024-11-09',
#       'eventId': 'id100015546657181',
#       'eventStatus': 'pre-game',
#       'participant1': 'Gimnasia',
#       'participant1Id': 3205,
#       'participant2': "Newell's",
#       'participant2Id': 3212,
#       'startTime': 1731182400,
#       'time': '20:00:00'},
#      '11': {'date': '2024-11-09',
#       'eventId': 'id100015546657157',
#       'eventStatus': 'pre-game',
#       'participant1': 'Rosario Central',
#       'participant1Id': 3217,
#       'participant2': 'San Lorenzo',
#       'participant2Id': 3201,
#       'startTime': 1731189600,
#       'time': '22:00:00'},
#      '12': {'date': '2024-11-10',
#       'eventId': 'id100015546657179',
#       'eventStatus': 'pre-game',
#       'participant1': 'Huracan',
#       'participant1Id': 7629,
#       'participant2': 'Independiente',
#       'participant2Id': 3209,
#       'startTime': 1731196800,
#       'time': '00:00:00'},
#      '13': {'date': '2024-11-10',
#       'eventId': 'id100015546657155',
#       'eventStatus': 'pre-game',
#       'participant1': 'Central Cordoba',
#       'participant1Id': 65676,
#       'participant2': 'Estudiantes LP',
#       'participant2Id': 3206,
#       'startTime': 1731265200,
#       'time': '19:00:00'},
#      '14': {'date': '2024-11-10',
#       'eventId': 'id100015546657161',
#       'eventStatus': 'pre-game',
#       'participant1': 'River Plate',
#       'participant1Id': 3211,
#       'participant2': 'Barracas Central',
#       'participant2Id': 65668,
#       'startTime': 1731269700,
#       'time': '20:15:00'},
#      '15': {'date': '2024-11-10',
#       'eventId': 'id100015546657173',
#       'eventStatus': 'pre-game',
#       'participant1': 'Godoy Cruz',
#       'participant1Id': 6074,
#       'participant2': 'Talleres',
#       'participant2Id': 3210,
#       'startTime': 1731276900,
#       'time': '22:15:00'},
#      '16': {'date': '2024-11-10',
#       'eventId': 'id100015546657159',
#       'eventStatus': 'pre-game',
#       'participant1': 'Racing Club Avellaneda',
#       'participant1Id': 3215,
#       'participant2': 'Independiente Rivadavia',
#       'participant2Id': 36842,
#       'startTime': 1731277800,
#       'time': '22:30:00'},
#      '17': {'date': '2024-11-11',
#       'eventId': 'id100015546657175',
#       'eventStatus': 'pre-game',
#       'participant1': 'Sarmiento',
#       'participant1Id': 42338,
#       'participant2': 'Boca Juniors',
#       'participant2Id': 3202,
#       'startTime': 1731285000,
#       'time': '00:30:00'},
#      '18': {'date': '2024-11-11',
#       'eventId': 'id100015546657169',
#       'eventStatus': 'pre-game',
#       'participant1': 'Riestra',
#       'participant1Id': 191648,
#       'participant2': 'Velez Sarsfield',
#       'participant2Id': 3208,
#       'startTime': 1731351600,
#       'time': '19:00:00'},
#      '19': {'date': '2024-11-11',
#       'eventId': 'id100015546657171',
#       'eventStatus': 'pre-game',
#       'participant1': 'Lanus',
#       'participant1Id': 3218,
#       'participant2': 'Platense',
#       'participant2Id': 36837,
#       'startTime': 1731361500,
#       'time': '21:45:00'},
#      '20': {'date': '2024-11-11',
#       'eventId': 'id100015546657167',
#       'eventStatus': 'pre-game',
#       'participant1': 'Tigre',
#       'participant1Id': 7628,
#       'participant2': 'Defensa y Justicia',
#       'participant2Id': 36839,
#       'startTime': 1731361500,
#       'time': '21:45:00'},
#      '21': {'date': '2024-11-12',
#       'eventId': 'id100015546657163',
#       'eventStatus': 'pre-game',
#       'participant1': '\tBelgrano',
#       'participant1Id': 3203,
#       'participant2': 'Instituto AC Cordoba',
#       'participant2Id': 4937,
#       'startTime': 1731369600,
#       'time': '00:00:00'},
#      '22': {'date': '2024-11-12',
#       'eventId': 'id100015546657165',
#       'eventStatus': 'pre-game',
#       'participant1': 'Argentinos Juniors',
#       'participant1Id': 3216,
#       'participant2': 'Banfield',
#       'participant2Id': 3219,
#       'startTime': 1731369600,
#       'time': '00:00:00'}},
#     'seasonId': 114317,
#     'start': 1715299200}],
#   'slug': 'liga-profesional',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 155},
#  {'categoryName': 'Armenia',
#   'categorySlug': 'armenia',
#   'name': 'Premier League',
#   'seasons': [{'end': 1751327999,
#     'events': {'0': {'date': '2024-11-06',
#       'eventId': 'id100067154710265',
#       'eventStatus': 'pre-game',
#       'participant1': 'Urartu',
#       'participant1Id': 2584,
#       'participant2': 'BKMA Yerevan',
#       'participant2Id': 1214124,
#       'startTime': 1730905200,
#       'time': '15:00:00'}},
#     'seasonId': 121029,
#     'start': 1722556800}],
#   'slug': 'premier-league',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 671},
#  {'categoryName': 'Australia',
#   'categorySlug': 'australia',
#   'name': 'A-League',
#   'seasons': [{'end': 1748735999,
#     'events': {'0': {'date': '2024-11-08',
#       'eventId': 'id100013652130475',
#       'eventStatus': 'pre-game',
#       'participant1': 'Western Sydney',
#       'participant1Id': 72926,
#       'participant2': 'Newcastle Jets',
#       'participant2Id': 2934,
#       'startTime': 1731054900,
#       'time': '08:35:00'},
#      '1': {'date': '2024-11-09',
#       'eventId': 'id100013652130477',
#       'eventStatus': 'pre-game',
#       'participant1': 'Melbourne Victory',
#       'participant1Id': 5970,
#       'participant2': 'Brisbane Roar FC',
#       'participant2Id': 5968,
#       'startTime': 1731132000,
#       'time': '06:00:00'},
#      '2': {'date': '2024-11-09',
#       'eventId': 'id100013652130481',
#       'eventStatus': 'pre-game',
#       'participant1': 'Adelaide United',
#       'participant1Id': 2946,
#       'participant2': 'Western United FC',
#       'participant2Id': 199320,
#       'startTime': 1731141300,
#       'time': '08:35:00'},
#      '3': {'date': '2024-11-10',
#       'eventId': 'id100013652130483',
#       'eventStatus': 'pre-game',
#       'participant1': 'Central Coast Mariners',
#       'participant1Id': 5966,
#       'participant2': 'Wellington Phoenix',
#       'participant2Id': 7568,
#       'startTime': 1731214800,
#       'time': '05:00:00'},
#      '4': {'date': '2024-11-10',
#       'eventId': 'id100013652130479',
#       'eventStatus': 'pre-game',
#       'participant1': 'Sydney FC',
#       'participant1Id': 5971,
#       'participant2': 'Macarthur FC',
#       'participant2Id': 744369,
#       'startTime': 1731222000,
#       'time': '07:00:00'},
#      '5': {'date': '2024-11-10',
#       'eventId': 'id100013652130485',
#       'eventStatus': 'pre-game',
#       'participant1': 'Perth Glory',
#       'participant1Id': 2945,
#       'participant2': 'Melbourne City',
#       'participant2Id': 42210,
#       'startTime': 1731231900,
#       'time': '09:45:00'}},
#     'seasonId': 120979,
#     'start': 1729209600}],
#   'slug': 'aleague',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 136},
#  {'categoryName': 'Australia',
#   'categorySlug': 'australia',
#   'name': 'A-League, Women',
#   'seasons': [{'end': 1747612799,
#     'events': {'0': {'date': '2024-11-08',
#       'eventId': 'id100189453562887',
#       'eventStatus': 'pre-game',
#       'participant1': 'Western United FC',
#       'participant1Id': 943721,
#       'participant2': 'Central Coast Mariners',
#       'participant2Id': 771208,
#       'startTime': 1731052800,
#       'time': '08:00:00'},
#      '1': {'date': '2024-11-09',
#       'eventId': 'id100189453562889',
#       'eventStatus': 'pre-game',
#       'participant1': 'Melbourne Victory',
#       'participant1Id': 174100,
#       'participant2': 'Melbourne City FC',
#       'participant2Id': 227542,
#       'startTime': 1731122100,
#       'time': '03:15:00'},
#      '2': {'date': '2024-11-10',
#       'eventId': 'id100189453562897',
#       'eventStatus': 'pre-game',
#       'participant1': 'Perth Glory FC',
#       'participant1Id': 174104,
#       'participant2': 'Newcastle Jets',
#       'participant2Id': 174102,
#       'startTime': 1731222000,
#       'time': '07:00:00'}},
#     'seasonId': 123819,
#     'start': 1730419200}],
#   'slug': 'aleague-women',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 1894},
#  {'categoryName': 'Austria',
#   'categorySlug': 'austria',
#   'name': '2. Liga',
#   'seasons': [{'end': 1748217599,
#     'events': {'0': {'date': '2024-11-08',
#       'eventId': 'id100013551157737',
#       'eventStatus': 'pre-game',
#       'participant1': 'SW Bregenz',
#       'participant1Id': 7786,
#       'participant2': 'SKN St. Polten',
#       'participant2Id': 2119,
#       'startTime': 1731085200,
#       'time': '17:00:00'},
#      '1': {'date': '2024-11-08',
#       'eventId': 'id100013551157739',
#       'eventStatus': 'pre-game',
#       'participant1': 'SV Horn',
#       'participant1Id': 2111,
#       'participant2': 'Floridsdorfer AC',
#       'participant2Id': 7785,
#       'startTime': 1731085200,
#       'time': '17:00:00'},
#      '2': {'date': '2024-11-08',
#       'eventId': 'id100013551157735',
#       'eventStatus': 'pre-game',
#       'participant1': 'SV StripfingWeiden',
#       'participant1Id': 218138,
#       'participant2': 'Kapfenberger SV',
#       'participant2Id': 2067,
#       'startTime': 1731085200,
#       'time': '17:00:00'},
#      '3': {'date': '2024-11-08',
#       'eventId': 'id100013551157733',
#       'eventStatus': 'pre-game',
#       'participant1': 'SKU Amstetten',
#       'participant1Id': 6281,
#       'participant2': 'SV Lafnitz',
#       'participant2Id': 105969,
#       'startTime': 1731085200,
#       'time': '17:00:00'},
#      '4': {'date': '2024-11-08',
#       'eventId': 'id100013551157741',
#       'eventStatus': 'pre-game',
#       'participant1': 'First Vienna FC 1894',
#       'participant1Id': 2054,
#       'participant2': 'SC Austria Lustenau',
#       'participant2Id': 2062,
#       'startTime': 1731094200,
#       'time': '19:30:00'},
#      '5': {'date': '2024-11-09',
#       'eventId': 'id100013551157743',
#       'eventStatus': 'pre-game',
#       'participant1': 'SK Sturm Graz II',
#       'participant1Id': 2103,
#       'participant2': 'SV Ried',
#       'participant2Id': 2049,
#       'startTime': 1731178800,
#       'time': '19:00:00'},
#      '6': {'date': '2024-11-10',
#       'eventId': 'id100013551157731',
#       'eventStatus': 'pre-game',
#       'participant1': 'ASK Voitsberg',
#       'participant1Id': 2081,
#       'participant2': 'FC Admira Wacker Modling',
#       'participant2Id': 2050,
#       'startTime': 1731231000,
#       'time': '09:30:00'},
#      '7': {'date': '2024-11-10',
#       'eventId': 'id100013551157729',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Liefering',
#       'participant1Id': 7790,
#       'participant2': 'Rapid Vienna II',
#       'participant2Id': 2092,
#       'startTime': 1731238200,
#       'time': '11:30:00'}},
#     'seasonId': 118725,
#     'start': 1722556800}],
#   'slug': '2-liga',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 135},
#  {'categoryName': 'Austria',
#   'categorySlug': 'austria',
#   'name': 'Bundesliga',
#   'seasons': [{'end': 1748822399,
#     'events': {'0': {'date': '2024-11-09',
#       'eventId': 'id100004551143507',
#       'eventStatus': 'pre-game',
#       'participant1': 'TSV Hartberg',
#       'participant1Id': 2075,
#       'participant2': 'SK Sturm Graz',
#       'participant2Id': 2051,
#       'startTime': 1731168000,
#       'time': '16:00:00'},
#      '1': {'date': '2024-11-09',
#       'eventId': 'id100004551143505',
#       'eventStatus': 'pre-game',
#       'participant1': 'Grazer AK',
#       'participant1Id': 2052,
#       'participant2': 'WSG Tirol',
#       'participant2Id': 5405,
#       'startTime': 1731168000,
#       'time': '16:00:00'},
#      '2': {'date': '2024-11-09',
#       'eventId': 'id100004551143497',
#       'eventStatus': 'pre-game',
#       'participant1': 'Wolfsberger AC',
#       'participant1Id': 2076,
#       'participant2': 'FK Austria Vienna',
#       'participant2Id': 2203,
#       'startTime': 1731168000,
#       'time': '16:00:00'},
#      '3': {'date': '2024-11-10',
#       'eventId': 'id100004551143501',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Blau Weiss Linz',
#       'participant1Id': 2113,
#       'participant2': 'FC Red Bull Salzburg',
#       'participant2Id': 2046,
#       'startTime': 1731245400,
#       'time': '13:30:00'},
#      '4': {'date': '2024-11-10',
#       'eventId': 'id100004551143503',
#       'eventStatus': 'pre-game',
#       'participant1': 'SCR Altach',
#       'participant1Id': 4856,
#       'participant2': 'Linzer ASK',
#       'participant2Id': 2058,
#       'startTime': 1731245400,
#       'time': '13:30:00'},
#      '5': {'date': '2024-11-10',
#       'eventId': 'id100004551143499',
#       'eventStatus': 'pre-game',
#       'participant1': 'Rapid Vienna',
#       'participant1Id': 2055,
#       'participant2': 'SK Austria Klagenfurt',
#       'participant2Id': 43254,
#       'startTime': 1731254400,
#       'time': '16:00:00'},
#      '6': {'date': '2024-11-23',
#       'eventId': 'id100004551143519',
#       'eventStatus': 'pre-game',
#       'participant1': 'WSG Tirol',
#       'participant1Id': 5405,
#       'participant2': 'Rapid Vienna',
#       'participant2Id': 2055,
#       'startTime': 1732377600,
#       'time': '16:00:00'},
#      '7': {'date': '2024-11-23',
#       'eventId': 'id100004551143509',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Red Bull Salzburg',
#       'participant1Id': 2046,
#       'participant2': 'Linzer ASK',
#       'participant2Id': 2058,
#       'startTime': 1732377600,
#       'time': '16:00:00'},
#      '8': {'date': '2024-11-23',
#       'eventId': 'id100004551143515',
#       'eventStatus': 'pre-game',
#       'participant1': 'SK Sturm Graz',
#       'participant1Id': 2051,
#       'participant2': 'SK Austria Klagenfurt',
#       'participant2Id': 43254,
#       'startTime': 1732377600,
#       'time': '16:00:00'},
#      '9': {'date': '2024-11-24',
#       'eventId': 'id100004551143517',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Blau Weiss Linz',
#       'participant1Id': 2113,
#       'participant2': 'Grazer AK',
#       'participant2Id': 2052,
#       'startTime': 1732455000,
#       'time': '13:30:00'},
#      '10': {'date': '2024-11-24',
#       'eventId': 'id100004551143511',
#       'eventStatus': 'pre-game',
#       'participant1': 'Wolfsberger AC',
#       'participant1Id': 2076,
#       'participant2': 'SCR Altach',
#       'participant2Id': 4856,
#       'startTime': 1732455000,
#       'time': '13:30:00'},
#      '11': {'date': '2024-11-24',
#       'eventId': 'id100004551143513',
#       'eventStatus': 'pre-game',
#       'participant1': 'FK Austria Vienna',
#       'participant1Id': 2203,
#       'participant2': 'TSV Hartberg',
#       'participant2Id': 2075,
#       'startTime': 1732464000,
#       'time': '16:00:00'}},
#     'seasonId': 118723,
#     'start': 1722556800}],
#   'slug': 'bundesliga',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 45},
#  {'categoryName': 'Azerbaijan',
#   'categorySlug': 'azerbaijan',
#   'name': 'Premier League',
#   'seasons': [{'end': 1748303999,
#     'events': {'0': {'date': '2024-11-06',
#       'eventId': 'id100070953509233',
#       'eventStatus': 'pre-game',
#       'participant1': 'Zira FK',
#       'participant1Id': 173406,
#       'participant2': 'Araz Nakhchivan PFK',
#       'participant2Id': 119066,
#       'startTime': 1730905200,
#       'time': '15:00:00'}},
#     'seasonId': 121111,
#     'start': 1722556800}],
#   'slug': 'premier-league',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 709},
#  {'categoryName': 'Belgium',
#   'categorySlug': 'belgium',
#   'name': 'Challenger Pro League',
#   'seasons': [{'end': 1745020799,
#     'events': {'0': {'date': '2024-11-08',
#       'eventId': 'id100000950716025',
#       'eventStatus': 'pre-game',
#       'participant1': 'Lierse Kempenzonen',
#       'participant1Id': 116075,
#       'participant2': 'KSC Lokeren Temse',
#       'participant2Id': 761290,
#       'startTime': 1731092400,
#       'time': '19:00:00'},
#      '1': {'date': '2024-11-08',
#       'eventId': 'id100000950716035',
#       'eventStatus': 'pre-game',
#       'participant1': 'RFC Liege',
#       'participant1Id': 221182,
#       'participant2': 'RWD Molenbeek 47',
#       'participant2Id': 220436,
#       'startTime': 1731092400,
#       'time': '19:00:00'},
#      '2': {'date': '2024-11-09',
#       'eventId': 'id100000950716031',
#       'eventStatus': 'pre-game',
#       'participant1': 'Jong KRC Genk',
#       'participant1Id': 912461,
#       'participant2': 'Club NXT',
#       'participant2Id': 76445,
#       'startTime': 1731164400,
#       'time': '15:00:00'},
#      '3': {'date': '2024-11-09',
#       'eventId': 'id100000950716021',
#       'eventStatus': 'pre-game',
#       'participant1': 'SK Beveren',
#       'participant1Id': 4859,
#       'participant2': 'Royal Francs Borains',
#       'participant2Id': 280181,
#       'startTime': 1731178800,
#       'time': '19:00:00'},
#      '4': {'date': '2024-11-09',
#       'eventId': 'id100000950716027',
#       'eventStatus': 'pre-game',
#       'participant1': 'Lommel SK',
#       'participant1Id': 5046,
#       'participant2': 'KMSK Deinze',
#       'participant2Id': 2920,
#       'startTime': 1731178800,
#       'time': '19:00:00'},
#      '5': {'date': '2024-11-10',
#       'eventId': 'id100000950716023',
#       'eventStatus': 'pre-game',
#       'participant1': 'SV Zulte Waregem',
#       'participant1Id': 2933,
#       'participant2': 'Raal La Louviere',
#       'participant2Id': 752197,
#       'startTime': 1731241800,
#       'time': '12:30:00'},
#      '6': {'date': '2024-11-10',
#       'eventId': 'id100000950716033',
#       'eventStatus': 'pre-game',
#       'participant1': 'RFC Seraing',
#       'participant1Id': 34985,
#       'participant2': 'RSC Anderlecht Futures',
#       'participant2Id': 912459,
#       'startTime': 1731250800,
#       'time': '15:00:00'},
#      '7': {'date': '2024-11-10',
#       'eventId': 'id100000950716029',
#       'eventStatus': 'pre-game',
#       'participant1': 'KAS Eupen',
#       'participant1Id': 2926,
#       'participant2': 'Patro Eisden Maasmechelen',
#       'participant2Id': 35076,
#       'startTime': 1731262500,
#       'time': '18:15:00'}},
#     'seasonId': 119501,
#     'start': 1723766400}],
#   'slug': 'challenger-pro-league',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 9},
#  {'categoryName': 'Belgium',
#   'categorySlug': 'belgium',
#   'name': 'Pro League',
#   'seasons': [{'end': 1748563199,
#     'events': {'0': {'date': '2024-11-08',
#       'eventId': 'id100003850715039',
#       'eventStatus': 'pre-game',
#       'participant1': 'Sint-Truidense VV',
#       'participant1Id': 2895,
#       'participant2': 'KV Mechelen',
#       'participant2Id': 5044,
#       'startTime': 1731095100,
#       'time': '19:45:00'},
#      '1': {'date': '2024-11-09',
#       'eventId': 'id100003850715033',
#       'eventStatus': 'pre-game',
#       'participant1': 'KV Kortrijk',
#       'participant1Id': 4858,
#       'participant2': 'Royal Antwerp FC',
#       'participant2Id': 2889,
#       'startTime': 1731164400,
#       'time': '15:00:00'},
#      '2': {'date': '2024-11-09',
#       'eventId': 'id100003850715043',
#       'eventStatus': 'pre-game',
#       'participant1': 'FCV Dender EH',
#       'participant1Id': 2922,
#       'participant2': 'Oud-Heverlee Leuven',
#       'participant2Id': 2918,
#       'startTime': 1731172500,
#       'time': '17:15:00'},
#      '3': {'date': '2024-11-09',
#       'eventId': 'id100003850715041',
#       'eventStatus': 'pre-game',
#       'participant1': 'Royal Charleroi SC',
#       'participant1Id': 2898,
#       'participant2': 'KVC Westerlo',
#       'participant2Id': 2893,
#       'startTime': 1731181500,
#       'time': '19:45:00'},
#      '4': {'date': '2024-11-10',
#       'eventId': 'id100003850715037',
#       'eventStatus': 'pre-game',
#       'participant1': 'Cercle Brugge KSV',
#       'participant1Id': 2929,
#       'participant2': 'RSC Anderlecht',
#       'participant2Id': 2900,
#       'startTime': 1731241800,
#       'time': '12:30:00'},
#      '5': {'date': '2024-11-10',
#       'eventId': 'id100003850715031',
#       'eventStatus': 'pre-game',
#       'participant1': 'KAA Gent',
#       'participant1Id': 2903,
#       'participant2': 'Standard Liège',
#       'participant2Id': 2901,
#       'startTime': 1731250800,
#       'time': '15:00:00'},
#      '6': {'date': '2024-11-10',
#       'eventId': 'id100003850715029',
#       'eventStatus': 'pre-game',
#       'participant1': 'Union Saint-Gilloise',
#       'participant1Id': 4860,
#       'participant2': 'KRC Genk',
#       'participant2Id': 2890,
#       'startTime': 1731259800,
#       'time': '17:30:00'},
#      '7': {'date': '2024-11-10',
#       'eventId': 'id100003850715035',
#       'eventStatus': 'pre-game',
#       'participant1': 'K Beerschot VA',
#       'participant1Id': 169260,
#       'participant2': 'Club Brugge KV',
#       'participant2Id': 2888,
#       'startTime': 1731262500,
#       'time': '18:15:00'}},
#     'seasonId': 119497,
#     'start': 1721952000}],
#   'slug': 'pro-league',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 38},
#  {'categoryName': 'Bosnia & Herzegovina',
#   'categorySlug': 'bosnia-herzegovina',
#   'name': 'Premijer Liga',
#   'seasons': [{'end': 1748217599,
#     'events': {'0': {'date': '2024-11-06',
#       'eventId': 'id100022255207247',
#       'eventStatus': 'pre-game',
#       'participant1': 'Zrinjski Mostar',
#       'participant1Id': 5178,
#       'participant2': 'FK Sarajevo',
#       'participant2Id': 5237,
#       'startTime': 1730912400,
#       'time': '17:00:00'},
#      '1': {'date': '2024-11-08',
#       'eventId': 'id100022251859103',
#       'eventStatus': 'pre-game',
#       'participant1': 'NK Posusje',
#       'participant1Id': 6147,
#       'participant2': 'Sloboda Tuzla',
#       'participant2Id': 6247,
#       'startTime': 1731085200,
#       'time': '17:00:00'}},
#     'seasonId': 120513,
#     'start': 1722643200}],
#   'slug': 'premijer-liga',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 222},
#  {'categoryName': 'Brazil',
#   'categorySlug': 'brazil',
#   'name': 'Brasileiro Serie A',
#   'seasons': [{'end': 1733788799,
#     'events': {'0': {'date': '2024-11-07',
#       'eventId': 'id100032548215073',
#       'eventStatus': 'pre-game',
#       'participant1': 'Cruzeiro MG',
#       'participant1Id': 1954,
#       'participant2': 'Flamengo RJ',
#       'participant2Id': 5981,
#       'startTime': 1730937600,
#       'time': '00:00:00'},
#      '1': {'date': '2024-11-07',
#       'eventId': 'id100032548215087',
#       'eventStatus': 'pre-game',
#       'participant1': 'Atletico GO',
#       'participant1Id': 7314,
#       'participant2': 'Clube Atletico MG',
#       'participant2Id': 1977,
#       'startTime': 1730937600,
#       'time': '00:00:00'},
#      '2': {'date': '2024-11-08',
#       'eventId': 'id100032548215091',
#       'eventStatus': 'pre-game',
#       'participant1': 'Internacional RS',
#       'participant1Id': 1966,
#       'participant2': 'Fluminense RJ',
#       'participant2Id': 1961,
#       'startTime': 1731103200,
#       'time': '22:00:00'},
#      '3': {'date': '2024-11-09',
#       'eventId': 'id100032548215101',
#       'eventStatus': 'pre-game',
#       'participant1': 'Palmeiras SP',
#       'participant1Id': 1963,
#       'participant2': 'Gremio RS',
#       'participant2Id': 5926,
#       'startTime': 1731112200,
#       'time': '00:30:00'},
#      '4': {'date': '2024-11-09',
#       'eventId': 'id100032548215095',
#       'eventStatus': 'pre-game',
#       'participant1': 'Vitoria BA',
#       'participant1Id': 1962,
#       'participant2': 'Corinthians SP',
#       'participant2Id': 1957,
#       'startTime': 1731180600,
#       'time': '19:30:00'},
#      '5': {'date': '2024-11-09',
#       'eventId': 'id100032548215099',
#       'eventStatus': 'pre-game',
#       'participant1': 'Botafogo RJ',
#       'participant1Id': 1958,
#       'participant2': 'Cuiaba MT',
#       'participant2Id': 49202,
#       'startTime': 1731180600,
#       'time': '19:30:00'},
#      '6': {'date': '2024-11-09',
#       'eventId': 'id100032548215093',
#       'eventStatus': 'pre-game',
#       'participant1': 'Cruzeiro MG',
#       'participant1Id': 1954,
#       'participant2': 'Criciuma SC',
#       'participant2Id': 1984,
#       'startTime': 1731189600,
#       'time': '22:00:00'},
#      '7': {'date': '2024-11-09',
#       'eventId': 'id100032548215107',
#       'eventStatus': 'pre-game',
#       'participant1': 'Atletico GO',
#       'participant1Id': 7314,
#       'participant2': 'Bragantino SP',
#       'participant2Id': 1999,
#       'startTime': 1731189600,
#       'time': '22:00:00'},
#      '8': {'date': '2024-11-09',
#       'eventId': 'id100032548215105',
#       'eventStatus': 'pre-game',
#       'participant1': 'Fortaleza CE',
#       'participant1Id': 2020,
#       'participant2': 'Vasco da Gama RJ',
#       'participant2Id': 1974,
#       'startTime': 1731189600,
#       'time': '22:00:00'},
#      '9': {'date': '2024-11-09',
#       'eventId': 'id100032548215109',
#       'eventStatus': 'pre-game',
#       'participant1': 'Juventude RS',
#       'participant1Id': 1980,
#       'participant2': 'EC Bahia BA',
#       'participant2Id': 1955,
#       'startTime': 1731189600,
#       'time': '22:00:00'},
#      '10': {'date': '2024-11-10',
#       'eventId': 'id100032548215103',
#       'eventStatus': 'pre-game',
#       'participant1': 'Sao Paulo SP',
#       'participant1Id': 1981,
#       'participant2': 'Athletico PR',
#       'participant2Id': 1967,
#       'startTime': 1731196800,
#       'time': '00:00:00'},
#      '11': {'date': '2024-11-13',
#       'eventId': 'id100032548215097',
#       'eventStatus': 'pre-game',
#       'participant1': 'Flamengo RJ',
#       'participant1Id': 5981,
#       'participant2': 'Clube Atletico MG',
#       'participant2Id': 1977,
#       'startTime': 1731538800,
#       'time': '23:00:00'},
#      '12': {'date': '2024-11-20',
#       'eventId': 'id100032548215121',
#       'eventStatus': 'pre-game',
#       'participant1': 'Corinthians SP',
#       'participant1Id': 1957,
#       'participant2': 'Cruzeiro MG',
#       'participant2Id': 1954,
#       'startTime': 1732111200,
#       'time': '14:00:00'},
#      '13': {'date': '2024-11-20',
#       'eventId': 'id100032548215125',
#       'eventStatus': 'pre-game',
#       'participant1': 'Athletico PR',
#       'participant1Id': 1967,
#       'participant2': 'Atletico GO',
#       'participant2Id': 7314,
#       'startTime': 1732131000,
#       'time': '19:30:00'},
#      '14': {'date': '2024-11-20',
#       'eventId': 'id100032548215123',
#       'eventStatus': 'pre-game',
#       'participant1': 'Bragantino SP',
#       'participant1Id': 1999,
#       'participant2': 'Sao Paulo SP',
#       'participant2Id': 1981,
#       'startTime': 1732131000,
#       'time': '19:30:00'},
#      '15': {'date': '2024-11-20',
#       'eventId': 'id100032548215129',
#       'eventStatus': 'pre-game',
#       'participant1': 'Criciuma SC',
#       'participant1Id': 1984,
#       'participant2': 'Vitoria BA',
#       'participant2Id': 1962,
#       'startTime': 1732131000,
#       'time': '19:30:00'},
#      '16': {'date': '2024-11-20',
#       'eventId': 'id100032548215127',
#       'eventStatus': 'pre-game',
#       'participant1': 'Cuiaba MT',
#       'participant1Id': 49202,
#       'participant2': 'Flamengo RJ',
#       'participant2Id': 5981,
#       'startTime': 1732140000,
#       'time': '22:00:00'},
#      '17': {'date': '2024-11-20',
#       'eventId': 'id100032548215115',
#       'eventStatus': 'pre-game',
#       'participant1': 'EC Bahia BA',
#       'participant1Id': 1955,
#       'participant2': 'Palmeiras SP',
#       'participant2Id': 1963,
#       'startTime': 1732143600,
#       'time': '23:00:00'},
#      '18': {'date': '2024-11-21',
#       'eventId': 'id100032548215113',
#       'eventStatus': 'pre-game',
#       'participant1': 'Clube Atletico MG',
#       'participant1Id': 1977,
#       'participant2': 'Botafogo RJ',
#       'participant2Id': 1958,
#       'startTime': 1732149000,
#       'time': '00:30:00'}},
#     'seasonId': 113943,
#     'start': 1712966400}],
#   'slug': 'brasileiro-serie-a',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 325},
#  {'categoryName': 'Brazil',
#   'categorySlug': 'brazil',
#   'name': 'Brasileiro Serie B',
#   'seasons': [{'end': 1732751999,
#     'events': {'0': {'date': '2024-11-09',
#       'eventId': 'id100039048424577',
#       'eventStatus': 'pre-game',
#       'participant1': 'Gremio Novorizontino',
#       'participant1Id': 36799,
#       'participant2': 'Operario PR',
#       'participant2Id': 37092,
#       'startTime': 1731182400,
#       'time': '20:00:00'},
#      '1': {'date': '2024-11-09',
#       'eventId': 'id100039048424563',
#       'eventStatus': 'pre-game',
#       'participant1': 'CRB AL',
#       'participant1Id': 9069,
#       'participant2': 'Goiás GO',
#       'participant2Id': 602,
#       'startTime': 1731182400,
#       'time': '20:00:00'},
#      '2': {'date': '2024-11-09',
#       'eventId': 'id100039048424561',
#       'eventStatus': 'pre-game',
#       'participant1': 'Avai SC',
#       'participant2': 'Mirassol SP',
#       'startTime': 1731182400,
#       'time': '20:00:00'},
#      '3': {'date': '2024-11-10',
#       'eventId': 'id100039048424569',
#       'eventStatus': 'pre-game',
#       'participant1': 'Sport Recife PE',
#       'participant1Id': 1959,
#       'participant2': 'Chapecoense SC',
#       'participant2Id': 21845,
#       'startTime': 1731274200,
#       'time': '21:30:00'},
#      '4': {'date': '2024-11-11',
#       'eventId': 'id100039048424571',
#       'eventStatus': 'pre-game',
#       'participant1': 'Vila Nova GO',
#       'participant2': 'Ponte Preta SP',
#       'startTime': 1731360600,
#       'time': '21:30:00'},
#      '5': {'date': '2024-11-12',
#       'eventId': 'id100039048424565',
#       'eventStatus': 'pre-game',
#       'participant1': 'Coritiba PR',
#       'participant2': 'Santos SP',
#       'startTime': 1731369600,
#       'time': '00:00:00'},
#      '6': {'date': '2024-11-12',
#       'eventId': 'id100039048424567',
#       'eventStatus': 'pre-game',
#       'participant1': 'Paysandu PA',
#       'participant2': 'Brusque SC',
#       'startTime': 1731369600,
#       'time': '00:00:00'},
#      '7': {'date': '2024-11-12',
#       'eventId': 'id100039048424579',
#       'eventStatus': 'pre-game',
#       'participant1': 'America MG',
#       'participant2': 'Ituano SP',
#       'startTime': 1731448800,
#       'time': '22:00:00'},
#      '8': {'date': '2024-11-13',
#       'eventId': 'id100039048424573',
#       'eventStatus': 'pre-game',
#       'participant1': 'Guarani SP',
#       'participant2': 'Amazonas AM',
#       'startTime': 1731456000,
#       'time': '00:00:00'}},
#     'seasonId': 114439,
#     'start': 1713484800}],
#   'slug': 'brasileiro-serie-b',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 390},
#  {'categoryName': 'Brazil',
#   'categorySlug': 'brazil',
#   'name': 'Carioca, Serie B1',
#   'seasons': [{'end': 1733270399,
#     'events': {'0': {'date': '2024-11-06',
#       'eventId': 'id104067752325605',
#       'eventStatus': 'pre-game',
#       'participant1': 'Friburguense AC RJ',
#       'participant1Id': 6979,
#       'participant2': 'Sao Goncalo EC RJ',
#       'participant2Id': 327307,
#       'startTime': 1730916000,
#       'time': '18:00:00'},
#      '1': {'date': '2024-11-06',
#       'eventId': 'id104067752325603',
#       'eventStatus': 'pre-game',
#       'participant1': 'Artsul FC RJ',
#       'participant1Id': 327295,
#       'participant2': 'SE Belford Roxo RJ',
#       'participant2Id': 2184600396234887168,
#       'startTime': 1730916000,
#       'time': '18:00:00'},
#      '2': {'date': '2024-11-06',
#       'eventId': 'id104067752325609',
#       'eventStatus': 'pre-game',
#       'participant1': 'Serrano FC RJ',
#       'participant1Id': 327299,
#       'participant2': 'Perolas Negras RJ',
#       'participant2Id': 585713,
#       'startTime': 1730916000,
#       'time': '18:00:00'},
#      '3': {'date': '2024-11-06',
#       'eventId': 'id104067752325607',
#       'eventStatus': 'pre-game',
#       'participant1': 'Sao Cristovao FR RJ',
#       'participant1Id': 327303,
#       'participant2': 'EC Nova Cidade RJ',
#       'participant2Id': 342212,
#       'startTime': 1730916000,
#       'time': '18:00:00'}},
#     'seasonId': 122199,
#     'start': 1726790400}],
#   'slug': 'carioca-serie-b1',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 40677},
#  {'categoryName': 'Brazil',
#   'categorySlug': 'brazil',
#   'name': 'Copa do Brasil',
#   'seasons': [{'end': 1731369599,
#     'events': {'0': {'date': '2024-11-10',
#       'eventId': 'id100037354880219',
#       'eventStatus': 'pre-game',
#       'participant1': 'Clube Atletico MG',
#       'participant1Id': 1977,
#       'participant2': 'Flamengo RJ',
#       'participant2Id': 5981,
#       'startTime': 1731265200,
#       'time': '19:00:00'}},
#     'seasonId': 114441,
#     'start': 1708387200}],
#   'slug': 'copa-do-brasil',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 373},
#  {'categoryName': 'Brazil',
#   'categorySlug': 'brazil',
#   'name': 'Copa Rio',
#   'seasons': [{'end': 1731023999,
#     'events': {'0': {'date': '2024-11-06',
#       'eventId': 'id104006154965947',
#       'eventStatus': 'pre-game',
#       'participant1': 'Marica FC RJ',
#       'participant1Id': 342210,
#       'participant2': 'Olaria RJ',
#       'participant2Id': 39616,
#       'startTime': 1730915100,
#       'time': '17:45:00'}},
#     'seasonId': 118633,
#     'start': 1721779200}],
#   'slug': 'copa-rio',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 40061},
#  {'categoryName': 'Brazil',
#   'categorySlug': 'brazil',
#   'name': 'U20 Copa do Brasil',
#   'seasons': [{'end': 1733183999,
#     'events': {'0': {'date': '2024-11-06',
#       'eventId': 'id101441354938535',
#       'eventStatus': 'pre-game',
#       'participant1': 'EC Bahia BA',
#       'participant1Id': 41824,
#       'participant2': 'Goias EC GO',
#       'participant2Id': 237888,
#       'startTime': 1730919600,
#       'time': '19:00:00'},
#      '1': {'date': '2024-11-07',
#       'eventId': 'id101441354938531',
#       'eventStatus': 'pre-game',
#       'participant1': 'Ceara SC CE',
#       'participant1Id': 210332,
#       'participant2': 'EC Macapa AP U20',
#       'participant2Id': 562522,
#       'startTime': 1730937600,
#       'time': '00:00:00'}},
#     'seasonId': 123903,
#     'start': 1727827200}],
#   'slug': 'u20-copa-do-brasil',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 14413},
#  {'categoryName': 'Bulgaria',
#   'categorySlug': 'bulgaria',
#   'name': 'Parva Liga',
#   'seasons': [{'end': 1748735999,
#     'events': {'0': {'date': '2024-11-07',
#       'eventId': 'id100024754160449',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC CSKA 1948',
#       'participant1Id': 288687,
#       'participant2': 'PFC CSKA Sofia',
#       'participant2Id': 3275,
#       'startTime': 1730993400,
#       'time': '15:30:00'},
#      '1': {'date': '2024-11-08',
#       'eventId': 'id100024750748511',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Arda Kardzhali',
#       'participant1Id': 364786,
#       'participant2': 'POFC Botev Vratsa',
#       'participant2Id': 36938,
#       'startTime': 1731070800,
#       'time': '13:00:00'},
#      '2': {'date': '2024-11-08',
#       'eventId': 'id100024750748513',
#       'eventStatus': 'pre-game',
#       'participant1': 'PFC Botev Plovdiv',
#       'participant1Id': 5241,
#       'participant2': 'FC Lokomotiv 1929 Sofia',
#       'participant2Id': 3277,
#       'startTime': 1731079800,
#       'time': '15:30:00'},
#      '3': {'date': '2024-11-09',
#       'eventId': 'id100024750748509',
#       'eventStatus': 'pre-game',
#       'participant1': 'PFC Slavia Sofia',
#       'participant1Id': 3274,
#       'participant2': 'PFC Lokomotiv Plovdiv',
#       'participant2Id': 3272,
#       'startTime': 1731148200,
#       'time': '10:30:00'},
#      '4': {'date': '2024-11-09',
#       'eventId': 'id100024750748517',
#       'eventStatus': 'pre-game',
#       'participant1': 'PFK Beroe Stara Zagora',
#       'participant1Id': 3281,
#       'participant2': 'PFC Cherno More Varna',
#       'participant2Id': 3280,
#       'startTime': 1731157200,
#       'time': '13:00:00'},
#      '5': {'date': '2024-11-09',
#       'eventId': 'id100024750748515',
#       'eventStatus': 'pre-game',
#       'participant1': 'PFC Levski Sofia',
#       'participant1Id': 3273,
#       'participant2': 'FK Septemvri Sofia',
#       'participant2Id': 214054,
#       'startTime': 1731166200,
#       'time': '15:30:00'},
#      '6': {'date': '2024-11-10',
#       'eventId': 'id100024750748503',
#       'eventStatus': 'pre-game',
#       'participant1': 'FK Hebar Pazardzhik',
#       'participant1Id': 45655,
#       'participant2': 'FC CSKA 1948',
#       'participant2Id': 288687,
#       'startTime': 1731234600,
#       'time': '10:30:00'},
#      '7': {'date': '2024-11-10',
#       'eventId': 'id100024750748507',
#       'eventStatus': 'pre-game',
#       'participant1': 'PFC CSKA Sofia',
#       'participant1Id': 3275,
#       'participant2': 'FC Krumovgrad',
#       'participant2Id': 821232,
#       'startTime': 1731243600,
#       'time': '13:00:00'},
#      '8': {'date': '2024-11-10',
#       'eventId': 'id100024750748505',
#       'eventStatus': 'pre-game',
#       'participant1': 'FK Spartak 1918 Varna',
#       'participant1Id': 3278,
#       'participant2': 'PFC Ludogorets 1945 Razgrad',
#       'participant2Id': 43840,
#       'startTime': 1731252600,
#       'time': '15:30:00'}},
#     'seasonId': 119261,
#     'start': 1721347200}],
#   'slug': 'parva-liga',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 247},
#  {'categoryName': 'Bulgaria',
#   'categorySlug': 'bulgaria',
#   'name': 'Second Prof. League',
#   'seasons': [{'end': 1748131199,
#     'events': {'0': {'date': '2024-11-09',
#       'eventId': 'id100113550747805',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Pirin Blagoevgrad',
#       'participant2': 'Litex Lovech',
#       'startTime': 1731155400,
#       'time': '12:30:00'},
#      '1': {'date': '2024-11-09',
#       'eventId': 'id100113550747811',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Fratria Varna',
#       'participant2': 'Gorna Oryahovitsa',
#       'startTime': 1731155400,
#       'time': '12:30:00'},
#      '2': {'date': '2024-11-09',
#       'eventId': 'id100113550747817',
#       'eventStatus': 'pre-game',
#       'participant1': 'PFC Nesebar',
#       'participant2': 'Pfk Botev Plovdiv II',
#       'startTime': 1731155400,
#       'time': '12:30:00'},
#      '3': {'date': '2024-11-09',
#       'eventId': 'id100113550747823',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Yantra Gabrovo',
#       'participant2': 'PFC Minyor Pernik',
#       'startTime': 1731155400,
#       'time': '12:30:00'},
#      '4': {'date': '2024-11-09',
#       'eventId': 'id100113550747807',
#       'eventStatus': 'pre-game',
#       'participant1': 'PFC Dobrudzha Dobrich',
#       'participant2': 'FC Dunav 2010',
#       'startTime': 1731155400,
#       'time': '12:30:00'},
#      '5': {'date': '2024-11-09',
#       'eventId': 'id100113550747809',
#       'eventStatus': 'pre-game',
#       'participant1': 'PFK Sportist Svoge',
#       'participant2': 'FK CSKA 1948 II',
#       'startTime': 1731155400,
#       'time': '12:30:00'},
#      '6': {'date': '2024-11-10',
#       'eventId': 'id100113550747815',
#       'eventStatus': 'pre-game',
#       'participant1': 'PFC Spartak Pleven',
#       'participant2': 'SFC Etar Veliko Tarnovo',
#       'startTime': 1731241800,
#       'time': '12:30:00'},
#      '7': {'date': '2024-11-11',
#       'eventId': 'id100113550747821',
#       'eventStatus': 'pre-game',
#       'participant1': 'PFC Montana 1921',
#       'participant2': 'PFC Belasitsa Petrich',
#       'startTime': 1731339000,
#       'time': '15:30:00'}},
#     'seasonId': 119599,
#     'start': 1721347200}],
#   'slug': 'second-prof-league',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 1135},
#  {'categoryName': 'Cambodia',
#   'categorySlug': 'cambodia',
#   'name': 'Cambodian Premier League',
#   'seasons': [{'end': 1747007999,
#     'events': {'0': {'date': '2024-11-06',
#       'eventId': 'id101925053785083',
#       'eventStatus': 'pre-game',
#       'participant1': 'Boeung Ket Angkor FC',
#       'participant1Id': 95619,
#       'participant2': 'Preah Khan Reach Svay Rieng FC',
#       'participant2Id': 153474,
#       'startTime': 1730894400,
#       'time': '12:00:00'}},
#     'seasonId': 121405,
#     'start': 1723248000}],
#   'slug': 'cambodian-premier-league',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 19250},
#  {'categoryName': 'Chile',
#   'categorySlug': 'chile',
#   'name': 'Primera Division',
#   'seasons': [{'end': 1731369599,
#     'events': {'0': {'date': '2024-11-09',
#       'eventId': 'id102766547445593',
#       'eventStatus': 'pre-game',
#       'participant1': 'Deportes Iquique',
#       'participant1Id': 33596,
#       'participant2': 'Union Espanola',
#       'participant2Id': 3153,
#       'startTime': 1731186000,
#       'time': '21:00:00'},
#      '1': {'date': '2024-11-09',
#       'eventId': 'id102766547445591',
#       'eventStatus': 'pre-game',
#       'participant1': 'Universidad Catolica',
#       'participant1Id': 3151,
#       'participant2': 'Coquimbo Unido',
#       'participant2Id': 3165,
#       'startTime': 1731186000,
#       'time': '21:00:00'},
#      '2': {'date': '2024-11-10',
#       'eventId': 'id102766547445597',
#       'eventStatus': 'pre-game',
#       'participant1': 'Deportes Union La Calera',
#       'participant1Id': 48242,
#       'participant2': 'Cobresal',
#       'participant2Id': 3167,
#       'startTime': 1731250800,
#       'time': '15:00:00'},
#      '3': {'date': '2024-11-10',
#       'eventId': 'id102766547445603',
#       'eventStatus': 'pre-game',
#       'participant1': 'Huachipato',
#       'participant1Id': 3164,
#       'participant2': 'Nublense',
#       'participant2Id': 7029,
#       'startTime': 1731250800,
#       'time': '15:00:00'},
#      '4': {'date': '2024-11-10',
#       'eventId': 'id102766547445601',
#       'eventStatus': 'pre-game',
#       'participant1': 'CD O´Higgins',
#       'participant1Id': 3163,
#       'participant2': 'CD Cobreloa Calama',
#       'participant2Id': 3159,
#       'startTime': 1731250800,
#       'time': '15:00:00'},
#      '5': {'date': '2024-11-10',
#       'eventId': 'id102766547445599',
#       'eventStatus': 'pre-game',
#       'participant1': 'CD Palestino',
#       'participant1Id': 3157,
#       'participant2': 'Audax Italiano',
#       'participant2Id': 3162,
#       'startTime': 1731250800,
#       'time': '15:00:00'},
#      '6': {'date': '2024-11-10',
#       'eventId': 'id102766547445589',
#       'eventStatus': 'pre-game',
#       'participant1': 'Universidad de Chile',
#       'participant1Id': 3161,
#       'participant2': 'CD Everton Vina del Mar',
#       'participant2Id': 5032,
#       'startTime': 1731265200,
#       'time': '19:00:00'},
#      '7': {'date': '2024-11-10',
#       'eventId': 'id102766547445595',
# ...
#       'participant1Id': 427189,
#       'participant2': 'Bangkok United',
#       'participant2Id': 85741,
#       'startTime': 1731240000,
#       'time': '12:00:00'}},
#     'seasonId': 120511,
#     'start': 1723161600}],
#   'slug': 'thai-league-1',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 1032},
#  {'categoryName': 'Turkiye',
#   'categorySlug': 'turkiye',
#   'name': '1. Lig',
#   'seasons': [{'end': 1748649599,
#     'events': {'0': {'date': '2024-11-08',
#       'eventId': 'id100009851856731',
#       'eventStatus': 'pre-game',
#       'participant1': 'ümraniyespor',
#       'participant2': 'Igdir Belediyespor',
#       'startTime': 1731085200,
#       'time': '17:00:00'},
#      '1': {'date': '2024-11-08',
#       'eventId': 'id100009851856733',
#       'eventStatus': 'pre-game',
#       'participant1': 'MKE Ankaragucu',
#       'participant2': 'Esenler Erokspor',
#       'startTime': 1731085200,
#       'time': '17:00:00'},
#      '2': {'date': '2024-11-09',
#       'eventId': 'id100009851856735',
#       'eventStatus': 'pre-game',
#       'participant1': 'Istanbulspor AS',
#       'participant1Id': 3066,
#       'participant2': 'Adanaspor',
#       'participant2Id': 3069,
#       'startTime': 1731148200,
#       'time': '10:30:00'},
#      '3': {'date': '2024-11-09',
#       'eventId': 'id100009851856737',
#       'eventStatus': 'pre-game',
#       'participant1': 'Fatih Karagumruk Istanbul',
#       'participant1Id': 4954,
#       'participant2': 'Yeni Malatyaspor',
#       'participant2Id': 24759,
#       'startTime': 1731157200,
#       'time': '13:00:00'},
#      '4': {'date': '2024-11-09',
#       'eventId': 'id100009851856745',
#       'eventStatus': 'pre-game',
#       'participant1': 'Amedspor',
#       'participant1Id': 225940,
#       'participant2': 'Keciorengucu',
#       'participant2Id': 6366,
#       'startTime': 1731157200,
#       'time': '13:00:00'},
#      '5': {'date': '2024-11-09',
#       'eventId': 'id100009851856747',
#       'eventStatus': 'pre-game',
#       'participant1': 'Corum FK',
#       'participant1Id': 77629,
#       'participant2': 'Pendikspor',
#       'participant2Id': 7032,
#       'startTime': 1731168000,
#       'time': '16:00:00'},
#      '6': {'date': '2024-11-10',
#       'eventId': 'id100009851856739',
#       'eventStatus': 'pre-game',
#       'participant1': 'Bandirmaspor',
#       'participant1Id': 44320,
#       'participant2': 'Boluspor',
#       'participant2Id': 6414,
#       'startTime': 1731234600,
#       'time': '10:30:00'},
#      '7': {'date': '2024-11-10',
#       'eventId': 'id100009851856729',
#       'eventStatus': 'pre-game',
#       'participant1': 'Sanliurfaspor',
#       'participant1Id': 3090,
#       'participant2': 'Genclerbirligi SK',
#       'participant2Id': 7802,
#       'startTime': 1731234600,
#       'time': '10:30:00'},
#      '8': {'date': '2024-11-10',
#       'eventId': 'id100009851856743',
#       'eventStatus': 'pre-game',
#       'participant1': 'Manisa Futbol Kulubu',
#       'participant1Id': 216878,
#       'participant2': 'Buyuksehir Belediye Erzurumspor',
#       'participant2Id': 55603,
#       'startTime': 1731243600,
#       'time': '13:00:00'},
#      '9': {'date': '2024-11-10',
#       'eventId': 'id100009851856741',
#       'eventStatus': 'pre-game',
#       'participant1': 'Sakaryaspor',
#       'participant1Id': 3080,
#       'participant2': 'Kocaelispor',
#       'participant2Id': 3065,
#       'startTime': 1731254400,
#       'time': '16:00:00'}},
#     'seasonId': 121433,
#     'start': 1723161600}],
#   'slug': '1-lig',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 98},
#  {'categoryName': 'Turkiye',
#   'categorySlug': 'turkiye',
#   'name': 'Super Lig',
#   'seasons': [{'end': 1748908799,
#     'events': {'0': {'date': '2024-11-08',
#       'eventId': 'id100005251472007',
#       'eventStatus': 'pre-game',
#       'participant1': 'Kasimpasa Istanbul',
#       'participant1Id': 6063,
#       'participant2': 'Kayserispor',
#       'participant2Id': 3072,
#       'startTime': 1731085200,
#       'time': '17:00:00'},
#      '1': {'date': '2024-11-09',
#       'eventId': 'id100005251472011',
#       'eventStatus': 'pre-game',
#       'participant1': 'Hatayspor Antakya',
#       'participant1Id': 3091,
#       'participant2': 'Gaziantep FK',
#       'participant2Id': 5138,
#       'startTime': 1731157200,
#       'time': '13:00:00'},
#      '2': {'date': '2024-11-09',
#       'eventId': 'id100005251472005',
#       'eventStatus': 'pre-game',
#       'participant1': 'Caykur Rizespor',
#       'participant1Id': 3064,
#       'participant2': 'Trabzonspor',
#       'participant2Id': 3051,
#       'startTime': 1731168000,
#       'time': '16:00:00'},
#      '3': {'date': '2024-11-09',
#       'eventId': 'id100005251472001',
#       'eventStatus': 'pre-game',
#       'participant1': 'Adana Demirspor',
#       'participant1Id': 3101,
#       'participant2': 'Eyupspor',
#       'participant2Id': 7040,
#       'startTime': 1731168000,
#       'time': '16:00:00'},
#      '4': {'date': '2024-11-10',
#       'eventId': 'id100005251472015',
#       'eventStatus': 'pre-game',
#       'participant1': 'Goztepe Izmir',
#       'participant1Id': 3054,
#       'participant2': 'Konyaspor',
#       'participant2Id': 3085,
#       'startTime': 1731234600,
#       'time': '10:30:00'},
#      '5': {'date': '2024-11-10',
#       'eventId': 'id100005251472013',
#       'eventStatus': 'pre-game',
#       'participant1': 'Antalyaspor',
#       'participant1Id': 3056,
#       'participant2': 'BB Bodrumspor',
#       'participant2Id': 216876,
#       'startTime': 1731240000,
#       'time': '12:00:00'},
#      '6': {'date': '2024-11-10',
#       'eventId': 'id100005251472009',
#       'eventStatus': 'pre-game',
#       'participant1': 'Galatasaray Istanbul',
#       'participant1Id': 3061,
#       'participant2': 'Samsunspor',
#       'participant2Id': 3053,
#       'startTime': 1731243600,
#       'time': '13:00:00'},
#      '7': {'date': '2024-11-10',
#       'eventId': 'id100005251472003',
#       'eventStatus': 'pre-game',
#       'participant1': 'Fenerbahce Istanbul',
#       'participant1Id': 3052,
#       'participant2': 'Sivasspor',
#       'participant2Id': 3076,
#       'startTime': 1731254400,
#       'time': '16:00:00'},
#      '8': {'date': '2024-11-10',
#       'eventId': 'id100005251472017',
#       'eventStatus': 'pre-game',
#       'participant1': 'Istanbul Basaksehir',
#       'participant1Id': 3086,
#       'participant2': 'Besiktas Istanbul',
#       'participant2Id': 3050,
#       'startTime': 1731254400,
#       'time': '16:00:00'}},
#     'seasonId': 119883,
#     'start': 1723248000}],
#   'slug': 'super-lig',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 52},
#  {'categoryName': 'Uganda',
#   'categorySlug': 'uganda',
#   'name': 'Premier League',
#   'seasons': [{'end': 1748217599,
#     'events': {'0': {'date': '2024-11-06',
#       'eventId': 'id101486454057149',
#       'eventStatus': 'pre-game',
#       'participant1': 'Wakiso Giants',
#       'participant1Id': 474814,
#       'participant2': 'Lugazi Municipal FC',
#       'participant2Id': 528159,
#       'startTime': 1730898000,
#       'time': '13:00:00'},
#      '1': {'date': '2024-11-06',
#       'eventId': 'id101486454057151',
#       'eventStatus': 'pre-game',
#       'participant1': 'UPDF FC',
#       'participant1Id': 218708,
#       'participant2': 'Mbarara City FC',
#       'participant2Id': 325273,
#       'startTime': 1730898000,
#       'time': '13:00:00'}},
#     'seasonId': 122637,
#     'start': 1726185600}],
#   'slug': 'premier-league',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 14864},
#  {'categoryName': 'Ukraine',
#   'categorySlug': 'ukraine',
#   'name': 'Premier League',
#   'seasons': [{'end': 1748908799,
#     'events': {'0': {'date': '2024-11-08',
#       'eventId': 'id100021851158255',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Chernomorets Odessa',
#       'participant1Id': 3310,
#       'participant2': 'FC Vorskla Poltava',
#       'participant2Id': 3309,
#       'startTime': 1731072600,
#       'time': '13:30:00'},
#      '1': {'date': '2024-11-08',
#       'eventId': 'id100021852112213',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Levy Bereg Kyiv',
#       'participant1Id': 822006,
#       'participant2': 'FC Ingulets Petrove',
#       'participant2Id': 211970,
#       'startTime': 1731081600,
#       'time': '16:00:00'},
#      '2': {'date': '2024-11-09',
#       'eventId': 'id100021851158243',
#       'eventStatus': 'pre-game',
#       'participant1': 'LNZ Cherkasy',
#       'participant1Id': 312744,
#       'participant2': 'FC Obolon Kyiv',
#       'participant2Id': 3312,
#       'startTime': 1731150000,
#       'time': '11:00:00'},
#      '3': {'date': '2024-11-09',
#       'eventId': 'id100021851158253',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Oleksandriya',
#       'participant1Id': 25479,
#       'participant2': 'Karpaty Lviv',
#       'participant2Id': 3316,
#       'startTime': 1731159000,
#       'time': '13:30:00'},
#      '4': {'date': '2024-11-09',
#       'eventId': 'id100021851158245',
#       'eventStatus': 'pre-game',
#       'participant1': 'Kolos Kovalivka',
#       'participant1Id': 213176,
#       'participant2': 'FC Kryvbas Kriviy Rih',
#       'participant2Id': 3320,
#       'startTime': 1731168000,
#       'time': '16:00:00'},
#      '5': {'date': '2024-11-10',
#       'eventId': 'id100021851158241',
#       'eventStatus': 'pre-game',
#       'participant1': 'Veres Rivne',
#       'participant1Id': 213180,
#       'participant2': 'FC Rukh Lviv',
#       'participant2Id': 277645,
#       'startTime': 1731236400,
#       'time': '11:00:00'},
#      '6': {'date': '2024-11-10',
#       'eventId': 'id100021851158249',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Shakhtar Donetsk',
#       'participant1Id': 3313,
#       'participant2': 'FC Zorya Lugansk',
#       'participant2Id': 5987,
#       'startTime': 1731245400,
#       'time': '13:30:00'},
#      '7': {'date': '2024-11-10',
#       'eventId': 'id100021851158247',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Dynamo Kyiv',
#       'participant1Id': 3305,
#       'participant2': 'FC Polissya Zhytomyr',
#       'participant2Id': 350828,
#       'startTime': 1731254400,
#       'time': '16:00:00'}},
#     'seasonId': 120467,
#     'start': 1722556800}],
#   'slug': 'premier-league',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 218},
#  {'categoryName': 'Uruguay',
#   'categorySlug': 'uruguay',
#   'name': 'Primera Division',
#   'seasons': [{'end': 1735689599,
#     'events': {'0': {'date': '2024-11-08',
#       'eventId': 'id100027855109909',
#       'eventStatus': 'pre-game',
#       'participant1': 'CA Cerro',
#       'participant2': 'Deportivo Maldonado',
#       'startTime': 1731099600,
#       'time': '21:00:00'},
#      '1': {'date': '2024-11-08',
#       'eventId': 'id100027855109923',
#       'eventStatus': 'pre-game',
#       'participant1': 'Racing Club Montevideo',
#       'participant2': 'Nacional Montevideo',
#       'startTime': 1731108600,
#       'time': '23:30:00'},
#      '2': {'date': '2024-11-09',
#       'eventId': 'id100027855109927',
#       'eventStatus': 'pre-game',
#       'participant1': 'Cerro Largo FC',
#       'participant2': 'River Plate Montevideo',
#       'startTime': 1731156300,
#       'time': '12:45:00'},
#      '3': {'date': '2024-11-09',
#       'eventId': 'id100027855109931',
#       'eventStatus': 'pre-game',
#       'participant1': 'Rampla Juniors',
#       'participant2': 'Danubio FC',
#       'startTime': 1731180600,
#       'time': '19:30:00'},
#      '4': {'date': '2024-11-09',
#       'eventId': 'id100027855109935',
#       'eventStatus': 'pre-game',
#       'participant1': 'CA Penarol Montevideo',
#       'participant2': 'Liverpool Montevideo',
#       'startTime': 1731189600,
#       'time': '22:00:00'},
#      '5': {'date': '2024-11-10',
#       'eventId': 'id100027855109939',
#       'eventStatus': 'pre-game',
#       'participant1': 'Miramar Misiones',
#       'participant2': 'CA Boston River',
#       'startTime': 1731198600,
#       'time': '00:30:00'},
#      '6': {'date': '2024-11-10',
#       'eventId': 'id100027855109941',
#       'eventStatus': 'pre-game',
#       'participant1': 'CA Progreso',
#       'participant2': 'Montevideo',
#       'startTime': 1731267000,
#       'time': '19:30:00'},
#      '7': {'date': '2024-11-10',
#       'eventId': 'id100027855109945',
#       'eventStatus': 'pre-game',
#       'participant1': 'Defensor Sporting',
#       'participant2': 'Atletico Fenix Montevideo',
#       'startTime': 1731276000,
#       'time': '22:00:00'}},
#     'seasonId': 115531,
#     'start': 1708041600}],
#   'slug': 'primera-division',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 278},
#  {'categoryName': 'USA',
#   'categorySlug': 'usa',
#   'name': 'MLS',
#   'seasons': [{'end': 1733702399,
#     'events': {'0': {'date': '2024-11-09',
#       'eventId': 'id100024255246411',
#       'eventStatus': 'pre-game',
#       'participant1': 'Los Angeles FC',
#       'participant1Id': 402227,
#       'participant2': 'Vancouver Whitecaps FC',
#       'participant2Id': 22010,
#       'startTime': 1731123000,
#       'time': '03:30:00'},
#      '1': {'date': '2024-11-09',
#       'eventId': 'id100024255196019',
#       'eventStatus': 'pre-game',
#       'participant1': 'FC Cincinnati',
#       'participant1Id': 245305,
#       'participant2': 'New York City FC',
#       'participant2Id': 167510,
#       'startTime': 1731186000,
#       'time': '21:00:00'},
#      '2': {'date': '2024-11-09',
#       'eventId': 'id100024255162707',
#       'eventStatus': 'pre-game',
#       'participant1': 'Orlando City SC',
#       'participant1Id': 52237,
#       'participant2': 'Charlotte FC',
#       'participant2Id': 863473,
#       'startTime': 1731193200,
#       'time': '23:00:00'},
#      '3': {'date': '2024-11-10',
#       'eventId': 'id100024255196021',
#       'eventStatus': 'pre-game',
#       'participant1': 'Inter Miami CF',
#       'participant1Id': 659691,
#       'participant2': 'Atlanta United FC',
#       'participant2Id': 305920,
#       'startTime': 1731200400,
#       'time': '01:00:00'}},
#     'seasonId': 114057,
#     'start': 1708473600}],
#   'slug': 'mls',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 242},
#  {'categoryName': 'Wales',
#   'categorySlug': 'wales',
#   'name': 'Cymru Premier',
#   'seasons': [{'end': 1747612799,
#     'events': {'0': {'date': '2024-11-08',
#       'eventId': 'id100025450943027',
#       'eventStatus': 'pre-game',
#       'participant1': 'Aberystwyth Town',
#       'participant1Id': 4905,
#       'participant2': 'Newtown AFC',
#       'participant2Id': 4918,
#       'startTime': 1731095100,
#       'time': '19:45:00'},
#      '1': {'date': '2024-11-09',
#       'eventId': 'id100025450943035',
#       'eventStatus': 'pre-game',
#       'participant1': 'Penybont',
#       'participant1Id': 115185,
#       'participant2': 'Flint Town United',
#       'participant2Id': 37090,
#       'startTime': 1731162600,
#       'time': '14:30:00'},
#      '2': {'date': '2024-11-09',
#       'eventId': 'id100025450943031',
#       'eventStatus': 'pre-game',
#       'participant1': 'Barry Town FC',
#       'participant1Id': 35186,
#       'participant2': "Connah's Quay Nomads FC",
#       'participant2Id': 4912,
#       'startTime': 1731162600,
#       'time': '14:30:00'},
#      '3': {'date': '2024-11-09',
#       'eventId': 'id100025450943033',
#       'eventStatus': 'pre-game',
#       'participant1': 'Briton Ferry',
#       'participant1Id': 130034,
#       'participant2': 'Caernarfon Town',
#       'participant2Id': 4909,
#       'startTime': 1731162600,
#       'time': '14:30:00'},
#      '4': {'date': '2024-11-09',
#       'eventId': 'id100025450943029',
#       'eventStatus': 'pre-game',
#       'participant1': 'Cardiff Met University',
#       'participant1Id': 167106,
#       'participant2': 'Bala Town FC',
#       'participant2Id': 36255,
#       'startTime': 1731172500,
#       'time': '17:15:00'},
#      '5': {'date': '2024-11-10',
#       'eventId': 'id100025450943037',
#       'eventStatus': 'pre-game',
#       'participant1': 'The New Saints FC',
#       'participant1Id': 4921,
#       'participant2': 'Haverfordwest County',
#       'participant2Id': 4915,
#       'startTime': 1731249000,
#       'time': '14:30:00'}},
#     'seasonId': 118707,
#     'start': 1723161600}],
#   'slug': 'cymru-premier',
#   'sportName': 'Soccer',
#   'sportSlug': 'soccer',
#   'tournamentId': 254}]

# %%
df_merged = pd.merge(df_events, df[['eventId', 'participant1', 'participant2']], left_on='Event ID', right_on='eventId', how='left')
df_merged
# Out:
#               Event ID  Event Date                      Market Name  \
# 0    id100013150869217  2024-10-27                 Full Time Result
# 1    id100013150869217  2024-10-27                 Full Time Result
# 2    id100013150869217  2024-10-27                 Full Time Result
# 3    id100013150869217  2024-10-27              Both Teams To Score
# 4    id100013150869217  2024-10-27              Both Teams To Score
# ..                 ...         ...                              ...
# 251  id100003750868143  2024-10-27            Over Under First Half
# 252  id100003750868143  2024-10-27   Both Teams To Score First Half
# 253  id100003750868143  2024-10-27   Both Teams To Score First Half
# 254  id100003750868143  2024-10-27  Both Teams To Score Second Half
# 255  id100003750868143  2024-10-27  Both Teams To Score Second Half
#
#     Outcome Name  Price Handicap   Odds Type Bookmaker            eventId  \
# 0              1  2.500        0        3Way    bet365  id100013150869217
# 1              X  4.000        0        3Way    bet365  id100013150869217
# 2              2  2.400        0        3Way    bet365  id100013150869217
# 3            Yes  1.571        0      Totals    bet365  id100013150869217
# 4             No  2.250        0      Totals    bet365  id100013150869217
# ..           ...    ...      ...         ...       ...                ...
# 251        Under  1.025      3.5  Over/Under    bet365  id100003750868143
# 252          Yes  4.000        0       Score    bet365  id100003750868143
# 253           No  1.222        0       Score    bet365  id100003750868143
# 254          Yes  3.000        0       Score    bet365  id100003750868143
# 255           No  1.363        0       Score    bet365  id100003750868143
#
#        participant1     participant2
# 0    MVV Maastricht    Helmond Sport
# 1    MVV Maastricht    Helmond Sport
# 2    MVV Maastricht    Helmond Sport
# 3    MVV Maastricht    Helmond Sport
# 4    MVV Maastricht    Helmond Sport
# ..              ...              ...
# 251      AZ Alkmaar  Go Ahead Eagles
# 252      AZ Alkmaar  Go Ahead Eagles
# 253      AZ Alkmaar  Go Ahead Eagles
# 254      AZ Alkmaar  Go Ahead Eagles
# 255      AZ Alkmaar  Go Ahead Eagles
#
# [256 rows x 11 columns]

# %%
df_merged.to_csv('bet365APIoutput.csv')
